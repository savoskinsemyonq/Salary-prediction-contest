# %%
import lightgbm as lgb, catboost as cb
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split

import os
import networkx as nx
from collections import Counter

from tqdm import tqdm
import pickle

pd.set_option('display.max_columns', None)

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# root_dir = "/kaggle/input/nsu-jobs/"

# %%
# !pip install pymorphy2
# !pip install cytoolz
# Out:
# Requirement already satisfied: pymorphy2 in /opt/conda/lib/python3.10/site-packages (0.9.1)
# Requirement already satisfied: dawg-python>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /opt/conda/lib/python3.10/site-packages (from pymorphy2) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in /opt/conda/lib/python3.10/site-packages (from pymorphy2) (0.6.2)
# Requirement already satisfied: cytoolz in /opt/conda/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: toolz>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from cytoolz) (0.12.0)

# %%
X_train = pd.read_csv("/kaggle/input/nsu-jobs/nsu-bda-2023-jobs/X_train.csv")
y_train = pd.read_csv("/kaggle/input/nsu-jobs/nsu-bda-2023-jobs/y_train.csv")
X_train=X_train.merge(y_train,how='left', on='id')

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27934 entries, 0 to 27933
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        27934 non-null  int64
#  1   name                      27934 non-null  object
#  2   has_test                  27934 non-null  bool
#  3   response_letter_required  27934 non-null  bool
#  4   salary_from               23902 non-null  float64
#  5   salary_currency           27934 non-null  object
#  6   salary_gross              27786 non-null  object
#  7   published_at              27934 non-null  object
#  8   created_at                27934 non-null  object
#  9   employer_name             27934 non-null  object
#  10  description               27933 non-null  object
#  11  area_id                   27934 non-null  int64
#  12  area_name                 27934 non-null  object
#  13  salary_to                 27934 non-null  float64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 2.6+ MB

# %%
X_train.description = X_train.description.fillna('')
#Все времена индентичны, чекал X_train[X_train.published_at!=X_train.created_at]
X_train.published_at = pd.to_datetime(X_train.published_at, errors='raise')
X_train.created_at = pd.to_datetime(X_train.created_at, errors='raise')
X_train['timestamp'] = (X_train.published_at.astype('int64') / 10**9)
X_train.salary_gross=X_train.salary_gross.astype('bool')

# %%
X_train.loc[X_train.salary_gross, 'salary_from'] = X_train.loc[X_train.salary_gross].salary_from*1.13

# %% [markdown]
# # Features from title

# %%
import nltk
nltk.download('stopwords')

def int_to_roman(x):
    """
    Normalizing titles like software engineer 3

    Also filters out numbers that are not likely part of a seniority description, i.e. 2000
    """

    if not x.isnumeric():
        return x
    x = int(x)
    ints = (1000, 900,  500, 400, 100,  90, 50,  40, 10,  9,   5,  4,   1)
    nums = ('M',  'CM', 'D', 'CD','C', 'XC','L','XL','X','IX','V','IV','I')
    result = []
    for i in range(len(ints)):
        count = int(x / ints[i])
        result.append(nums[i] * count)
        x -= ints[i] * count
    result = ''.join(result).lower()
    if any([n in result for n in ['M', 'C', 'D', 'X', 'L']]):
        return ""
    return ''.join(result).lower()
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from pymorphy2 import MorphAnalyzer
from nltk import wordpunct_tokenize
from cytoolz import memoize
import re
from nltk.corpus import stopwords
from string import punctuation

morph = MorphAnalyzer()

stops = set(stopwords.words('russian'))
stops.update(set(punctuation))
stopwords = ['ул', 'пр', 'кт']
stops.update(set(stopwords))


functors_pos = {'INTJ', 'PRCL', 'CONJ', 'PREP'}  # function words

def preprocess_title(title:str):
    if pd.isna(title) or title == "":
        return []
    tokens = wordpunct_tokenize(title)
    tokens = [token.lower() for token in tokens]
    tokens = [re.sub(r"[^\w\s]", "", token) for token in tokens]
    # tokens = [re.sub(r"\d+", "", token) for token in tokens]
  ## lemmatization
    tokens = [morph.normal_forms(token)[0] for token in tokens]

  # удалить дубликаты
    tokens = [k for k, v in Counter(tokens).items() if v == 1]

  # удалить междометия, частицы, союзы и предлоги
    functors_pos = {'INTJ', 'PRCL', 'CONJ', 'PREP'}  # function words
    tokens = [token for token in tokens if morph.parse(token)[0].tag.POS not in functors_pos]

  # удалить слова из 1 символа кроме
    good_words = {'c'}
    tokens = [token for token in tokens if len(token) >= 2 or token in good_words]

  #remove stop words
    tokens = [token for token in tokens if token not in stops]

    tokens = [int_to_roman(token) for token in tokens]
    tokens = list(filter(bool, tokens))
  # print(f"{title} -> {tokens}")
    return tokens

# %%
titles = ['директора 2', 'дата-аналитик', 'Менеджер по продажам (брокер) элитной городской недвижимости', 'Продавец-кассир (Москва, Вернадского, 93)']
for t in titles:
    print(preprocess_title(t))
# Out:
# ['директор']
# ['дата', 'аналитик']
# ['менеджер', 'продажа', 'брокер', 'элитный', 'городской', 'недвижимость']
# ['продавец', 'кассир', 'москва', 'вернадский', 'xciii']

# %%
from tqdm import tqdm
names1 = []
names2 = []
names3 = []
for t in tqdm(X_train.name):
    title = preprocess_title(t)
    if(len(title)>=3):
        names1.append(title[0])
        names2.append(title[1])
        names3.append(title[2])
    elif(len(title)>=2):
        names1.append(title[0])
        names2.append(title[1])
        names3.append('')
    elif(len(title)>=1):
        names1.append(title[0])
        names2.append('')
        names3.append('')
    else:
        names1.append('')
        names2.append('')
        names3.append('')
# Out:
# 100%|██████████| 27934/27934 [00:59<00:00, 472.22it/s]

# %%
X_train['start_name1'] = names1
X_train['start_name2'] = names2
X_train['start_name3'] = names3

# %%
title_counts = Counter(X_train['name'].apply(lambda x: " ".join(preprocess_title(x))).values)
del title_counts['']
title_counts.most_common(10)
# Out:
# [('менеджер продажа', 344),
#  ('менеджер работа клиент', 203),
#  ('уборщица уборщик', 197),
#  ('юрист', 163),
#  ('помощник юрист', 149),
#  ('аналитик', 146),
#  ('оператор call центр', 136),
#  ('frontend разработчик', 124),
#  ('копирайтер', 115),
#  ('офис менеджер', 108)]

# %%
len(title_counts)
# Out:
# 14968

# %%
from cytoolz import isdistinct, topk
from itertools import product
from operator import itemgetter

def get_gram_counts(tokens, best_grams):
    results = []
    seen = set()
    if not best_grams:
        gram_product = product(tokens, repeat=2)
    else:
        gram_product = product(tokens, best_grams)
    for title_grams in gram_product:
        if not isdistinct(title_grams):
            continue
        title = " ".join(title_grams)
        if title in seen:
            continue
        else:
            seen.add(title)
        count = title_counts.get(title, 0)
        results.append((title, count))
    return sorted(results, key=itemgetter(1), reverse=True)


def optimize_title(x:str, topn=3, title_counts=title_counts):
    tokens = preprocess_title(x)
    if not tokens:
        return x
    if len(tokens)==1:
        return tokens[0]

    starting_score = title_counts.get(x, 1)
    best_ngrams = [(token, title_counts.get(token, 0)) for token in tokens]
    gram_counter = 2
    while gram_counter <= len(tokens): # Continue chaining tokens to get the highest score
        gram_counts = get_gram_counts(tokens, [token for token, score in best_ngrams])
        best_ngrams.extend(gram_counts)
        best_ngrams = list(topk(topn, best_ngrams, key=itemgetter(1)))
        if not any([g in best_ngrams for g in gram_counts]):  # The most recent get_gram_counts did not 'make the cut'
            best_ngram_found = topk(1, best_ngrams, key=itemgetter(1))[0]
            best_ngram, best_ngram_score = best_ngram_found
            if best_ngram_score > starting_score:
                return best_ngram
            else:
                return x
        gram_counter += 1
    return best_ngrams[0][0]

# %%
optimum_titless = []
optimum_countss = []

for title in tqdm(X_train.name):
    optimum_title = optimize_title(title, title_counts=title_counts)
    optimum_count = title_counts[optimum_title]
    optimum_titless.append(optimum_title)
    optimum_countss.append(optimum_count)
# Out:
# 100%|██████████| 27934/27934 [01:03<00:00, 437.23it/s]

# %%
X_train['optimum_title'] = optimum_titless
X_train[['name','start_name1','start_name2','start_name3','optimum_title']].sample(10)
# Out:
#                                                     name start_name1  \
# 12805  Продавец-консультант (Санкт-Петербург, пр-кт Э...    продавец
# 11492                         Менеджер по продажам (ГПД)    менеджер
# 20261               Middle+ React разработчик (удалённо)      middle
# 14812                                              Повар       повар
# 1166      Backend Python / Django разработчик (удаленно)     backend
# 25707                                 Укладчик-упаковщик    укладчик
# 19913     Уборщик производственных и служебных помещений     уборщик
# 24122       Продавец-кассир (Москва, ул Дубнинская, 44А)    продавец
# 27396                                  Педагог-хореограф     педагог
# 26134                         Помощник менеджера проекта    помощник
#
#             start_name2  start_name3         optimum_title
# 12805       консультант        санкт  продавец консультант
# 11492           продажа          гпд      менеджер продажа
# 20261             react  разработчик           разработчик
# 14812                                                повар
# 1166             python       django    python разработчик
# 25707         упаковщик                 укладчик упаковщик
# 19913  производственный    служебный     уборщик помещение
# 24122            кассир       москва       продавец кассир
# 27396         хореограф                  педагог хореограф
# 26134          менеджер       проект       менеджер проект

# %%
# X_train[X_train.employer_name=='Астор']

# %% [markdown]
# # Features description

# %%
from pymorphy2 import MorphAnalyzer
from nltk import wordpunct_tokenize, word_tokenize
from cytoolz import memoize
import re
from nltk.corpus import stopwords
from string import punctuation
from collections import Counter

morph = MorphAnalyzer()

stops = set(stopwords.words('russian'))
stops.update(set(punctuation))
stopwords = ['ул', 'пр', 'кт']
stops.update(set(stopwords))

functors_pos = {'INTJ', 'PRCL', 'CONJ', 'PREP'}  # function words

def is_rus(s: str):
    rus = set('абвгдеёжзийклмнопрстуфхцчшщъыьэюя1234567890')
    return all(map(lambda symbol: symbol in rus, s))

def tokenize(desc:str,is_lemmatization=False, mod=1):
    if pd.isna(desc) or desc == "":
        return []
    
    if mod == 1:
        tokens = wordpunct_tokenize(desc)
    else:
        tokens = word_tokenize(desc)
    
    tokens = [token.lower() for token in tokens]
    
    if is_lemmatization:
        tokens = [morph.normal_forms(token)[0] for token in tokens]
    
    return tokens
        
    
def desc_to_tokens(tokens:list, delete_non_unction_words=False, only_words=True):

  if only_words:
      tokens = [re.sub(r"[^\w\s]", "", token) for token in tokens]
  # tokens = [re.sub(r"\d+", "", token) for token in tokens]
  # lemmatization не делаю, т.к. высшее становится высокий
#   if is_lemmatization:
#       tokens = [morph.normal_forms(token)[0] for token in tokens]

  # удалить дубликаты
  # tokens = [k for k, v in Counter(tokens).items() if v == 1]

#   удалить междометия, частицы, союзы и предлоги
  if delete_non_unction_words:
      functors_pos = {'INTJ', 'PRCL', 'CONJ', 'PREP'}  # function words
      tokens = [token for token in tokens if morph.parse(token)[0].tag.POS not in functors_pos]

  # удалить слова из 1 символа кроме
  # good_words = {'c', '.'}
  # tokens = [token for token in tokens if len(token) >= 2 or token in good_words]

  #remove stop words
  # tokens = [token for token in tokens if token not in stops]

  tokens = list(filter(bool, tokens))
  # print(f"{desc} -> {tokens}")
  return tokens

# %%
"""
Проверяет, есть ли токен X в delta токенов окресности списка токенов 
m - объект match
"""
def is_word_near_eng(x: str, spisok: list, position: int, delta=6):
    
    if position >= len(spisok):
        return False
    
    okresnost = (spisok[:position])[-delta:] + (spisok[position+1:])[:delta]
    
    return x in okresnost

"""
Возвращает строку из eng_levels = ['A', 'B', 'C'] или None
"""
def get_english(desc_tokens: list):
    
    eng_levels = ['A', 'B', 'C']
    
    eng_levels_matching_strong = {
        'с1': eng_levels[2],
        'с2': eng_levels[2],
        'c1': eng_levels[2],
        'c2': eng_levels[2],
        'b1': eng_levels[1],
        'b2': eng_levels[1],
        'a1': eng_levels[0],
        'a2': eng_levels[0],
        'intermediate': eng_levels[1],
        'advanced': eng_levels[2],
        'proficient': eng_levels[2],
        'elementary': eng_levels[0],
    }
    
    eng_levels_matching = {
        'разговорный': eng_levels[2],
        'свободный': eng_levels[2],
        'свободно': eng_levels[2],
        'письменный': eng_levels[1],
        'уверенный':eng_levels[1],
        'чтение': eng_levels[1], 
        'технический': eng_levels[1],
        'литература': eng_levels[1],
        'средний': eng_levels[1],
        'хороший': eng_levels[1],
        'написание': eng_levels[1],
        'знать': eng_levels[1],
        'уровень': eng_levels[1],
        'общение': eng_levels[2],
    }
    
    angliiskii = 'английский'
    
    for token in desc_tokens:
        for eng_level in eng_levels_matching_strong.keys():
            if eng_level in token:
                return eng_levels_matching_strong[eng_level]
    
    for i in range(len(desc_tokens)):
        if angliiskii in desc_tokens[i]:
            for eng_level in eng_levels_matching.keys():
                if is_word_near_eng(position=i, spisok=desc_tokens,x=eng_level):
                    return eng_levels_matching[eng_level]
     
    return None

# %%
eng_test = ['Английский или немецкий язык на разговорном уровне ',
'Английский за счет компании;',
'Английский язык (письменный профессиональный must have),',
'если знаете английский язык и управляли небольшой командой.',
'Уверенный английский для изучения научной литературы.',
'английский язык - чтение технической литературы',
'Желательно английский язык для чтения тех. Документации',
'Английский не ниже Intermediate.',
'английский (средний, профессиональная терминология);',
'Команда русскоговорящая, но хороший английский может Вам пригодиться',
'Английский язык (свободно).',
'Технический английский язык (чтение документации',
'Английский язык - на уровне, достаточном для',
'английский будет плюсом',
'ной язык общения — английский',
'Английский язык не ниже уровня Upper Intermediate.',
'Английский язык Intermediate и выше',
'Корпоративный английский язык',
'Английский от upper-intermediate',
'нужно знать английский язык, а также',
'Английский язык от <strong>Intermediate<',
'Английский разговорный',
'Английский язык технический',
'Английский язык (на уровне чтения технической документации)',
'Свободный английский язык',
'Английский язык - intermediate',
'Английский не -ниже уровня B2 (Upper-Intermediate);',
'Английский, письменный и устный, свободное общение<',
'Хороший технический и разговорный английский (Intermediate +)<',
'Английский язык на уровне чтения профессиональной литературы',
'Английский язык на уровне написания текстов.',
'Разговорный английский язык.',
'Английский язык - не ниже С1;']

# h = [desc_to_tokens(a, True, True, mod = 0) for a in eng_test]

tokens_eng=[tokenize(a,is_lemmatization=True,mod = 0) for a in eng_test]
h = [desc_to_tokens(a, True) for a in tokens_eng]
h1 = [get_english(t) for t in h]

for lvl, desc in zip(h1, eng_test):
    print (f'{desc}\n -> {lvl}')
# Out:
# Английский или немецкий язык на разговорном уровне
#  -> C
# Английский за счет компании;
#  -> None
# Английский язык (письменный профессиональный must have),
#  -> B
# если знаете английский язык и управляли небольшой командой.
#  -> B
# Уверенный английский для изучения научной литературы.
#  -> B
# английский язык - чтение технической литературы
#  -> B
# Желательно английский язык для чтения тех. Документации
#  -> B
# Английский не ниже Intermediate.
#  -> B
# английский (средний, профессиональная терминология);
#  -> B
# Команда русскоговорящая, но хороший английский может Вам пригодиться
#  -> B
# Английский язык (свободно).
#  -> C
# Технический английский язык (чтение документации
#  -> B
# Английский язык - на уровне, достаточном для
#  -> B
# английский будет плюсом
#  -> None
# ной язык общения — английский
#  -> C
# Английский язык не ниже уровня Upper Intermediate.
#  -> B
# Английский язык Intermediate и выше
#  -> B
# Корпоративный английский язык
#  -> None
# Английский от upper-intermediate
#  -> B
# нужно знать английский язык, а также
#  -> B
# Английский язык от <strong>Intermediate<
#  -> B
# Английский разговорный
#  -> C
# Английский язык технический
#  -> B
# Английский язык (на уровне чтения технической документации)
#  -> B
# Свободный английский язык
#  -> C
# Английский язык - intermediate
#  -> B
# Английский не -ниже уровня B2 (Upper-Intermediate);
#  -> B
# Английский, письменный и устный, свободное общение<
#  -> C
# Хороший технический и разговорный английский (Intermediate +)<
#  -> B
# Английский язык на уровне чтения профессиональной литературы
#  -> B
# Английский язык на уровне написания текстов.
#  -> B
# Разговорный английский язык.
#  -> C
# Английский язык - не ниже С1;
#  -> C

# %%
"""
Проверяет, есть ли токен X в delta токенов окресности списка токенов 
m - объект match
"""
def is_word_near_exp(x: str, spisok: list, position: int, delta=6):
    
    if position >= len(spisok):
        return False
    
    okresnost = (spisok[:position])[-delta:] + (spisok[position+1:])[:delta]
    
    return x in okresnost

def get_number(t: str):
    regular_digit = r'\b\d-й\b'
    if t.replace(',','',1).isdigit() or t.replace('.','',1).isdigit():
        return float(t.replace(',','.',1))           
    if re.match(regular_digit, t):  # 1-й 3-й 2-й
        return int(''.join(filter(str.isdigit, t)))
    return None
    

def get_experience(desc_tokens: list, debug=False):
#     опыт + число + год/месяц (рядом)
#     опыт + год
#     опыт работа

    year_time = ['год', 'лет']
    mounth_time = ['месяц']
    
    need_exp = ['только', 'обязательный']
    no_exp = 'без'
    
    delta = 15
    
    default_exp = 1
    
    is_need_exp = 0
    
    for i in range(len(desc_tokens)):
        if 'опыт' in desc_tokens[i]: # нашел опыт
            if debug:
                print(f'check: {desc_tokens[i+1:i+1+delta]}')
        
            next_tokens = desc_tokens[i+1:i+1+delta]
            for j in range(len(next_tokens)):
                if debug:
                    print(f'check: {next_tokens[j]}')
                num = get_number(next_tokens[j]) # в следующих токенах есть число
                if debug:
                    print(f'num: {num}')
                if num:
                    if num >= 15: # не то
                        continue
                    try:
                        if debug:
                            print(f'desc_tokens[j+1]: {next_tokens[j+1]}')
                        # после числа должен быть год или месяц

                        if next_tokens[j+1] in year_time: 
                            # опыт + число + год/месяц (рядом)
                            return num
                        if next_tokens[j+1] in mounth_time:
                            return num/12
                    except Exception:
                        continue
                else:
                    if debug:
                        print(f'{next_tokens[j]} - не число')
                    
            # в следующих токенах нет числа, поищем слово год
            for value in desc_tokens[i+1:i+1+delta]:
                if 'год' in value:
                    return 1
        
            # вероятно, это не тот опыт.
            # в окресности опыт поищем 'без'
            if is_word_near_exp(no_exp, desc_tokens, i):
                # пока запомним
                is_need_exp = 0
            
            # в окресности опыт поищем 'только' или 'обязателен'
            for h in need_exp:
                if is_word_near_exp(h, desc_tokens, i, 20):
                    # пока запомним
                    is_need_exp = default_exp
            
            # опыт работа - считаем что нужен
            for value in desc_tokens[i+1:i+1+2]:
                if 'работа' in value:
                    is_need_exp = default_exp
            
    return is_need_exp

# %%
from tqdm import tqdm
exp_test = ['Опыт работы с Java от 3-х лет;',
'опыт работы не менее 2-х лет',
'аналогичный опыт работы от года;',
'опыт работы в продажах электро и другого сложного оборудования обязателен.',
'тебя есть опыт преподавания от 6 месяцев;',
'Возможно оформление без опыта работы',
'Опыт работы желателен.',
'опыт работы по аналогичному направлению деятельности не менее 3-х лет;',
'Опыт программирования в 1С 8 не менее 3-х лет;',
'Имеется опыт в IT recruiting (инхаус от 1 года или агентство от 6 месяцев),',
'Возможно без опыта, но большое желание его получить',
'На вакансию рассматриваются только кандидаты с опытом работы в сфере HR',
'Опыт работы <strong>в найме персонала</strong> от 2-х лет Опыт найма сотрудников, которые работают в компании год и более;<',
'Релевантный опыт работы как преимущество;</p> <p>- Приветствуется опыт в сетевых компаниях;',
'отделом технической поддержки (опыт от 1-ого года) ',
'Имеете опыт общения с конечным потребителем софта',
'опыт работы с детьми от 1 года;',
'с художественным академическим образованием и опытом более 5 лет',
'Рассматриваем только с опытом продажи',
'Опыт работы от года;',
'Управленческий опыт работы от 0,5 года (желательно)',
'опыт работы в PR от 2-х лет;',
'Опыт работы с sql, kotlin. Опыт работы на руководящей должность от 1 года',
'Опыт работы в данной сфере обязателен, будет плюсом опыт в химчистке v Опыт работы с sql, kotlin.',
'Имеет опыт работы в интернет-маркетинге от 2-х лет']

# ttttt = df.loc[0:1000, 'description']

# ttttt - токенизировано mod=0

tokens_exp=[tokenize(a,is_lemmatization=True,mod = 0) for a in exp_test]

h = [desc_to_tokens(a,  False, False) for a in tokens_exp]
h1 = [get_experience(u) for u in h]


for i, j in zip(exp_test, h1):
    print(f'{i}\n -> {j}')
# Out:
# Опыт работы с Java от 3-х лет;
#  -> 3
# опыт работы не менее 2-х лет
#  -> 2
# аналогичный опыт работы от года;
#  -> 1
# опыт работы в продажах электро и другого сложного оборудования обязателен.
#  -> 1
# тебя есть опыт преподавания от 6 месяцев;
#  -> 0.5
# Возможно оформление без опыта работы
#  -> 1
# Опыт работы желателен.
#  -> 1
# опыт работы по аналогичному направлению деятельности не менее 3-х лет;
#  -> 3
# Опыт программирования в 1С 8 не менее 3-х лет;
#  -> 3
# Имеется опыт в IT recruiting (инхаус от 1 года или агентство от 6 месяцев),
#  -> 1.0
# Возможно без опыта, но большое желание его получить
#  -> 0
# На вакансию рассматриваются только кандидаты с опытом работы в сфере HR
#  -> 1
# Опыт работы <strong>в найме персонала</strong> от 2-х лет Опыт найма сотрудников, которые работают в компании год и более;<
#  -> 2
# Релевантный опыт работы как преимущество;</p> <p>- Приветствуется опыт в сетевых компаниях;
#  -> 1
# отделом технической поддержки (опыт от 1-ого года)
#  -> 1
# Имеете опыт общения с конечным потребителем софта
#  -> 0
# опыт работы с детьми от 1 года;
#  -> 1.0
# с художественным академическим образованием и опытом более 5 лет
#  -> 5.0
# Рассматриваем только с опытом продажи
#  -> 1
# Опыт работы от года;
#  -> 1
# Управленческий опыт работы от 0,5 года (желательно)
#  -> 0.5
# опыт работы в PR от 2-х лет;
#  -> 2
# Опыт работы с sql, kotlin. Опыт работы на руководящей должность от 1 года
#  -> 1.0
# Опыт работы в данной сфере обязателен, будет плюсом опыт в химчистке v Опыт работы с sql, kotlin.
#  -> 1
# Имеет опыт работы в интернет-маркетинге от 2-х лет
#  -> 2

# %%
test_df = X_train.loc[0:99,['id','description' ]]
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           100 non-null    int64
#  1   description  100 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 1.7+ KB

# %%
tokens_description_test=[tokenize(a,is_lemmatization=True,mod = 0) for a in tqdm(test_df.description)]
len(tokens_description_test)
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 22.73it/s]
# 100

# %%
h_exp_test = [desc_to_tokens(a, False, False) for a in tokens_description_test]
h1_exp_test = [get_experience(u) for u in h_exp_test]
len(h_exp_test),len(h1_exp_test)
# Out:
# (100, 100)

# %%
h_eng_test = [desc_to_tokens(a, True) for a in tqdm(tokens_description_test)]
h1_eng_test = [get_english(t) for t in h_eng_test]
len(h_eng_test ),len(h1_eng_test)
# Out:
# 100%|██████████| 100/100 [00:03<00:00, 25.03it/s]
# (100, 100)

# %%
test_df['exp'] = h1_exp_test
test_df['eng'] = h1_eng_test
test_df
# Out:
#        id                                        description  exp   eng
# 0   29083  <strong>Обязанности:</strong> <p>​​​​​- Прием ...  1.0  None
# 1   26052  <p><strong>CityAds Media</strong> – один из ли...  2.0     B
# 2   24055  <p>В перспективный международный Fintech старт...  2.0  None
# 3    4408  <p><strong>Обязанности:</strong></p><ul><li>Об...  0.0  None
# 4   16856  <p><strong>Компания MALL DECOR</strong> - лиде...  0.0  None
# ..    ...                                                ...  ...   ...
# 95  17956  <strong>Обязанности:</strong> <ul> <li>Разрабо...  0.0  None
# 96  16629  <p><strong>Темп в поиске харизматичных зумеров...  1.0  None
# 97  22786  <p><strong>Обязанности:</strong></p> <ul> <li>...  1.0  None
# 98  35738  <p><strong>Обязанности:</strong></p> <ul> <li>...  1.0  None
# 99  14446  <p><strong>НЕ УДАЛЕННАЯ РАБОТА!</strong></p> <...  3.0  None
#
# [100 rows x 4 columns]

# %%
if(os.path.exists("/kaggle/input/nsu-jobs/tokens_description_plus_lemment_mod0.pkl")):
    with open("/kaggle/input/nsu-jobs/tokens_description_plus_lemment_mod0.pkl", 'rb') as file:
        tokens_description_lemm_mod0 = pickle.load(file)
else:
    tokens_description_lemm_mod0=[tokenize(a,is_lemmatization=True,mod = 0) for a in tqdm(X_train.description)]
    with open('tokens_description_plus_lemment_mod0.pkl', 'wb') as file:
        pickle.dump(tokens_description_lemm_mod0, file)

# %%
# h_exp_full = [desc_to_tokens(a, False, False) for a in tokens_description_lemm_mod0]
# h1_exp_full = [get_experience(u) for u in h_exp_full]
# len(h_exp_full),len(h1_exp_full)

# %%
if(os.path.exists("/kaggle/input/nsu-jobs/tokens_description_plus_lemment_mod0_eng.pkl")):
    with open("/kaggle/input/nsu-jobs/tokens_description_plus_lemment_mod0_eng.pkl", 'rb') as file:
        h_eng_full = pickle.load(file)
else:
    h_eng_full = [desc_to_tokens(a, True) for a in tqdm(tokens_description_lemm_mod0)]
    with open('tokens_description_plus_lemment_mod0_eng.pkl', 'wb') as file:
        pickle.dump(h_eng_full, file)

# %%
# h_eng_full = [desc_to_tokens(a, True) for a in tokens_description_lemm_mod0]
# h1_eng_full = [get_english(t) for t in h_eng_full]
# len(h_eng_full ),len(h1_eng_full)

# %%
if(os.path.exists("/kaggle/input/nsu-jobs/Exp_Eng.csv")):
    Eng_Exp = pd.read_csv("/kaggle/input/nsu-jobs/Exp_Eng.csv")
    X_train=X_train.merge(Eng_Exp ,how='left', on='id')
    X_train.eng = X_train.eng.fillna('')
else:
    h_exp_full = [desc_to_tokens(a, False, False) for a in tokens_description_lemm_mod0]
    h1_exp_full = [get_experience(u) for u in h_exp_full]
    
    h1_eng_full = [get_english(t) for t in h_eng_full]
    
    X_train['exp'] = h1_exp_full
    X_train['eng'] = h1_eng_full
    X_train[['id','exp','eng']].to_csv('Exp_Eng.csv', index=False)
    X_train.eng = X_train.eng.fillna('')

# %%
# X_train['exp'] = h1_exp_full
# X_train['eng'] = h1_eng_full
# X_train[['id','exp','eng']].to_csv('Exp_Eng.csv', index=False)

# %%
# Eng_Exp = pd.read_csv("/kaggle/input/nsu-jobs/Exp_Eng.csv")
# X_train=X_train.merge(Eng_Exp ,how='left', on='id')
# X_train.eng = X_train.eng.fillna('')

# %%
X_train[['id','exp','eng']]
# Out:
#           id  exp eng
# 0      29083  1.0
# 1      26052  2.0   B
# 2      24055  2.0
# 3       4408  0.0
# 4      16856  0.0
# ...      ...  ...  ..
# 27929  16850  3.0   B
# 27930   6265  0.0
# 27931  11284  1.0
# 27932    860  0.0   B
# 27933  15795  0.0   B
#
# [27934 rows x 3 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27934 entries, 0 to 27933
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        27934 non-null  int64
#  1   name                      27934 non-null  object
#  2   has_test                  27934 non-null  bool
#  3   response_letter_required  27934 non-null  bool
#  4   salary_from               23902 non-null  float64
#  5   salary_currency           27934 non-null  object
#  6   salary_gross              27934 non-null  bool
#  7   published_at              27934 non-null  datetime64[ns, UTC]
#  8   created_at                27934 non-null  datetime64[ns, UTC]
#  9   employer_name             27934 non-null  object
#  10  description               27934 non-null  object
#  11  area_id                   27934 non-null  int64
#  12  area_name                 27934 non-null  object
#  13  salary_to                 27934 non-null  float64
#  14  timestamp                 27934 non-null  float64
#  15  start_name1               27934 non-null  object
#  16  start_name2               27934 non-null  object
#  17  start_name3               27934 non-null  object
#  18  optimum_title             27934 non-null  object
#  19  exp                       27934 non-null  float64
#  20  eng                       27934 non-null  object
# dtypes: bool(3), datetime64[ns, UTC](2), float64(4), int64(2), object(10)
# memory usage: 3.9+ MB

# %%
def is_bonus(tokens_lemm: list):
    bonus_words = ['бонус', 'премия', 'процент']
    return any(map(lambda bonus_word: bonus_word in tokens_lemm, bonus_words))

# %%
desc_is_bonus=[is_bonus(t) for t in tokens_description_lemm_mod0]
X_train['is_bonus']=desc_is_bonus
len(desc_is_bonus)
# Out:
# 27934

# %%
X_train[X_train.loc[:, X_train.dtypes == object].columns] = X_train.loc[:, X_train.dtypes == object].astype('category')

# %% [markdown]
# # Parse Salary from description

# %%
def find_salary(tokens: list):
    
    def is_real_zp(zp: int):
        
        salary_theoretical_max = 500000
        salary_theoretical_min = 10000
        
        return zp <= salary_theoretical_max and zp >= salary_theoretical_min
            
    stopwords_salary = ['партнер', 'клиент', 'партнёр', 'ученик', 'компания', 'сотрудник']    
        
    regular_digit = r'\b[1-9]\d{1,2}(к|т|тыс){1}\b'   # 50к 500к 50тыс
    
    # слово тыс слово 50 100 слово слово тыс -> слово тыс слово 50000 100000 слово слово тыс
    for position in range(len(tokens)):
        if tokens[position] == 'тыс' or tokens[position] == 'к' or tokens[position] == 'т':
            how_many = 0
            for i in range(5):
                if position-i-1 < 0:
                    break
                if tokens[position-i-1].isdigit():
                    how_many += 1
                    tokens[position-i-1] += "000"
                    if how_many == 2:
                        break
    
    tokens = list(filter(lambda t: not (t == 'тыс' or t == 'к' or t == 'т') , tokens))      
    
    # 50к -> 50000   50тыс -> 50000   50т -> 50000  000к -> ничего
    for i in range(len(tokens)):
        if re.match(regular_digit, tokens[i]):
            tokens[i] = ''.join(filter(str.isdigit, tokens[i])) + "000"
            
    # 50 000 -> 50000    50 000р -> 50000    50 000руб -> 50000   50 000к -> 50000 
    for i in range(len(tokens)):
        if re.search(r'\b000(?:р|руб|к)*\b', tokens[i]):
            if i-1 >= 0 and i-1 < len(tokens) and tokens[i-1].isdigit():
                tokens[i-1] = tokens[i-1] + "000"
                tokens[i] = ""
#             if i-2 >= 0 and i-2 < len(tokens) and tokens[i-2].isdigit():
#                 tokens[i-2] = tokens[i-2] + "000"
#                 tokens[i] = ""
#             if i-3 >= 0 and i-3 < len(tokens) and tokens[i-3].isdigit():
#                 tokens[i-3] = tokens[i-3] + "000"
#                 tokens[i] = ""

    tokens = list(filter(bool, tokens)) 

    
    # 50000р -> 50000   50000руб -> 50000 
    for i in range(len(tokens)):
        if re.search(r'\b\d{5,7}(?:р|(?:руб)?)\b', tokens[i]):
            tokens[i] = ''.join(filter(str.isdigit, tokens[i]))
            
    
    min_zp_set = set()
    max_zp_set = set()
    
    # ищем до
    for i in range(len(tokens)):
        if tokens[i].isdigit() and is_real_zp(int(tokens[i])):
            if (i-1 < len(tokens)) and tokens[i-1] == 'до' and (((i+1) == len(tokens)) or (tokens[i+1] not in stopwords_salary)):
                max_zp_set.add(int(tokens[i]))

    # ищем от или не менее
    for i in range(len(tokens)):
        if tokens[i].isdigit() and is_real_zp(int(tokens[i])):
            if (i-1 >= 0) and \
            (((i+1) == len(tokens)) or (tokens[i+1] not in stopwords_salary)) and \
            ((tokens[i-1] == 'от') or ((tokens[i-1] == 'менее') and (i-2 >= 0) and (tokens[i-2] == 'не'))):
                min_zp_set.add(int(tokens[i]))

    max_zp = None
    min_zp = None
    
    # оставляем только максимальный
    max_zp = max(max_zp_set, default=None)
    
    if len(min_zp_set) == 1:
        min_zp = min(min_zp_set, default=None)
    
    # если максимум найден, вывожу его
    if max_zp and min_zp:
        return min_zp, max_zp

    if max_zp:
        return None, max_zp
    
    digits = set()
    
    # оставляю уникальные числа, после которых нет стопслов
    for i in range(len(tokens)):
        if (tokens[i].isdigit() and is_real_zp(int(tokens[i]))) and (((i+1) == len(tokens)) or (tokens[i+1] not in stopwords_salary)):
            digits.add(int(tokens[i]))
            
    digits = list(digits)
    
    # сортировка
    digits.sort(reverse=True)
    
    # если я знаю ОТ min_zp, и если максимум больше него, то возвращаю максимум
    if min_zp:
        if len(digits) >= 1 and digits[0] > min_zp:
            max_zp = digits[0]
            return min_zp, max_zp
        else:
             # если максимума нет
            return min_zp, None
        
    # если я не знаю ОТ min_zp, то ищу два максимума
    
    # беру два самых больших
    if len(digits) >= 1:
        max_zp = digits[0]
        
    if len(digits) >= 2:
        min_zp = digits[1]  
        
    return min_zp, max_zp

# %%
test_df = X_train[['id','description', 'is_bonus', 'salary_from', 'salary_to']][1000:1200]
descs_tokens = [tokenize(d,is_lemmatization=True,mod = 1) for d in test_df['description']]
descs_tokens = [desc_to_tokens(d) for d in descs_tokens]
oklads = [find_salary(desc_tokens) for desc_tokens in descs_tokens]

# %%
test_df['oklad'] = oklads
test_df
# Out:
#          id                                        description  is_bonus  \
# 1000   1414  <p>Приглашаем стать членом нашей команды, в От...     False
# 1001  23209  <p><strong>Обязанности:</strong></p> <ul> <li>...     False
# 1002  25930  <p><strong>Обязанности:</strong></p> <p>- Выпо...     False
# 1003  20024  <p><strong>Должностные обязанности:</strong></...     False
# 1004  36433  <strong>Обязанности:</strong> <p>- -Выполнение...     False
# ...     ...                                                ...       ...
# 1195  35973  <p><strong>Digital-агентство Web Generation Gr...     False
# 1196  13590  <p>В группу хроматоргафии отделения комбинатор...     False
# 1197  20632  <strong>Обязанности:</strong> <ul> <li>Опыт ра...     False
# 1198   9459  <p>В компанию, которая специализируется на ИТ ...     False
# 1199  36140  <p>Контроль размещения товара на складе</p> <p...     False
#
#       salary_from  salary_to          oklad
# 1000      35000.0    35000.0   (None, None)
# 1001      14000.0    28000.0   (None, None)
# 1002      65000.0    70000.0   (None, None)
# 1003      45000.0    50000.0   (None, None)
# 1004          NaN    70000.0   (None, None)
# ...           ...        ...            ...
# 1195          NaN    40000.0  (30000, None)
# 1196      50850.0    70000.0   (None, None)
# 1197      60000.0   100000.0   (None, None)
# 1198      90400.0   120000.0   (None, None)
# 1199      33900.0    50000.0   (None, None)
#
# [200 rows x 6 columns]

# %%
salary_min_desc = []
salary_max_desc = []
for ind, oklad in enumerate(oklads):
    salary_from = test_df.salary_from[1000+ind]
    if(oklad[1]==salary_from):
        salary_min_desc.append(oklad[1])
        salary_max_desc.append(None)
    else:
        salary_min_desc.append(oklad[0])
        salary_max_desc.append(oklad[1])

# %%
test_df['salary_min_desc']=salary_min_desc
test_df['salary_max_desc']=salary_max_desc

# %%
test_df.loc[((test_df.salary_from>test_df.salary_max_desc) | (abs(test_df['salary_min_desc']-test_df.salary_from)>test_df.salary_from*0.1)),['salary_min_desc', 'salary_max_desc']] = None 
test_df.loc[1190:1200]
# Out:
#          id                                        description  is_bonus  \
# 1190  20055  <strong>Обязанности:</strong> <ul> <li> <p>Экс...     False
# 1191   4907  <p>Yva.ai – компания спин-офф от ABBYY Давида ...      True
# 1192  18236  <p>М13 - компания, которая занимается разработ...     False
# 1193  24621  <p><strong>Обязанности</strong>:</p> <ul> <li>...     False
# 1194    367  <p> Группа компаний «Велунд Сталь» зарекомендо...     False
# 1195  35973  <p><strong>Digital-агентство Web Generation Gr...     False
# 1196  13590  <p>В группу хроматоргафии отделения комбинатор...     False
# 1197  20632  <strong>Обязанности:</strong> <ul> <li>Опыт ра...     False
# 1198   9459  <p>В компанию, которая специализируется на ИТ ...     False
# 1199  36140  <p>Контроль размещения товара на складе</p> <p...     False
#
#       salary_from  salary_to           oklad  salary_min_desc  salary_max_desc
# 1190     85000.00   100000.0    (None, None)              NaN              NaN
# 1191     40000.00    50000.0  (10000, 40000)          40000.0              NaN
# 1192    130000.00   170000.0    (None, None)              NaN              NaN
# 1193     73836.46    84945.0    (None, None)              NaN              NaN
# 1194     96050.00   240000.0   (None, 30000)              NaN              NaN
# 1195          NaN    40000.0   (30000, None)          30000.0              NaN
# 1196     50850.00    70000.0    (None, None)              NaN              NaN
# 1197     60000.00   100000.0    (None, None)              NaN              NaN
# 1198     90400.00   120000.0    (None, None)              NaN              NaN
# 1199     33900.00    50000.0    (None, None)              NaN              NaN

# %%
import pickle
if(os.path.exists("/kaggle/input/nsu-jobs/tokens_description_plus_lemment_mod1.pkl")):
    with open("/kaggle/input/nsu-jobs/tokens_description_plus_lemment_mod1.pkl", 'rb') as file:
        tokens_description_lemm_mod1 = pickle.load(file)
else:
    tokens_description_lemm_mod1 = [tokenize(d,is_lemmatization=True,mod = 1) for d in tqdm(X_train['description'])]
    with open('tokens_description_plus_lemment_mod1.pkl', 'wb') as file:
        pickle.dump(tokens_description_lemm_mod1, file)

# %%
descs_tokens_rus = list(map(lambda desc: list(filter(lambda token: is_rus(token), desc)), tqdm(tokens_description_lemm_mod1)))
len(descs_tokens_rus)
# Out:
# 100%|██████████| 27934/27934 [00:35<00:00, 788.49it/s]
# 27934

# %%
descs_tokens_full = [desc_to_tokens(d) for d in tqdm(descs_tokens_rus)]
# Out:
# 100%|██████████| 27934/27934 [00:04<00:00, 5919.14it/s]

# %%
oklads_full = [find_salary(descs_token) for descs_token in tqdm(descs_tokens_full)]
# Out:
# 100%|██████████| 27934/27934 [00:15<00:00, 1848.68it/s]

# %%
salary_min_desc_full = []
salary_max_desc_full = []
for ind, oklad in enumerate(oklads_full):
    salary_from = X_train.salary_from[ind]
    if(oklad[1]==salary_from):
        if(oklad[0]==salary_from):
            salary_min_desc_full.append(oklad[1])
            salary_max_desc_full.append(oklad[1])
        else:
            salary_min_desc_full.append(oklad[1])
            salary_max_desc_full.append(None)
    else:
        salary_min_desc_full.append(oklad[0])
        salary_max_desc_full.append(oklad[1])

# %%
X_train['salary_min_desc']=salary_min_desc_full
X_train['salary_max_desc']=salary_max_desc_full
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27934 entries, 0 to 27933
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        27934 non-null  int64
#  1   name                      27934 non-null  category
#  2   has_test                  27934 non-null  bool
#  3   response_letter_required  27934 non-null  bool
#  4   salary_from               23902 non-null  float64
#  5   salary_currency           27934 non-null  category
#  6   salary_gross              27934 non-null  bool
#  7   published_at              27934 non-null  datetime64[ns, UTC]
#  8   created_at                27934 non-null  datetime64[ns, UTC]
#  9   employer_name             27934 non-null  category
#  10  description               27934 non-null  category
#  11  area_id                   27934 non-null  int64
#  12  area_name                 27934 non-null  category
#  13  salary_to                 27934 non-null  float64
#  14  timestamp                 27934 non-null  float64
#  15  start_name1               27934 non-null  category
#  16  start_name2               27934 non-null  category
#  17  start_name3               27934 non-null  category
#  18  optimum_title             27934 non-null  category
#  19  exp                       27934 non-null  float64
#  20  eng                       27934 non-null  category
#  21  is_bonus                  27934 non-null  bool
#  22  salary_min_desc           4915 non-null   float64
#  23  salary_max_desc           5291 non-null   float64
# dtypes: bool(4), category(10), datetime64[ns, UTC](2), float64(6), int64(2)
# memory usage: 4.9 MB

# %%
X_train.loc[((X_train.salary_from>=X_train.salary_max_desc) | (abs(X_train['salary_min_desc']-X_train.salary_from)>X_train.salary_from*0.1)),['salary_min_desc', 'salary_max_desc']] = None

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27934 entries, 0 to 27933
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        27934 non-null  int64
#  1   name                      27934 non-null  category
#  2   has_test                  27934 non-null  bool
#  3   response_letter_required  27934 non-null  bool
#  4   salary_from               23902 non-null  float64
#  5   salary_currency           27934 non-null  category
#  6   salary_gross              27934 non-null  bool
#  7   published_at              27934 non-null  datetime64[ns, UTC]
#  8   created_at                27934 non-null  datetime64[ns, UTC]
#  9   employer_name             27934 non-null  category
#  10  description               27934 non-null  category
#  11  area_id                   27934 non-null  int64
#  12  area_name                 27934 non-null  category
#  13  salary_to                 27934 non-null  float64
#  14  timestamp                 27934 non-null  float64
#  15  start_name1               27934 non-null  category
#  16  start_name2               27934 non-null  category
#  17  start_name3               27934 non-null  category
#  18  optimum_title             27934 non-null  category
#  19  exp                       27934 non-null  float64
#  20  eng                       27934 non-null  category
#  21  is_bonus                  27934 non-null  bool
#  22  salary_min_desc           3291 non-null   float64
#  23  salary_max_desc           3163 non-null   float64
# dtypes: bool(4), category(10), datetime64[ns, UTC](2), float64(6), int64(2)
# memory usage: 4.9 MB

# %% [markdown]
# # Считаем средние зп, по ним заполняем недостающие.

# %%
agg_prof1_emp = X_train.groupby(['start_name1','employer_name'],sort=False).agg(
    salary_mean_prof1_emp = ('salary_from', lambda x: np.mean(x)),
)

agg_prof2_emp = X_train.groupby(['start_name2','employer_name'],sort=False).agg(
    salary_mean_prof2_emp = ('salary_from', lambda x: np.mean(x)),
)

agg_prof3_emp = X_train.groupby(['start_name3','employer_name'],sort=False).agg(
    salary_mean_prof3_emp = ('salary_from', lambda x: np.mean(x)),
)

agg_emp_area = X_train.groupby(['employer_name','area_id'],sort=False).agg(
    salary_mean_emp_area = ('salary_from', lambda x: np.mean(x)),
)
agg_prof1_area = X_train.groupby(['start_name1','area_id'],sort=False).agg(
    salary_mean_prof1_area = ('salary_from', lambda x: np.mean(x)),
)
agg_emp = X_train.groupby(['employer_name',],sort=False).agg(
    salary_mean_emp = ('salary_from', lambda x: np.mean(x)),
)
agg_prof = X_train.groupby(['start_name1',],sort=False).agg(
    salary_mean_prof = ('salary_from', lambda x: np.mean(x)),
)
agg_area = X_train.groupby(['area_id',],sort=False).agg(
    salary_mean_area = ('salary_from', lambda x: np.mean(x)),
)
agg_all = X_train.salary_from.mean()

agg_prof12 = X_train.groupby(['start_name1','start_name2',],sort=False).agg(
    salary_mean_prof12 = ('salary_from', lambda x: np.mean(x)),
)
agg_prof13 = X_train.groupby(['start_name1','start_name3',],sort=False).agg(
    salary_mean_prof13 = ('salary_from', lambda x: np.mean(x)),
)
agg_prof23 = X_train.groupby(['start_name2','start_name3',],sort=False).agg(
    salary_mean_prof23 = ('salary_from', lambda x: np.mean(x)),
)

agg_opt_emp = X_train.groupby(['optimum_title','employer_name'],sort=False).agg(
    salary_mean_opt_emp = ('salary_from', lambda x: np.mean(x)),
)

agg_opt_area = X_train.groupby(['optimum_title','area_id'],sort=False).agg(
    salary_mean_opt_area = ('salary_from', lambda x: np.mean(x)),
)

agg_opt = X_train.groupby(['optimum_title'],sort=False).agg(
    salary_mean_opt = ('salary_from', lambda x: np.mean(x)),
)
agg_opt_prof1 = X_train.groupby(['optimum_title', 'start_name1'],sort=False).agg(
    salary_mean_opt_prof1 = ('salary_from', lambda x: np.mean(x)),
)

# %%
agg_prof12 = X_train.groupby(['start_name1','start_name2',],sort=False).agg(
    salary_mean_prof12 = ('salary_from', lambda x: np.mean(x)),
)
agg_prof13 = X_train.groupby(['start_name1','start_name3',],sort=False).agg(
    salary_mean_prof13 = ('salary_from', lambda x: np.mean(x)),
)
agg_prof23 = X_train.groupby(['start_name2','start_name3',],sort=False).agg(
    salary_mean_prof23 = ('salary_from', lambda x: np.mean(x)),
)

# %%
agg_opt_emp = X_train.groupby(['optimum_title','employer_name'],sort=False).agg(
    salary_mean_opt_emp = ('salary_from', lambda x: np.mean(x)),
)

agg_opt_area = X_train.groupby(['optimum_title','area_id'],sort=False).agg(
    salary_mean_opt_area = ('salary_from', lambda x: np.mean(x)),
)

agg_opt = X_train.groupby(['optimum_title'],sort=False).agg(
    salary_mean_opt = ('salary_from', lambda x: np.mean(x)),
)
agg_opt_prof1 = X_train.groupby(['optimum_title', 'start_name1'],sort=False).agg(
    salary_mean_opt_prof1 = ('salary_from', lambda x: np.mean(x)),
)

# %%
agg_opt_emp.reset_index(inplace=True)
agg_opt_area.reset_index(inplace=True)
agg_opt.reset_index(inplace=True)
agg_opt_prof1.reset_index(inplace=True)

agg_prof1_emp.reset_index(inplace=True)
agg_prof2_emp.reset_index(inplace=True)
agg_prof3_emp.reset_index(inplace=True)
agg_emp_area.reset_index(inplace=True)
agg_prof1_area.reset_index(inplace=True)
agg_emp.reset_index(inplace=True)
agg_prof.reset_index(inplace=True)
agg_area.reset_index(inplace=True)
agg_prof12.reset_index(inplace=True)
agg_prof13.reset_index(inplace=True)
agg_prof23.reset_index(inplace=True)

# %%
agg_opt_emp=agg_opt_emp.dropna()
agg_opt_area=agg_opt_area.dropna()
agg_opt=agg_opt.dropna()
agg_opt_prof1=agg_opt_prof1.dropna()

agg_prof1_emp = agg_prof1_emp.dropna()
agg_prof2_emp = agg_prof2_emp.dropna()
agg_prof3_emp = agg_prof3_emp.dropna()
agg_emp_area = agg_emp_area.dropna()
agg_prof1_area = agg_prof1_area.dropna()
agg_emp = agg_emp.dropna()
agg_prof = agg_prof.dropna()
agg_area = agg_area.dropna()
agg_prof12 = agg_prof12.dropna()
agg_prof13 = agg_prof13.dropna()
agg_prof23 = agg_prof23.dropna()

# %%
len(agg_prof1_emp), len(agg_emp_area), len(agg_prof1_area), len(agg_emp),len(agg_prof),len(agg_area),len(agg_prof12), len(agg_prof13), len(agg_prof23),
# Out:
# (16774, 13112, 2200, 11980, 925, 150, 5025, 6440, 6632)

# %%
X_train2 = X_train.copy()
without_salary = X_train2[X_train2.salary_from.isnull()]

# %%
without_salary = without_salary.merge(agg_opt_emp, on=['optimum_title','employer_name'], how='left')
without_salary = without_salary.merge(agg_opt_area, on=['optimum_title','area_id'], how='left')
without_salary = without_salary.merge(agg_opt, on=['optimum_title'], how='left')
without_salary = without_salary.merge(agg_opt_prof1, on=['optimum_title', 'start_name1'], how='left')

without_salary = without_salary.merge(agg_prof12, on=['start_name1','start_name2'], how='left')
without_salary = without_salary.merge(agg_prof13, on=['start_name1','start_name3'], how='left')
without_salary= without_salary.merge(agg_prof23, on=['start_name2','start_name3'], how='left')

without_salary = without_salary.merge(agg_prof1_emp, on=['start_name1','employer_name'], how='left')
without_salary = without_salary.merge(agg_prof2_emp, on=['start_name2','employer_name'], how='left')
without_salary = without_salary.merge(agg_prof3_emp, on=['start_name3','employer_name'], how='left')

without_salary = without_salary.merge(agg_emp_area, on=['employer_name','area_id'], how='left')
without_salary = without_salary.merge(agg_prof1_area, on=['start_name1','area_id'], how='left')
without_salary = without_salary.merge(agg_emp, on=['employer_name',], how='left')
without_salary = without_salary.merge(agg_prof, on=['start_name1',], how='left')
without_salary = without_salary.merge(agg_area, on=['area_id',], how='left')

# %%
without_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4032 entries, 0 to 4031
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        4032 non-null   int64
#  1   name                      4032 non-null   category
#  2   has_test                  4032 non-null   bool
#  3   response_letter_required  4032 non-null   bool
#  4   salary_from               0 non-null      float64
#  5   salary_currency           4032 non-null   category
#  6   salary_gross              4032 non-null   bool
#  7   published_at              4032 non-null   datetime64[ns, UTC]
#  8   created_at                4032 non-null   datetime64[ns, UTC]
#  9   employer_name             4032 non-null   category
#  10  description               4032 non-null   category
#  11  area_id                   4032 non-null   int64
#  12  area_name                 4032 non-null   category
#  13  salary_to                 4032 non-null   float64
#  14  timestamp                 4032 non-null   float64
#  15  start_name1               4032 non-null   category
#  16  start_name2               4032 non-null   category
#  17  start_name3               4032 non-null   category
#  18  optimum_title             4032 non-null   category
#  19  exp                       4032 non-null   float64
#  20  eng                       4032 non-null   category
#  21  is_bonus                  4032 non-null   bool
#  22  salary_min_desc           224 non-null    float64
#  23  salary_max_desc           776 non-null    float64
#  24  salary_mean_opt_emp       516 non-null    float64
#  25  salary_mean_opt_area      3611 non-null   float64
#  26  salary_mean_opt           3754 non-null   float64
#  27  salary_mean_opt_prof1     3542 non-null   float64
#  28  salary_mean_prof12        3229 non-null   float64
#  29  salary_mean_prof13        2980 non-null   float64
#  30  salary_mean_prof23        2917 non-null   float64
#  31  salary_mean_prof1_emp     554 non-null    float64
#  32  salary_mean_prof2_emp     487 non-null    float64
#  33  salary_mean_prof3_emp     764 non-null    float64
#  34  salary_mean_emp_area      1920 non-null   float64
#  35  salary_mean_prof1_area    3764 non-null   float64
#  36  salary_mean_emp           2183 non-null   float64
#  37  salary_mean_prof          3952 non-null   float64
#  38  salary_mean_area          4026 non-null   float64
# dtypes: bool(4), category(10), datetime64[ns, UTC](2), float64(21), int64(2)
# memory usage: 3.1 MB

# %%
# without_salary[['salary_from','salary_to','salary_mean_opt_emp','salary_mean_opt_prof1','salary_mean_opt_area','salary_mean_opt','salary_mean_prof12', 'salary_mean_prof13', 'salary_mean_prof23','salary_mean_prof1_emp','salary_mean_prof2_emp', 'salary_mean_prof3_emp','salary_mean_emp_area','salary_mean_prof1_area','salary_mean_emp', 'salary_mean_prof','salary_mean_area']].sample(12)

# %%
from tqdm import tqdm
median_emp=[]
median_prof = []
for i in tqdm(range(len(without_salary))):
    row_values_emp = without_salary.loc[i, ['salary_mean_prof1_emp','salary_mean_prof2_emp', 'salary_mean_prof3_emp','salary_mean_opt_emp']]
    row_values_prof = without_salary.loc[i, ['salary_mean_opt_prof1','salary_mean_opt_area', 'salary_mean_opt','salary_mean_prof12','salary_mean_prof13','salary_mean_prof23','salary_mean_emp_area','salary_mean_prof1_area','salary_mean_emp','salary_mean_prof']]
    median_emp.append(row_values_emp.mean())
    median_prof.append(row_values_prof.mean())
# Out:
# 100%|██████████| 4032/4032 [00:06<00:00, 660.93it/s]

# %%
without_salary['median_emp'] = median_emp
without_salary['median_prof'] = median_prof

# %%
without_salary.loc[(without_salary.salary_from.isnull()),'salary_from'] = without_salary.loc[(without_salary.salary_from.isnull())].median_emp
without_salary.loc[(without_salary.salary_from.isnull()),'salary_from'] = without_salary.loc[(without_salary.salary_from.isnull())].median_prof
without_salary.loc[(without_salary.salary_from.isnull()),'salary_from'] = without_salary.loc[(without_salary.salary_from.isnull())].salary_mean_area

# %%
without_salary = without_salary.rename (columns= {'salary_from': 'salary_from_without'})

# %%
without_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4032 entries, 0 to 4031
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        4032 non-null   int64
#  1   name                      4032 non-null   category
#  2   has_test                  4032 non-null   bool
#  3   response_letter_required  4032 non-null   bool
#  4   salary_from_without       4032 non-null   float64
#  5   salary_currency           4032 non-null   category
#  6   salary_gross              4032 non-null   bool
#  7   published_at              4032 non-null   datetime64[ns, UTC]
#  8   created_at                4032 non-null   datetime64[ns, UTC]
#  9   employer_name             4032 non-null   category
#  10  description               4032 non-null   category
#  11  area_id                   4032 non-null   int64
#  12  area_name                 4032 non-null   category
#  13  salary_to                 4032 non-null   float64
#  14  timestamp                 4032 non-null   float64
#  15  start_name1               4032 non-null   category
#  16  start_name2               4032 non-null   category
#  17  start_name3               4032 non-null   category
#  18  optimum_title             4032 non-null   category
#  19  exp                       4032 non-null   float64
#  20  eng                       4032 non-null   category
#  21  is_bonus                  4032 non-null   bool
#  22  salary_min_desc           224 non-null    float64
#  23  salary_max_desc           776 non-null    float64
#  24  salary_mean_opt_emp       516 non-null    float64
#  25  salary_mean_opt_area      3611 non-null   float64
#  26  salary_mean_opt           3754 non-null   float64
#  27  salary_mean_opt_prof1     3542 non-null   float64
#  28  salary_mean_prof12        3229 non-null   float64
#  29  salary_mean_prof13        2980 non-null   float64
#  30  salary_mean_prof23        2917 non-null   float64
#  31  salary_mean_prof1_emp     554 non-null    float64
#  32  salary_mean_prof2_emp     487 non-null    float64
#  33  salary_mean_prof3_emp     764 non-null    float64
#  34  salary_mean_emp_area      1920 non-null   float64
#  35  salary_mean_prof1_area    3764 non-null   float64
#  36  salary_mean_emp           2183 non-null   float64
#  37  salary_mean_prof          3952 non-null   float64
#  38  salary_mean_area          4026 non-null   float64
#  39  median_emp                1152 non-null   float64
#  40  median_prof               4021 non-null   float64
# dtypes: bool(4), category(10), datetime64[ns, UTC](2), float64(23), int64(2)
# memory usage: 3.1 MB

# %% [markdown]
# # Добавляем в трейн

# %%
X_train2 = X_train.copy()
X_train2 = X_train2.merge(agg_opt_emp, on=['optimum_title','employer_name'], how='left')
X_train2 = X_train2.merge(agg_opt_area, on=['optimum_title','area_id'], how='left')
X_train2 = X_train2.merge(agg_opt, on=['optimum_title'], how='left')
X_train2 = X_train2.merge(agg_opt_prof1, on=['optimum_title', 'start_name1'], how='left')

X_train2 = X_train2.merge(agg_prof12, on=['start_name1','start_name2'], how='left')
X_train2 = X_train2.merge(agg_prof13, on=['start_name1','start_name3'], how='left')
X_train2 = X_train2.merge(agg_prof23, on=['start_name2','start_name3'], how='left')

X_train2 = X_train2.merge(agg_prof1_emp, on=['start_name1','employer_name'], how='left')
X_train2 = X_train2.merge(agg_prof2_emp, on=['start_name2','employer_name'], how='left')
X_train2 = X_train2.merge(agg_prof3_emp, on=['start_name3','employer_name'], how='left')

X_train2 = X_train2.merge(agg_emp_area, on=['employer_name','area_id'], how='left')
X_train2 = X_train2.merge(agg_prof1_area, on=['start_name1','area_id'], how='left')
X_train2 = X_train2.merge(agg_emp, on=['employer_name',], how='left')
X_train2 = X_train2.merge(agg_prof, on=['start_name1',], how='left')
X_train2 = X_train2.merge(agg_area, on=['area_id',], how='left')

# %%
X_train2= X_train2.merge(without_salary[['id','salary_from_without']], on='id', how='left')
X_train2.loc[(X_train2.salary_from.isnull()),'salary_from'] = X_train2.salary_from_without

# %%
X_train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27934 entries, 0 to 27933
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        27934 non-null  int64
#  1   name                      27934 non-null  category
#  2   has_test                  27934 non-null  bool
#  3   response_letter_required  27934 non-null  bool
#  4   salary_from               27934 non-null  float64
#  5   salary_currency           27934 non-null  category
#  6   salary_gross              27934 non-null  bool
#  7   published_at              27934 non-null  datetime64[ns, UTC]
#  8   created_at                27934 non-null  datetime64[ns, UTC]
#  9   employer_name             27934 non-null  category
#  10  description               27934 non-null  category
#  11  area_id                   27934 non-null  int64
#  12  area_name                 27934 non-null  category
#  13  salary_to                 27934 non-null  float64
#  14  timestamp                 27934 non-null  float64
#  15  start_name1               27934 non-null  category
#  16  start_name2               27934 non-null  category
#  17  start_name3               27934 non-null  category
#  18  optimum_title             27934 non-null  category
#  19  exp                       27934 non-null  float64
#  20  eng                       27934 non-null  category
#  21  is_bonus                  27934 non-null  bool
#  22  salary_min_desc           3291 non-null   float64
#  23  salary_max_desc           3163 non-null   float64
#  24  salary_mean_opt_emp       24418 non-null  float64
#  25  salary_mean_opt_area      27513 non-null  float64
#  26  salary_mean_opt           27656 non-null  float64
#  27  salary_mean_opt_prof1     27444 non-null  float64
#  28  salary_mean_prof12        27131 non-null  float64
#  29  salary_mean_prof13        26882 non-null  float64
#  30  salary_mean_prof23        26819 non-null  float64
#  31  salary_mean_prof1_emp     24456 non-null  float64
#  32  salary_mean_prof2_emp     24389 non-null  float64
#  33  salary_mean_prof3_emp     24666 non-null  float64
#  34  salary_mean_emp_area      25822 non-null  float64
#  35  salary_mean_prof1_area    27666 non-null  float64
#  36  salary_mean_emp           26085 non-null  float64
#  37  salary_mean_prof          27854 non-null  float64
#  38  salary_mean_area          27928 non-null  float64
#  39  salary_from_without       4032 non-null   float64
# dtypes: bool(4), category(10), datetime64[ns, UTC](2), float64(22), int64(2)
# memory usage: 8.3 MB

# %%
# X_train2['difff'] = abs(X_train1.salary_from - X_train1.salary_to)
# pd.DataFrame({'from':X_train1.salary_from, 'to': X_train1.salary_to, 'difff': X_train1.difff}).sort_values(by='difff').tail(10)

# %%
X_train2[X_train2.salary_from<5000]
# Out:
#           id                                               name  has_test  \
# 466    35514                     Мастер маникюра и педикюра (м)     False
# 481    23899  QA engineer (инженер по качеству / тестировщик...     False
# 816    25278                                          Секретарь     False
# 1105   18751      Копирайтер технических текстов в мототематике     False
# 1924    3831                                         Стажер SMM     False
# ...      ...                                                ...       ...
# 27242  15034           Investment Analyst/ Investment Associate     False
# 27618  27236                Классный барбер/ стилист по волосам     False
# 27645  29592                                          Шеф-повар     False
# 27728  31616  Администратор в СПА-Студию при фитнес-клубе (г...     False
# 27887  23939                       Менеджер по оптовым продажам     False
#
#        response_letter_required  salary_from salary_currency  salary_gross  \
# 466                       False         60.0             RUR         False
# 481                       False         40.0             RUR         False
# 816                       False       1130.0             RUR          True
# 1105                      False       2000.0             RUR         False
# 1924                      False       1000.0             RUR         False
# ...                         ...          ...             ...           ...
# 27242                     False        150.0             RUR         False
# 27618                     False         56.5             RUR          True
# 27645                     False        150.0             RUR         False
# 27728                     False         50.0             RUR         False
# 27887                     False        100.0             RUR         False
#
#                    published_at                created_at  \
# 466   2020-07-12 10:27:10+00:00 2020-07-12 10:27:10+00:00
# 481   2020-04-09 01:55:19+00:00 2020-04-09 01:55:19+00:00
# 816   2020-04-27 22:10:59+00:00 2020-04-27 22:10:59+00:00
# 1105  2021-11-15 06:58:28+00:00 2021-11-15 06:58:28+00:00
# 1924  2020-08-28 10:15:03+00:00 2020-08-28 10:15:03+00:00
# ...                         ...                       ...
# 27242 2021-06-25 12:20:29+00:00 2021-06-25 12:20:29+00:00
# 27618 2020-05-13 21:26:58+00:00 2020-05-13 21:26:58+00:00
# 27645 2020-06-28 18:21:12+00:00 2020-06-28 18:21:12+00:00
# 27728 2020-08-02 14:55:53+00:00 2020-08-02 14:55:53+00:00
# 27887 2020-07-14 10:50:23+00:00 2020-07-14 10:50:23+00:00
#
#                           employer_name  \
# 466                  HEIM beauty studio
# 481                             Роадгид
# 816                            Дельта +
# 1105                          СМ-Моторс
# 1924         Романов Дмитрий Алексеевич
# ...                                 ...
# 27242               Black Lions Capital
# 27618                           Glambar
# 27645  Подъяпольская Татьяна Викторовна
# 27728                    Эстетик Фэмили
# 27887          Азизов Мехродж Тохирович
#
#                                              description  area_id  \
# 466    <p><strong>В салон красоты HEIM BEAUTY требует...        1
# 481    Автомобильные видео-регистраторы Roadgid прода...        2
# 816    <strong>Обязанности:</strong> <ul> <li>Делопро...        1
# 1105   <p><strong>Компания &quot;SM - Motors&quot;( Ф...        1
# 1924   <p>Мы рассматриваем вовлечённого человека, кот...        1
# ...                                                  ...      ...
# 27242  <p>Black Lions Capital is a company within Red...        1
# 27618  <p>Glambar -это новый проект, созданный команд...        1
# 27645  <strong>Обязанности:</strong> <ul> <li>Создани...        1
# 27728  <strong>Обязанности:</strong> <ul> <li>Презент...        1
# 27887  <p><strong>Обязанности: Продажа товара, общени...        1
#
#              area_name  salary_to     timestamp    start_name1  start_name2  \
# 466             Москва   100000.0  1.594550e+09         мастер      маникюр
# 481    Санкт-Петербург       55.0  1.586397e+09             qa     engineer
# 816             Москва    30000.0  1.588025e+09      секретарь
# 1105            Москва    80000.0  1.636960e+09     копирайтер  технический
# 1924            Москва     1500.0  1.598610e+09         стажёр          smm
# ...                ...        ...           ...            ...          ...
# 27242           Москва      250.0  1.624624e+09        analyst    associate
# 27618           Москва   120000.0  1.589405e+09       классный       барбер
# 27645           Москва      300.0  1.593368e+09            шеф        повар
# 27728           Москва       65.0  1.596380e+09  администратор          спа
# 27887           Москва      100.0  1.594724e+09       менеджер      оптовый
#
#       start_name3     optimum_title  exp eng  is_bonus  salary_min_desc  \
# 466       педикюр    мастер маникюр  0.0         False              NaN
# 481       инженер           инженер  0.0   B     False              NaN
# 816                       секретарь  0.0         False              NaN
# 1105        текст        копирайтер  0.0         False              NaN
# 1924                         стажёр  0.0         False              NaN
# ...           ...               ...  ...  ..       ...              ...
# 27242                       analyst  0.0   C     False              NaN
# 27618     стилист            барбер  1.0         False              NaN
# 27645                         повар  3.0         False              NaN
# 27728      студия     администратор  1.0         False              NaN
# 27887     продажа  менеджер продажа  0.0         False              NaN
#
#        salary_max_desc  salary_mean_opt_emp  salary_mean_opt_area  \
# 466                NaN                 60.0          50635.384615
# 481                NaN                 40.0          68485.385417
# 816                NaN               1130.0          38430.739130
# 1105               NaN               2000.0          43057.186940
# 1924               NaN               7750.0          48139.747849
# ...                ...                  ...                   ...
# 27242              NaN                150.0          96880.555556
# 27618              NaN                 56.5          50091.300000
# 27645              NaN                150.0          44050.455696
# 27728          10000.0                 50.0          45812.573150
# 27887              NaN                100.0          56000.169186
#
#        salary_mean_opt  salary_mean_opt_prof1  salary_mean_prof12  \
# 466       46014.444444           47391.764706        47391.764706
# 481       73966.940963           99460.000000        93485.000000
# 816       37333.534247           37746.000000        39298.666667
# 1105      41865.795847           42043.412675        14666.666667
# 1924      43931.649784           43859.120312        19000.000000
# ...                ...                    ...                 ...
# 27242    110352.923077           66541.666667          150.000000
# 27618     50091.300000              56.500000           56.500000
# 27645     41346.057851           75421.428571        75421.428571
# 27728     43432.176750           40255.478562        20025.000000
# 27887     54446.406415           53974.520802        58502.777778
#
#        salary_mean_prof13  salary_mean_prof23  salary_mean_prof1_emp  \
# 466          44884.444444        44884.444444                   60.0
# 481          25020.000000        25020.000000                   40.0
# 816          37935.575758        52690.940836                 1130.0
# 1105          4666.666667         2000.000000                 2000.0
# 1924         42625.769231        38900.000000                 7750.0
# ...                   ...                 ...                    ...
# 27242        66541.666667        20075.000000                  150.0
# 27618           56.500000           56.500000                   56.5
# 27645        73519.230769        67772.222222                  150.0
# 27728        25010.000000           50.000000                   50.0
# 27887        56787.450331        59818.867925                  100.0
#
#        salary_mean_prof2_emp  salary_mean_prof3_emp  salary_mean_emp_area  \
# 466                     60.0                   60.0             60.000000
# 481                     40.0                   40.0             40.000000
# 816                   1130.0                 1130.0           1130.000000
# 1105                  2000.0                 2000.0           2000.000000
# 1924                  1000.0                15500.0          31148.148148
# ...                      ...                    ...                   ...
# 27242                  150.0                  150.0            150.000000
# 27618                   56.5                   56.5          28278.250000
# 27645                  150.0                  150.0            150.000000
# 27728                   50.0                   50.0             50.000000
# 27887                  100.0                  100.0            100.000000
#
#        salary_mean_prof1_area  salary_mean_emp  salary_mean_prof  \
# 466              59413.933444        60.000000      56474.200083
# 481             130480.000000        40.000000     129254.137931
# 816              38145.870968      1130.000000      38300.821053
# 1105             43355.209456      2000.000000      42043.412675
# 1924             42471.511454     31107.142857      39535.968772
# ...                       ...              ...               ...
# 27242            59850.000000       150.000000      66541.666667
# 27618               56.500000     28278.250000         56.500000
# 27645            72975.000000       150.000000      73383.333333
# 27728            42763.253638        50.000000      40179.239459
# 27887            57559.310833       100.000000      55073.174916
#
#        salary_mean_area  salary_from_without
# 466        69104.656165                  NaN
# 481        55174.750504                  NaN
# 816        69104.656165                  NaN
# 1105       69104.656165                  NaN
# 1924       69104.656165                  NaN
# ...                 ...                  ...
# 27242      69104.656165                  NaN
# 27618      69104.656165                  NaN
# 27645      69104.656165                  NaN
# 27728      69104.656165                  NaN
# 27887      69104.656165                  NaN
#
# [100 rows x 40 columns]

# %%
# X_train2[['salary_from','salary_to','salary_mean_opt_emp','salary_mean_opt_prof1','salary_mean_opt_area','salary_mean_opt','salary_mean_prof12', 'salary_mean_prof13', 'salary_mean_prof23','salary_mean_prof1_emp','salary_mean_prof2_emp', 'salary_mean_prof3_emp','salary_mean_emp_area','salary_mean_prof1_area','salary_mean_emp', 'salary_mean_prof','salary_mean_area']].sample(12)

# %% [markdown]
# # Посмотрим крайные ЗП

# %%
X_train_low = X_train[X_train.salary_from<=5000]

# %%
X_train_norm = X_train[(X_train.salary_from>5000) & (X_train.salary_from<=300000)]

# %%
X_train_high = X_train[X_train.salary_from>5000]

# %%
len(X_train_low), len(X_train_norm), len(X_train_high)
# Out:
# (127, 23706, 23775)

# %%
tes = X_train_low[['id', 'salary_from', 'salary_to', 'salary_min_desc', 'salary_max_desc']]

# %%
tes[(~tes.salary_min_desc.isnull())]
# Out:
# Empty DataFrame
# Columns: [id, salary_from, salary_to, salary_min_desc, salary_max_desc]
# Index: []

# %%
tes[((~tes.salary_max_desc.isnull()) | (~tes.salary_min_desc.isnull()))]
# Out:
#           id  salary_from  salary_to  salary_min_desc  salary_max_desc
# 4917     906      5000.00    15000.0              NaN          15000.0
# 14068   6260        35.00       60.0              NaN         137000.0
# 20184  25928      5000.00    10000.0              NaN          10000.0
# 20805  34963      1600.00     1800.0              NaN         414000.0
# 21190   6752      2500.00     2500.0              NaN          50000.0
# 21938  34492      5000.00    10000.0              NaN          10000.0
# 21964  16727      5000.00    10000.0              NaN          10000.0
# 23017   5798        15.00       25.0              NaN          15000.0
# 23125  30979        50.85   100000.0              NaN          35000.0
# 27728  31616        50.00       65.0              NaN          10000.0

# %% [markdown]
# # Train

# %%
X_train2 = X_train2.drop(columns=['salary_from_without'])
X_train = X_train2.copy()

# %%
y_true = X_train.salary_to
X = X_train.drop(columns=["id", "description","salary_currency","salary_to", 'published_at','created_at', 'exp', 'eng', 'is_bonus'])

# %%
category_feat = X.loc[:, X.dtypes == 'category'].columns.to_list()
category_feat
# Out:
# ['name',
#  'employer_name',
#  'area_name',
#  'start_name1',
#  'start_name2',
#  'start_name3',
#  'optimum_title']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27934 entries, 0 to 27933
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name                      27934 non-null  category
#  1   has_test                  27934 non-null  bool
#  2   response_letter_required  27934 non-null  bool
#  3   salary_from               27934 non-null  float64
#  4   salary_gross              27934 non-null  bool
#  5   employer_name             27934 non-null  category
#  6   area_id                   27934 non-null  int64
#  7   area_name                 27934 non-null  category
#  8   timestamp                 27934 non-null  float64
#  9   start_name1               27934 non-null  category
#  10  start_name2               27934 non-null  category
#  11  start_name3               27934 non-null  category
#  12  optimum_title             27934 non-null  category
#  13  salary_min_desc           3291 non-null   float64
#  14  salary_max_desc           3163 non-null   float64
#  15  salary_mean_opt_emp       24418 non-null  float64
#  16  salary_mean_opt_area      27513 non-null  float64
#  17  salary_mean_opt           27656 non-null  float64
#  18  salary_mean_opt_prof1     27444 non-null  float64
#  19  salary_mean_prof12        27131 non-null  float64
#  20  salary_mean_prof13        26882 non-null  float64
#  21  salary_mean_prof23        26819 non-null  float64
#  22  salary_mean_prof1_emp     24456 non-null  float64
#  23  salary_mean_prof2_emp     24389 non-null  float64
#  24  salary_mean_prof3_emp     24666 non-null  float64
#  25  salary_mean_emp_area      25822 non-null  float64
#  26  salary_mean_prof1_area    27666 non-null  float64
#  27  salary_mean_emp           26085 non-null  float64
#  28  salary_mean_prof          27854 non-null  float64
#  29  salary_mean_area          27928 non-null  float64
# dtypes: bool(3), category(7), float64(19), int64(1)
# memory usage: 6.2 MB

# %%
X_tr, X_val, y_tr, y_val = train_test_split(X, y_true, test_size=0.2, random_state=912, shuffle=True)

# %%
from catboost import CatBoostRegressor
cat = CatBoostRegressor(cat_features=category_feat, iterations=600, learning_rate=0.1, depth=10,score_function= 'L2', random_state=912, boosting_type = 'Plain',has_time=True,max_bin=254, random_strength=1)

# %%
cat.fit(X_tr,y_tr)
# Out:
# 0:	learn: 98584.3987082	total: 72.8ms	remaining: 43.6s
# 1:	learn: 93947.2761764	total: 140ms	remaining: 41.9s
# 2:	learn: 89945.4857068	total: 208ms	remaining: 41.4s
# 3:	learn: 86313.0415324	total: 276ms	remaining: 41.2s
# 4:	learn: 83166.1458553	total: 343ms	remaining: 40.8s
# 5:	learn: 80286.6387234	total: 413ms	remaining: 40.9s
# 6:	learn: 77767.0857814	total: 483ms	remaining: 40.9s
# 7:	learn: 75625.3386193	total: 554ms	remaining: 41s
# 8:	learn: 73697.2914719	total: 624ms	remaining: 40.9s
# 9:	learn: 71887.7796061	total: 694ms	remaining: 40.9s
# 10:	learn: 70379.9834575	total: 762ms	remaining: 40.8s
# 11:	learn: 69095.2970549	total: 834ms	remaining: 40.9s
# 12:	learn: 67898.2060635	total: 911ms	remaining: 41.1s
# 13:	learn: 66702.3278160	total: 988ms	remaining: 41.4s
# 14:	learn: 65729.7316718	total: 1.09s	remaining: 42.7s
# 15:	learn: 64809.1722370	total: 1.17s	remaining: 42.8s
# 16:	learn: 63968.0981218	total: 1.24s	remaining: 42.5s
# 17:	learn: 63194.6008213	total: 1.31s	remaining: 42.4s
# 18:	learn: 62511.9328284	total: 1.38s	remaining: 42.3s
# 19:	learn: 61827.6684130	total: 1.45s	remaining: 42.1s
# 20:	learn: 61215.0928756	total: 1.52s	remaining: 42s
# 21:	learn: 60669.5588730	total: 1.59s	remaining: 41.8s
# 22:	learn: 60062.4463603	total: 1.66s	remaining: 41.7s
# 23:	learn: 59455.2134507	total: 1.74s	remaining: 41.7s
# 24:	learn: 58897.9504434	total: 1.81s	remaining: 41.7s
# 25:	learn: 58351.3892213	total: 1.89s	remaining: 41.7s
# 26:	learn: 57878.8056631	total: 1.96s	remaining: 41.5s
# 27:	learn: 57486.2679100	total: 2.02s	remaining: 41.4s
# 28:	learn: 56893.5996866	total: 2.1s	remaining: 41.4s
# 29:	learn: 56366.9135455	total: 2.18s	remaining: 41.4s
# 30:	learn: 55947.5905327	total: 2.25s	remaining: 41.4s
# 31:	learn: 55495.6374388	total: 2.32s	remaining: 41.2s
# 32:	learn: 55117.1230121	total: 2.39s	remaining: 41.1s
# 33:	learn: 54804.6546039	total: 2.46s	remaining: 40.9s
# 34:	learn: 54401.8690887	total: 2.53s	remaining: 40.8s
# 35:	learn: 54123.0875218	total: 2.59s	remaining: 40.6s
# 36:	learn: 53827.0125262	total: 2.66s	remaining: 40.4s
# 37:	learn: 53496.3185068	total: 2.73s	remaining: 40.4s
# 38:	learn: 53078.0820795	total: 2.8s	remaining: 40.3s
# 39:	learn: 52859.7706071	total: 2.87s	remaining: 40.2s
# 40:	learn: 52661.6669015	total: 2.94s	remaining: 40.1s
# 41:	learn: 52441.9578808	total: 3.02s	remaining: 40.1s
# 42:	learn: 52125.2791662	total: 3.1s	remaining: 40.2s
# 43:	learn: 51851.7356889	total: 3.18s	remaining: 40.2s
# 44:	learn: 51616.6990216	total: 3.25s	remaining: 40.1s
# 45:	learn: 51422.3068002	total: 3.32s	remaining: 40s
# 46:	learn: 51200.6288504	total: 3.39s	remaining: 39.8s
# 47:	learn: 51041.9940409	total: 3.46s	remaining: 39.8s
# 48:	learn: 50782.2639292	total: 3.53s	remaining: 39.7s
# 49:	learn: 50610.4285831	total: 3.59s	remaining: 39.5s
# 50:	learn: 50431.6538030	total: 3.66s	remaining: 39.4s
# 51:	learn: 50226.7300940	total: 3.73s	remaining: 39.3s
# 52:	learn: 49977.4875716	total: 3.8s	remaining: 39.3s
# 53:	learn: 49783.5622685	total: 3.88s	remaining: 39.3s
# 54:	learn: 49546.6631967	total: 3.96s	remaining: 39.2s
# 55:	learn: 49320.6009514	total: 4.03s	remaining: 39.2s
# 56:	learn: 49187.6221803	total: 4.11s	remaining: 39.1s
# 57:	learn: 49039.3428763	total: 4.18s	remaining: 39s
# 58:	learn: 48840.2401944	total: 4.25s	remaining: 38.9s
# 59:	learn: 48678.6310615	total: 4.32s	remaining: 38.8s
# 60:	learn: 48503.5390758	total: 4.38s	remaining: 38.7s
# 61:	learn: 48308.7978903	total: 4.46s	remaining: 38.7s
# 62:	learn: 48210.0738237	total: 4.52s	remaining: 38.5s
# 63:	learn: 48032.7344944	total: 4.59s	remaining: 38.5s
# 64:	learn: 47896.4322891	total: 4.66s	remaining: 38.4s
# 65:	learn: 47708.3010481	total: 4.74s	remaining: 38.4s
# 66:	learn: 47533.6196887	total: 4.82s	remaining: 38.3s
# 67:	learn: 47298.1616965	total: 4.9s	remaining: 38.3s
# 68:	learn: 47152.2661734	total: 4.97s	remaining: 38.3s
# 69:	learn: 47014.7030205	total: 5.04s	remaining: 38.2s
# 70:	learn: 46903.5332472	total: 5.11s	remaining: 38.1s
# 71:	learn: 46773.8415081	total: 5.18s	remaining: 38s
# 72:	learn: 46668.0113624	total: 5.26s	remaining: 38s
# 73:	learn: 46529.9433603	total: 5.33s	remaining: 37.9s
# 74:	learn: 46381.7335799	total: 5.39s	remaining: 37.7s
# 75:	learn: 46180.4874451	total: 5.46s	remaining: 37.7s
# 76:	learn: 46064.4334541	total: 5.54s	remaining: 37.6s
# 77:	learn: 45936.3704605	total: 5.61s	remaining: 37.6s
# 78:	learn: 45832.7908896	total: 5.68s	remaining: 37.5s
# 79:	learn: 45669.4209240	total: 5.77s	remaining: 37.5s
# 80:	learn: 45434.3803562	total: 5.85s	remaining: 37.5s
# 81:	learn: 45253.6907379	total: 5.92s	remaining: 37.4s
# 82:	learn: 45148.9607941	total: 6s	remaining: 37.4s
# 83:	learn: 44963.9015738	total: 6.07s	remaining: 37.3s
# 84:	learn: 44820.7831958	total: 6.16s	remaining: 37.3s
# 85:	learn: 44753.5852736	total: 6.22s	remaining: 37.2s
# 86:	learn: 44618.9075370	total: 6.29s	remaining: 37.1s
# 87:	learn: 44455.1620890	total: 6.36s	remaining: 37s
# 88:	learn: 44351.3449136	total: 6.43s	remaining: 36.9s
# 89:	learn: 44272.2705074	total: 6.5s	remaining: 36.8s
# 90:	learn: 44158.5313531	total: 6.57s	remaining: 36.7s
# 91:	learn: 44082.9088374	total: 6.64s	remaining: 36.7s
# 92:	learn: 44026.7234523	total: 6.71s	remaining: 36.6s
# 93:	learn: 43893.0317043	total: 6.78s	remaining: 36.5s
# 94:	learn: 43769.0107224	total: 6.86s	remaining: 36.5s
# 95:	learn: 43652.3435189	total: 6.93s	remaining: 36.4s
# 96:	learn: 43548.7211128	total: 7.01s	remaining: 36.4s
# 97:	learn: 43404.6762293	total: 7.09s	remaining: 36.3s
# 98:	learn: 43326.0773963	total: 7.16s	remaining: 36.2s
# 99:	learn: 43264.0417659	total: 7.23s	remaining: 36.1s
# 100:	learn: 43124.1934192	total: 7.3s	remaining: 36.1s
# 101:	learn: 42987.7410684	total: 7.38s	remaining: 36.1s
# 102:	learn: 42908.2862159	total: 7.46s	remaining: 36s
# 103:	learn: 42763.6015009	total: 7.53s	remaining: 35.9s
# 104:	learn: 42661.4948092	total: 7.6s	remaining: 35.8s
# 105:	learn: 42514.8062294	total: 7.67s	remaining: 35.8s
# 106:	learn: 42421.5108871	total: 7.75s	remaining: 35.7s
# 107:	learn: 42375.7819159	total: 7.82s	remaining: 35.6s
# 108:	learn: 42233.7289466	total: 7.9s	remaining: 35.6s
# 109:	learn: 42144.5688390	total: 7.97s	remaining: 35.5s
# 110:	learn: 42049.0887161	total: 8.04s	remaining: 35.4s
# 111:	learn: 41947.9819419	total: 8.11s	remaining: 35.3s
# 112:	learn: 41847.0565435	total: 8.18s	remaining: 35.3s
# 113:	learn: 41745.7080755	total: 8.26s	remaining: 35.2s
# 114:	learn: 41677.8974835	total: 8.32s	remaining: 35.1s
# 115:	learn: 41593.6304402	total: 8.39s	remaining: 35s
# 116:	learn: 41521.0402178	total: 8.46s	remaining: 34.9s
# 117:	learn: 41351.1029102	total: 8.55s	remaining: 34.9s
# 118:	learn: 41243.4029821	total: 8.63s	remaining: 34.9s
# 119:	learn: 41128.5593891	total: 8.71s	remaining: 34.8s
# 120:	learn: 41049.7666660	total: 8.79s	remaining: 34.8s
# 121:	learn: 40969.7899053	total: 8.87s	remaining: 34.8s
# 122:	learn: 40817.6848212	total: 8.96s	remaining: 34.7s
# 123:	learn: 40676.2295374	total: 9.04s	remaining: 34.7s
# 124:	learn: 40595.3988760	total: 9.11s	remaining: 34.6s
# 125:	learn: 40490.3743893	total: 9.19s	remaining: 34.6s
# 126:	learn: 40391.3281392	total: 9.26s	remaining: 34.5s
# 127:	learn: 40308.6056368	total: 9.35s	remaining: 34.5s
# 128:	learn: 40216.6235661	total: 9.41s	remaining: 34.4s
# 129:	learn: 40105.2838493	total: 9.49s	remaining: 34.3s
# 130:	learn: 40027.3288302	total: 9.56s	remaining: 34.2s
# 131:	learn: 39929.5065008	total: 9.64s	remaining: 34.2s
# 132:	learn: 39856.3412805	total: 9.71s	remaining: 34.1s
# 133:	learn: 39763.6199102	total: 9.79s	remaining: 34.1s
# 134:	learn: 39666.8850423	total: 9.86s	remaining: 34s
# 135:	learn: 39554.4007027	total: 9.93s	remaining: 33.9s
# 136:	learn: 39493.6051607	total: 9.99s	remaining: 33.8s
# 137:	learn: 39437.3595177	total: 10.1s	remaining: 33.7s
# 138:	learn: 39356.5726286	total: 10.1s	remaining: 33.6s
# 139:	learn: 39215.0084864	total: 10.2s	remaining: 33.6s
# 140:	learn: 39138.6816445	total: 10.3s	remaining: 33.5s
# 141:	learn: 39039.5951645	total: 10.4s	remaining: 33.4s
# 142:	learn: 38939.4480379	total: 10.4s	remaining: 33.4s
# 143:	learn: 38870.7767361	total: 10.5s	remaining: 33.3s
# 144:	learn: 38757.0212629	total: 10.6s	remaining: 33.3s
# 145:	learn: 38659.7031837	total: 10.7s	remaining: 33.2s
# 146:	learn: 38568.0323127	total: 10.7s	remaining: 33.1s
# 147:	learn: 38446.9508038	total: 10.8s	remaining: 33.1s
# 148:	learn: 38369.9431405	total: 10.9s	remaining: 33s
# 149:	learn: 38315.9465000	total: 11s	remaining: 33s
# 150:	learn: 38237.6034668	total: 11.1s	remaining: 32.9s
# 151:	learn: 38190.0526173	total: 11.1s	remaining: 32.8s
# 152:	learn: 38133.9668249	total: 11.2s	remaining: 32.8s
# 153:	learn: 38072.3984502	total: 11.3s	remaining: 32.7s
# 154:	learn: 37998.6159257	total: 11.4s	remaining: 32.6s
# 155:	learn: 37874.8889629	total: 11.4s	remaining: 32.6s
# 156:	learn: 37790.6804569	total: 11.5s	remaining: 32.5s
# 157:	learn: 37724.7689718	total: 11.6s	remaining: 32.4s
# 158:	learn: 37663.1069604	total: 11.7s	remaining: 32.4s
# 159:	learn: 37611.2808381	total: 11.7s	remaining: 32.3s
# 160:	learn: 37565.1166191	total: 11.8s	remaining: 32.2s
# 161:	learn: 37463.9656359	total: 11.9s	remaining: 32.2s
# 162:	learn: 37364.9823608	total: 12s	remaining: 32.1s
# 163:	learn: 37281.1521155	total: 12s	remaining: 32s
# 164:	learn: 37191.6125154	total: 12.1s	remaining: 32s
# 165:	learn: 37090.7137735	total: 12.2s	remaining: 31.9s
# 166:	learn: 37001.0474927	total: 12.3s	remaining: 31.8s
# 167:	learn: 36940.4015171	total: 12.4s	remaining: 31.8s
# 168:	learn: 36882.7673314	total: 12.4s	remaining: 31.7s
# 169:	learn: 36826.9244136	total: 12.5s	remaining: 31.6s
# 170:	learn: 36736.6787230	total: 12.6s	remaining: 31.6s
# 171:	learn: 36660.8275142	total: 12.7s	remaining: 31.5s
# 172:	learn: 36594.0778165	total: 12.7s	remaining: 31.4s
# 173:	learn: 36504.8427559	total: 12.8s	remaining: 31.4s
# 174:	learn: 36446.6754746	total: 12.9s	remaining: 31.3s
# 175:	learn: 36390.9901121	total: 13s	remaining: 31.2s
# 176:	learn: 36277.5472481	total: 13s	remaining: 31.2s
# 177:	learn: 36170.0475483	total: 13.1s	remaining: 31.1s
# 178:	learn: 36097.6157817	total: 13.2s	remaining: 31s
# 179:	learn: 35985.2057036	total: 13.3s	remaining: 31s
# 180:	learn: 35904.5709470	total: 13.3s	remaining: 30.9s
# 181:	learn: 35836.0249059	total: 13.4s	remaining: 30.8s
# 182:	learn: 35759.1472456	total: 13.5s	remaining: 30.7s
# 183:	learn: 35694.4206608	total: 13.6s	remaining: 30.7s
# 184:	learn: 35585.2210768	total: 13.6s	remaining: 30.6s
# 185:	learn: 35546.7463452	total: 13.7s	remaining: 30.5s
# 186:	learn: 35455.8405242	total: 13.8s	remaining: 30.4s
# 187:	learn: 35387.2671655	total: 13.9s	remaining: 30.4s
# 188:	learn: 35333.2893229	total: 13.9s	remaining: 30.3s
# 189:	learn: 35268.1408553	total: 14s	remaining: 30.2s
# 190:	learn: 35213.3201296	total: 14.1s	remaining: 30.1s
# 191:	learn: 35173.4271584	total: 14.1s	remaining: 30s
# 192:	learn: 35104.1912315	total: 14.2s	remaining: 30s
# 193:	learn: 35049.4122307	total: 14.3s	remaining: 29.9s
# 194:	learn: 34989.8413745	total: 14.4s	remaining: 29.8s
# 195:	learn: 34909.4327754	total: 14.4s	remaining: 29.7s
# 196:	learn: 34851.7741290	total: 14.5s	remaining: 29.7s
# 197:	learn: 34776.9196993	total: 14.6s	remaining: 29.6s
# 198:	learn: 34730.3263211	total: 14.6s	remaining: 29.5s
# 199:	learn: 34677.5477795	total: 14.7s	remaining: 29.4s
# 200:	learn: 34616.0382382	total: 14.8s	remaining: 29.4s
# 201:	learn: 34547.3530875	total: 14.9s	remaining: 29.3s
# 202:	learn: 34473.2513047	total: 14.9s	remaining: 29.2s
# 203:	learn: 34428.4976038	total: 15s	remaining: 29.2s
# 204:	learn: 34372.1510272	total: 15.1s	remaining: 29.1s
# 205:	learn: 34298.5159569	total: 15.2s	remaining: 29s
# 206:	learn: 34220.0899708	total: 15.2s	remaining: 28.9s
# 207:	learn: 34176.6330983	total: 15.3s	remaining: 28.8s
# 208:	learn: 34110.0675894	total: 15.4s	remaining: 28.8s
# 209:	learn: 34058.0502825	total: 15.5s	remaining: 28.7s
# 210:	learn: 33965.5969397	total: 15.5s	remaining: 28.6s
# 211:	learn: 33919.3395800	total: 15.6s	remaining: 28.6s
# 212:	learn: 33844.0628314	total: 15.7s	remaining: 28.5s
# 213:	learn: 33760.1508265	total: 15.8s	remaining: 28.4s
# 214:	learn: 33686.9516867	total: 15.9s	remaining: 28.4s
# 215:	learn: 33634.8558774	total: 15.9s	remaining: 28.3s
# 216:	learn: 33588.2755980	total: 16s	remaining: 28.3s
# 217:	learn: 33523.4131014	total: 16.1s	remaining: 28.2s
# 218:	learn: 33477.2434430	total: 16.2s	remaining: 28.1s
# 219:	learn: 33396.7647910	total: 16.2s	remaining: 28.1s
# 220:	learn: 33332.3614755	total: 16.3s	remaining: 28s
# 221:	learn: 33277.1282995	total: 16.4s	remaining: 27.9s
# 222:	learn: 33229.5056624	total: 16.5s	remaining: 27.8s
# 223:	learn: 33168.7092908	total: 16.5s	remaining: 27.8s
# 224:	learn: 33136.2022962	total: 16.6s	remaining: 27.7s
# 225:	learn: 33091.0494108	total: 16.7s	remaining: 27.6s
# 226:	learn: 33050.7028820	total: 16.8s	remaining: 27.5s
# 227:	learn: 33010.1949528	total: 16.8s	remaining: 27.5s
# 228:	learn: 32945.5235907	total: 16.9s	remaining: 27.4s
# 229:	learn: 32906.9030495	total: 17s	remaining: 27.4s
# 230:	learn: 32853.7136421	total: 17.1s	remaining: 27.4s
# 231:	learn: 32785.2843302	total: 17.2s	remaining: 27.3s
# 232:	learn: 32728.9567935	total: 17.3s	remaining: 27.3s
# 233:	learn: 32663.3391624	total: 17.4s	remaining: 27.3s
# 234:	learn: 32615.7067667	total: 17.6s	remaining: 27.3s
# 235:	learn: 32555.4267644	total: 17.6s	remaining: 27.2s
# 236:	learn: 32508.7011126	total: 17.8s	remaining: 27.2s
# 237:	learn: 32445.5343942	total: 17.9s	remaining: 27.2s
# 238:	learn: 32403.8218222	total: 18s	remaining: 27.1s
# 239:	learn: 32336.2011472	total: 18.1s	remaining: 27.1s
# 240:	learn: 32298.3775189	total: 18.1s	remaining: 27s
# 241:	learn: 32256.4586728	total: 18.2s	remaining: 27s
# 242:	learn: 32217.2566571	total: 18.3s	remaining: 26.9s
# 243:	learn: 32191.8899201	total: 18.4s	remaining: 26.8s
# 244:	learn: 32105.7785481	total: 18.4s	remaining: 26.7s
# 245:	learn: 32043.1430661	total: 18.5s	remaining: 26.6s
# 246:	learn: 31998.7107471	total: 18.6s	remaining: 26.6s
# 247:	learn: 31943.9010027	total: 18.6s	remaining: 26.5s
# 248:	learn: 31882.1899644	total: 18.7s	remaining: 26.4s
# 249:	learn: 31792.7153377	total: 18.8s	remaining: 26.3s
# 250:	learn: 31740.9996869	total: 18.9s	remaining: 26.3s
# 251:	learn: 31698.2265693	total: 19s	remaining: 26.2s
# 252:	learn: 31645.3346163	total: 19s	remaining: 26.1s
# 253:	learn: 31585.6502152	total: 19.1s	remaining: 26s
# 254:	learn: 31514.8818187	total: 19.2s	remaining: 26s
# 255:	learn: 31455.1952294	total: 19.3s	remaining: 25.9s
# 256:	learn: 31414.7437438	total: 19.3s	remaining: 25.8s
# 257:	learn: 31358.5114732	total: 19.4s	remaining: 25.7s
# 258:	learn: 31315.2294680	total: 19.5s	remaining: 25.6s
# 259:	learn: 31266.9959009	total: 19.6s	remaining: 25.6s
# 260:	learn: 31239.6150067	total: 19.6s	remaining: 25.5s
# 261:	learn: 31204.7093939	total: 19.7s	remaining: 25.4s
# 262:	learn: 31171.8265956	total: 19.8s	remaining: 25.3s
# 263:	learn: 31138.2062641	total: 19.8s	remaining: 25.3s
# 264:	learn: 31078.0905321	total: 19.9s	remaining: 25.2s
# 265:	learn: 31020.4092232	total: 20s	remaining: 25.1s
# 266:	learn: 30973.9480571	total: 20.1s	remaining: 25s
# 267:	learn: 30886.4032924	total: 20.2s	remaining: 25s
# 268:	learn: 30822.4590319	total: 20.2s	remaining: 24.9s
# 269:	learn: 30791.7438109	total: 20.3s	remaining: 24.8s
# 270:	learn: 30733.3412513	total: 20.4s	remaining: 24.7s
# 271:	learn: 30690.2122240	total: 20.5s	remaining: 24.7s
# 272:	learn: 30653.4811382	total: 20.5s	remaining: 24.6s
# 273:	learn: 30598.6803784	total: 20.6s	remaining: 24.5s
# 274:	learn: 30515.9959939	total: 20.7s	remaining: 24.5s
# 275:	learn: 30457.1921332	total: 20.8s	remaining: 24.4s
# 276:	learn: 30384.2176009	total: 20.9s	remaining: 24.3s
# 277:	learn: 30333.4614301	total: 20.9s	remaining: 24.2s
# 278:	learn: 30276.8705409	total: 21s	remaining: 24.2s
# 279:	learn: 30227.1833814	total: 21.1s	remaining: 24.1s
# 280:	learn: 30179.9408011	total: 21.2s	remaining: 24s
# 281:	learn: 30121.3655776	total: 21.3s	remaining: 24s
# 282:	learn: 30077.9182291	total: 21.3s	remaining: 23.9s
# 283:	learn: 30057.7289278	total: 21.4s	remaining: 23.8s
# 284:	learn: 30028.1493059	total: 21.5s	remaining: 23.8s
# 285:	learn: 29979.8296460	total: 21.6s	remaining: 23.7s
# 286:	learn: 29916.7178050	total: 21.6s	remaining: 23.6s
# 287:	learn: 29872.7134037	total: 21.7s	remaining: 23.5s
# 288:	learn: 29806.3666223	total: 21.8s	remaining: 23.5s
# 289:	learn: 29772.8357320	total: 21.9s	remaining: 23.4s
# 290:	learn: 29730.5618027	total: 22s	remaining: 23.3s
# 291:	learn: 29683.2681446	total: 22s	remaining: 23.2s
# 292:	learn: 29632.7233468	total: 22.1s	remaining: 23.2s
# 293:	learn: 29577.7659688	total: 22.2s	remaining: 23.1s
# 294:	learn: 29525.1026512	total: 22.3s	remaining: 23s
# 295:	learn: 29464.5151249	total: 22.3s	remaining: 22.9s
# 296:	learn: 29426.6470184	total: 22.4s	remaining: 22.9s
# 297:	learn: 29353.0052615	total: 22.5s	remaining: 22.8s
# 298:	learn: 29308.2946872	total: 22.6s	remaining: 22.7s
# 299:	learn: 29287.3258731	total: 22.6s	remaining: 22.6s
# 300:	learn: 29262.1511958	total: 22.7s	remaining: 22.6s
# 301:	learn: 29221.3024993	total: 22.8s	remaining: 22.5s
# 302:	learn: 29182.7515209	total: 22.9s	remaining: 22.4s
# 303:	learn: 29150.1930019	total: 22.9s	remaining: 22.3s
# 304:	learn: 29123.5595532	total: 23s	remaining: 22.3s
# 305:	learn: 29076.0333393	total: 23.1s	remaining: 22.2s
# 306:	learn: 29020.8939462	total: 23.2s	remaining: 22.1s
# 307:	learn: 28980.2185892	total: 23.3s	remaining: 22.1s
# 308:	learn: 28933.6540808	total: 23.3s	remaining: 22s
# 309:	learn: 28907.1116763	total: 23.4s	remaining: 21.9s
# 310:	learn: 28871.8123398	total: 23.5s	remaining: 21.8s
# 311:	learn: 28830.9087631	total: 23.6s	remaining: 21.8s
# 312:	learn: 28790.3578493	total: 23.7s	remaining: 21.7s
# 313:	learn: 28735.4657292	total: 23.7s	remaining: 21.6s
# 314:	learn: 28689.8729106	total: 23.8s	remaining: 21.5s
# 315:	learn: 28627.9358011	total: 23.9s	remaining: 21.5s
# 316:	learn: 28601.8394540	total: 24s	remaining: 21.4s
# 317:	learn: 28545.3523281	total: 24.1s	remaining: 21.3s
# 318:	learn: 28505.3554423	total: 24.1s	remaining: 21.3s
# 319:	learn: 28454.1911411	total: 24.2s	remaining: 21.2s
# 320:	learn: 28405.4831604	total: 24.3s	remaining: 21.1s
# 321:	learn: 28365.0314496	total: 24.4s	remaining: 21s
# 322:	learn: 28327.6499016	total: 24.5s	remaining: 21s
# 323:	learn: 28284.6902776	total: 24.5s	remaining: 20.9s
# 324:	learn: 28230.9000048	total: 24.6s	remaining: 20.8s
# 325:	learn: 28208.8134650	total: 24.7s	remaining: 20.7s
# 326:	learn: 28176.8310487	total: 24.8s	remaining: 20.7s
# 327:	learn: 28136.7361936	total: 24.8s	remaining: 20.6s
# 328:	learn: 28082.5237372	total: 24.9s	remaining: 20.5s
# 329:	learn: 28053.1187285	total: 25s	remaining: 20.5s
# 330:	learn: 27987.5714613	total: 25.1s	remaining: 20.4s
# 331:	learn: 27948.6999803	total: 25.2s	remaining: 20.3s
# 332:	learn: 27919.4869282	total: 25.2s	remaining: 20.2s
# 333:	learn: 27873.3266829	total: 25.3s	remaining: 20.2s
# 334:	learn: 27842.0946522	total: 25.4s	remaining: 20.1s
# 335:	learn: 27778.0950813	total: 25.5s	remaining: 20s
# 336:	learn: 27750.4372680	total: 25.6s	remaining: 19.9s
# 337:	learn: 27691.2485768	total: 25.6s	remaining: 19.9s
# 338:	learn: 27648.3305555	total: 25.7s	remaining: 19.8s
# 339:	learn: 27609.4337876	total: 25.8s	remaining: 19.7s
# 340:	learn: 27544.5855409	total: 25.9s	remaining: 19.7s
# 341:	learn: 27489.4216570	total: 26s	remaining: 19.6s
# 342:	learn: 27438.3357980	total: 26s	remaining: 19.5s
# 343:	learn: 27385.8426633	total: 26.1s	remaining: 19.4s
# 344:	learn: 27334.7033857	total: 26.2s	remaining: 19.4s
# 345:	learn: 27287.2435591	total: 26.3s	remaining: 19.3s
# 346:	learn: 27246.8619124	total: 26.4s	remaining: 19.2s
# 347:	learn: 27207.3870875	total: 26.5s	remaining: 19.2s
# 348:	learn: 27175.1545684	total: 26.5s	remaining: 19.1s
# 349:	learn: 27147.9949253	total: 26.6s	remaining: 19s
# 350:	learn: 27100.5222635	total: 26.7s	remaining: 18.9s
# 351:	learn: 27063.0417562	total: 26.8s	remaining: 18.9s
# 352:	learn: 27022.0712607	total: 26.8s	remaining: 18.8s
# 353:	learn: 26979.7538064	total: 26.9s	remaining: 18.7s
# 354:	learn: 26938.5501980	total: 27s	remaining: 18.6s
# 355:	learn: 26912.3724852	total: 27.1s	remaining: 18.6s
# 356:	learn: 26879.3092840	total: 27.2s	remaining: 18.5s
# 357:	learn: 26855.2101273	total: 27.2s	remaining: 18.4s
# 358:	learn: 26794.2892326	total: 27.3s	remaining: 18.3s
# 359:	learn: 26738.5191723	total: 27.4s	remaining: 18.3s
# 360:	learn: 26721.7936729	total: 27.5s	remaining: 18.2s
# 361:	learn: 26696.0867159	total: 27.5s	remaining: 18.1s
# 362:	learn: 26671.5727542	total: 27.6s	remaining: 18s
# 363:	learn: 26648.6506553	total: 27.7s	remaining: 18s
# 364:	learn: 26613.0933256	total: 27.8s	remaining: 17.9s
# 365:	learn: 26569.3857317	total: 27.9s	remaining: 17.8s
# 366:	learn: 26528.9222038	total: 27.9s	remaining: 17.7s
# 367:	learn: 26497.7877183	total: 28s	remaining: 17.7s
# 368:	learn: 26433.2391620	total: 28.1s	remaining: 17.6s
# 369:	learn: 26380.7686911	total: 28.2s	remaining: 17.5s
# 370:	learn: 26330.7065333	total: 28.2s	remaining: 17.4s
# 371:	learn: 26302.7100106	total: 28.3s	remaining: 17.4s
# 372:	learn: 26277.9666214	total: 28.4s	remaining: 17.3s
# 373:	learn: 26245.0935773	total: 28.5s	remaining: 17.2s
# 374:	learn: 26214.9248224	total: 28.5s	remaining: 17.1s
# 375:	learn: 26184.7671915	total: 28.6s	remaining: 17s
# 376:	learn: 26163.4372115	total: 28.7s	remaining: 17s
# 377:	learn: 26123.0011397	total: 28.8s	remaining: 16.9s
# 378:	learn: 26081.7431442	total: 28.9s	remaining: 16.8s
# 379:	learn: 26050.9786973	total: 28.9s	remaining: 16.7s
# 380:	learn: 26026.8325800	total: 29s	remaining: 16.7s
# 381:	learn: 25994.7849164	total: 29.1s	remaining: 16.6s
# 382:	learn: 25964.2239198	total: 29.1s	remaining: 16.5s
# 383:	learn: 25922.9588859	total: 29.2s	remaining: 16.4s
# 384:	learn: 25889.0836002	total: 29.3s	remaining: 16.4s
# 385:	learn: 25862.0716087	total: 29.4s	remaining: 16.3s
# 386:	learn: 25791.1814917	total: 29.5s	remaining: 16.2s
# 387:	learn: 25763.6600772	total: 29.5s	remaining: 16.1s
# 388:	learn: 25726.8067802	total: 29.6s	remaining: 16.1s
# 389:	learn: 25698.6763654	total: 29.7s	remaining: 16s
# 390:	learn: 25673.4768713	total: 29.8s	remaining: 15.9s
# 391:	learn: 25638.2272961	total: 29.8s	remaining: 15.8s
# 392:	learn: 25615.9685799	total: 29.9s	remaining: 15.8s
# 393:	learn: 25583.9118035	total: 30s	remaining: 15.7s
# 394:	learn: 25546.3103714	total: 30.1s	remaining: 15.6s
# 395:	learn: 25515.7969156	total: 30.1s	remaining: 15.5s
# 396:	learn: 25489.2979019	total: 30.2s	remaining: 15.5s
# 397:	learn: 25450.4802929	total: 30.3s	remaining: 15.4s
# 398:	learn: 25415.5353766	total: 30.4s	remaining: 15.3s
# 399:	learn: 25385.1023851	total: 30.4s	remaining: 15.2s
# 400:	learn: 25370.4158290	total: 30.5s	remaining: 15.1s
# 401:	learn: 25357.8870949	total: 30.6s	remaining: 15.1s
# 402:	learn: 25329.7630153	total: 30.7s	remaining: 15s
# 403:	learn: 25297.5866391	total: 30.7s	remaining: 14.9s
# 404:	learn: 25258.3748104	total: 30.8s	remaining: 14.8s
# 405:	learn: 25236.0639756	total: 30.9s	remaining: 14.8s
# 406:	learn: 25211.1914405	total: 31s	remaining: 14.7s
# 407:	learn: 25195.7517909	total: 31.1s	remaining: 14.6s
# 408:	learn: 25139.6459305	total: 31.1s	remaining: 14.5s
# 409:	learn: 25119.5747997	total: 31.2s	remaining: 14.5s
# 410:	learn: 25073.7397803	total: 31.3s	remaining: 14.4s
# 411:	learn: 25041.4539460	total: 31.4s	remaining: 14.3s
# 412:	learn: 25005.6268713	total: 31.4s	remaining: 14.2s
# 413:	learn: 24979.8011195	total: 31.5s	remaining: 14.2s
# 414:	learn: 24936.1426572	total: 31.6s	remaining: 14.1s
# 415:	learn: 24903.9689261	total: 31.7s	remaining: 14s
# 416:	learn: 24876.7469640	total: 31.8s	remaining: 13.9s
# 417:	learn: 24831.9558366	total: 31.8s	remaining: 13.9s
# 418:	learn: 24810.7091030	total: 31.9s	remaining: 13.8s
# 419:	learn: 24789.6269366	total: 32s	remaining: 13.7s
# 420:	learn: 24756.6647781	total: 32.1s	remaining: 13.6s
# 421:	learn: 24719.7115189	total: 32.1s	remaining: 13.6s
# 422:	learn: 24699.1540258	total: 32.2s	remaining: 13.5s
# 423:	learn: 24667.7008825	total: 32.3s	remaining: 13.4s
# 424:	learn: 24630.0032517	total: 32.4s	remaining: 13.3s
# 425:	learn: 24590.0169391	total: 32.5s	remaining: 13.3s
# 426:	learn: 24564.2217418	total: 32.5s	remaining: 13.2s
# 427:	learn: 24535.8269946	total: 32.6s	remaining: 13.1s
# 428:	learn: 24503.8776297	total: 32.7s	remaining: 13s
# 429:	learn: 24478.4288101	total: 32.8s	remaining: 12.9s
# 430:	learn: 24433.8366692	total: 32.8s	remaining: 12.9s
# 431:	learn: 24399.8389436	total: 32.9s	remaining: 12.8s
# 432:	learn: 24354.7820086	total: 33s	remaining: 12.7s
# 433:	learn: 24328.0721741	total: 33.1s	remaining: 12.7s
# 434:	learn: 24284.8357726	total: 33.2s	remaining: 12.6s
# 435:	learn: 24257.7356952	total: 33.2s	remaining: 12.5s
# 436:	learn: 24217.2875552	total: 33.3s	remaining: 12.4s
# 437:	learn: 24189.9441571	total: 33.4s	remaining: 12.3s
# 438:	learn: 24155.5756322	total: 33.5s	remaining: 12.3s
# 439:	learn: 24138.9261261	total: 33.5s	remaining: 12.2s
# 440:	learn: 24122.9461322	total: 33.6s	remaining: 12.1s
# 441:	learn: 24069.7098955	total: 33.7s	remaining: 12s
# 442:	learn: 24036.3374050	total: 33.8s	remaining: 12s
# 443:	learn: 23995.2738608	total: 33.9s	remaining: 11.9s
# 444:	learn: 23969.2109423	total: 33.9s	remaining: 11.8s
# 445:	learn: 23945.3182530	total: 34s	remaining: 11.7s
# 446:	learn: 23923.8177097	total: 34.1s	remaining: 11.7s
# 447:	learn: 23885.7571063	total: 34.2s	remaining: 11.6s
# 448:	learn: 23860.8500347	total: 34.3s	remaining: 11.5s
# 449:	learn: 23807.4941880	total: 34.4s	remaining: 11.4s
# 450:	learn: 23781.1822236	total: 34.4s	remaining: 11.4s
# 451:	learn: 23743.3827042	total: 34.5s	remaining: 11.3s
# 452:	learn: 23713.6837095	total: 34.6s	remaining: 11.2s
# 453:	learn: 23689.6101911	total: 34.6s	remaining: 11.1s
# 454:	learn: 23667.4765743	total: 34.7s	remaining: 11.1s
# 455:	learn: 23635.0602884	total: 34.8s	remaining: 11s
# 456:	learn: 23599.3354689	total: 34.9s	remaining: 10.9s
# 457:	learn: 23577.7320935	total: 35s	remaining: 10.8s
# 458:	learn: 23564.6166233	total: 35s	remaining: 10.8s
# 459:	learn: 23529.7226387	total: 35.1s	remaining: 10.7s
# 460:	learn: 23503.0730296	total: 35.2s	remaining: 10.6s
# 461:	learn: 23476.1685818	total: 35.3s	remaining: 10.5s
# 462:	learn: 23438.6605132	total: 35.4s	remaining: 10.5s
# 463:	learn: 23406.3332127	total: 35.4s	remaining: 10.4s
# 464:	learn: 23380.7084755	total: 35.5s	remaining: 10.3s
# 465:	learn: 23347.4469722	total: 35.6s	remaining: 10.2s
# 466:	learn: 23310.6407576	total: 35.7s	remaining: 10.2s
# 467:	learn: 23296.9773928	total: 35.8s	remaining: 10.1s
# 468:	learn: 23262.3441531	total: 35.8s	remaining: 10s
# 469:	learn: 23236.6058647	total: 35.9s	remaining: 9.94s
# 470:	learn: 23203.3980754	total: 36s	remaining: 9.86s
# 471:	learn: 23175.6649811	total: 36.1s	remaining: 9.79s
# 472:	learn: 23132.8060833	total: 36.2s	remaining: 9.72s
# 473:	learn: 23105.2052645	total: 36.3s	remaining: 9.64s
# 474:	learn: 23087.0924327	total: 36.3s	remaining: 9.56s
# 475:	learn: 23057.0616617	total: 36.4s	remaining: 9.49s
# 476:	learn: 23022.2105093	total: 36.5s	remaining: 9.41s
# 477:	learn: 22984.1934215	total: 36.6s	remaining: 9.34s
# 478:	learn: 22955.3952753	total: 36.7s	remaining: 9.26s
# 479:	learn: 22918.0718716	total: 36.7s	remaining: 9.19s
# 480:	learn: 22887.3486398	total: 36.8s	remaining: 9.11s
# 481:	learn: 22861.8948873	total: 36.9s	remaining: 9.04s
# 482:	learn: 22829.4626277	total: 37s	remaining: 8.96s
# 483:	learn: 22798.0849574	total: 37.1s	remaining: 8.89s
# 484:	learn: 22769.1265290	total: 37.2s	remaining: 8.81s
# 485:	learn: 22741.2129182	total: 37.3s	remaining: 8.74s
# 486:	learn: 22712.6346228	total: 37.3s	remaining: 8.66s
# 487:	learn: 22693.0284760	total: 37.4s	remaining: 8.59s
# 488:	learn: 22656.0288678	total: 37.5s	remaining: 8.51s
# 489:	learn: 22633.3901054	total: 37.6s	remaining: 8.43s
# 490:	learn: 22612.2963947	total: 37.7s	remaining: 8.36s
# 491:	learn: 22569.4406706	total: 37.7s	remaining: 8.28s
# 492:	learn: 22534.2415006	total: 37.8s	remaining: 8.21s
# 493:	learn: 22509.2836032	total: 37.9s	remaining: 8.13s
# 494:	learn: 22483.2549635	total: 38s	remaining: 8.05s
# 495:	learn: 22466.6476345	total: 38s	remaining: 7.98s
# 496:	learn: 22446.1867084	total: 38.1s	remaining: 7.9s
# 497:	learn: 22403.9277282	total: 38.2s	remaining: 7.83s
# 498:	learn: 22384.3354043	total: 38.3s	remaining: 7.75s
# 499:	learn: 22362.9438115	total: 38.4s	remaining: 7.67s
# 500:	learn: 22328.7084676	total: 38.4s	remaining: 7.6s
# 501:	learn: 22292.4334346	total: 38.5s	remaining: 7.52s
# 502:	learn: 22264.6685742	total: 38.6s	remaining: 7.44s
# 503:	learn: 22239.8380049	total: 38.7s	remaining: 7.37s
# 504:	learn: 22214.4891212	total: 38.8s	remaining: 7.29s
# 505:	learn: 22196.4427525	total: 38.8s	remaining: 7.21s
# 506:	learn: 22182.0710855	total: 38.9s	remaining: 7.13s
# 507:	learn: 22145.3807262	total: 39s	remaining: 7.06s
# 508:	learn: 22127.8789302	total: 39.1s	remaining: 6.98s
# 509:	learn: 22108.3685393	total: 39.1s	remaining: 6.9s
# 510:	learn: 22092.0463825	total: 39.2s	remaining: 6.83s
# 511:	learn: 22066.4585253	total: 39.3s	remaining: 6.75s
# 512:	learn: 22035.7274446	total: 39.4s	remaining: 6.67s
# 513:	learn: 22005.5533314	total: 39.4s	remaining: 6.59s
# 514:	learn: 21973.9908636	total: 39.5s	remaining: 6.52s
# 515:	learn: 21943.8751902	total: 39.6s	remaining: 6.45s
# 516:	learn: 21920.8209697	total: 39.7s	remaining: 6.37s
# 517:	learn: 21886.0400101	total: 39.8s	remaining: 6.29s
# 518:	learn: 21861.2206475	total: 39.8s	remaining: 6.22s
# 519:	learn: 21840.8108416	total: 39.9s	remaining: 6.14s
# 520:	learn: 21818.9238366	total: 40s	remaining: 6.06s
# 521:	learn: 21790.1125454	total: 40.1s	remaining: 5.99s
# 522:	learn: 21759.0927815	total: 40.2s	remaining: 5.91s
# 523:	learn: 21737.9429885	total: 40.2s	remaining: 5.83s
# 524:	learn: 21717.1063673	total: 40.3s	remaining: 5.76s
# 525:	learn: 21686.0245601	total: 40.4s	remaining: 5.68s
# 526:	learn: 21659.0693509	total: 40.5s	remaining: 5.61s
# 527:	learn: 21637.1741063	total: 40.5s	remaining: 5.53s
# 528:	learn: 21610.1158042	total: 40.6s	remaining: 5.45s
# 529:	learn: 21579.8358778	total: 40.7s	remaining: 5.38s
# 530:	learn: 21558.6666678	total: 40.8s	remaining: 5.3s
# 531:	learn: 21541.2473488	total: 40.9s	remaining: 5.23s
# 532:	learn: 21527.6772477	total: 41s	remaining: 5.15s
# 533:	learn: 21511.0850391	total: 41.1s	remaining: 5.08s
# 534:	learn: 21483.5087080	total: 41.1s	remaining: 5s
# 535:	learn: 21461.2040819	total: 41.2s	remaining: 4.92s
# 536:	learn: 21436.7028117	total: 41.3s	remaining: 4.84s
# 537:	learn: 21407.4312284	total: 41.4s	remaining: 4.77s
# 538:	learn: 21398.4349939	total: 41.4s	remaining: 4.69s
# 539:	learn: 21384.0491482	total: 41.5s	remaining: 4.61s
# 540:	learn: 21357.1304091	total: 41.6s	remaining: 4.54s
# 541:	learn: 21339.3532915	total: 41.7s	remaining: 4.46s
# 542:	learn: 21325.8632054	total: 41.7s	remaining: 4.38s
# 543:	learn: 21286.0716299	total: 41.8s	remaining: 4.31s
# 544:	learn: 21262.1615941	total: 41.9s	remaining: 4.23s
# 545:	learn: 21239.0083036	total: 42s	remaining: 4.15s
# 546:	learn: 21218.0608186	total: 42.1s	remaining: 4.08s
# 547:	learn: 21194.4687602	total: 42.1s	remaining: 4s
# 548:	learn: 21170.5888415	total: 42.2s	remaining: 3.92s
# 549:	learn: 21158.9409057	total: 42.3s	remaining: 3.84s
# 550:	learn: 21125.4165375	total: 42.4s	remaining: 3.77s
# 551:	learn: 21111.5542238	total: 42.4s	remaining: 3.69s
# 552:	learn: 21090.1734264	total: 42.5s	remaining: 3.61s
# 553:	learn: 21066.5274308	total: 42.6s	remaining: 3.54s
# 554:	learn: 21042.2274652	total: 42.7s	remaining: 3.46s
# 555:	learn: 21015.1018383	total: 42.8s	remaining: 3.38s
# 556:	learn: 20996.2115457	total: 42.8s	remaining: 3.31s
# 557:	learn: 20974.1665262	total: 42.9s	remaining: 3.23s
# 558:	learn: 20965.7883655	total: 43s	remaining: 3.15s
# 559:	learn: 20949.3521051	total: 43s	remaining: 3.07s
# 560:	learn: 20927.8915544	total: 43.1s	remaining: 3s
# 561:	learn: 20902.7310816	total: 43.2s	remaining: 2.92s
# 562:	learn: 20880.1498109	total: 43.3s	remaining: 2.84s
# 563:	learn: 20853.5671400	total: 43.4s	remaining: 2.77s
# 564:	learn: 20832.7373835	total: 43.4s	remaining: 2.69s
# 565:	learn: 20812.3762740	total: 43.5s	remaining: 2.61s
# 566:	learn: 20792.2615330	total: 43.6s	remaining: 2.54s
# 567:	learn: 20777.7165975	total: 43.7s	remaining: 2.46s
# 568:	learn: 20748.7338502	total: 43.7s	remaining: 2.38s
# 569:	learn: 20722.3416620	total: 43.8s	remaining: 2.31s
# 570:	learn: 20696.8850543	total: 43.9s	remaining: 2.23s
# 571:	learn: 20671.4935883	total: 44s	remaining: 2.15s
# 572:	learn: 20652.8312160	total: 44s	remaining: 2.08s
# 573:	learn: 20626.1235286	total: 44.1s	remaining: 2s
# 574:	learn: 20612.4841659	total: 44.2s	remaining: 1.92s
# 575:	learn: 20598.0947225	total: 44.3s	remaining: 1.84s
# 576:	learn: 20573.6872173	total: 44.3s	remaining: 1.77s
# 577:	learn: 20543.2413873	total: 44.4s	remaining: 1.69s
# 578:	learn: 20529.6519890	total: 44.5s	remaining: 1.61s
# 579:	learn: 20500.8895715	total: 44.6s	remaining: 1.54s
# 580:	learn: 20471.3885255	total: 44.7s	remaining: 1.46s
# 581:	learn: 20447.2069628	total: 44.7s	remaining: 1.38s
# 582:	learn: 20427.5810279	total: 44.8s	remaining: 1.31s
# 583:	learn: 20398.1264767	total: 44.9s	remaining: 1.23s
# 584:	learn: 20382.7594958	total: 45s	remaining: 1.15s
# 585:	learn: 20365.9319301	total: 45.1s	remaining: 1.08s
# 586:	learn: 20344.6194730	total: 45.1s	remaining: 999ms
# 587:	learn: 20332.1189637	total: 45.2s	remaining: 922ms
# 588:	learn: 20313.3955200	total: 45.3s	remaining: 845ms
# 589:	learn: 20283.7742769	total: 45.3s	remaining: 769ms
# 590:	learn: 20264.4699247	total: 45.4s	remaining: 692ms
# 591:	learn: 20235.7158796	total: 45.5s	remaining: 615ms
# 592:	learn: 20225.3323421	total: 45.6s	remaining: 538ms
# 593:	learn: 20194.6995421	total: 45.6s	remaining: 461ms
# 594:	learn: 20169.4436464	total: 45.7s	remaining: 384ms
# 595:	learn: 20144.6536473	total: 45.8s	remaining: 307ms
# 596:	learn: 20129.7781039	total: 45.9s	remaining: 231ms
# 597:	learn: 20103.7839759	total: 46s	remaining: 154ms
# 598:	learn: 20076.2909841	total: 46s	remaining: 76.9ms
# 599:	learn: 20043.4778276	total: 46.1s	remaining: 0us

# %%
pd.DataFrame({'featchure':X_tr.columns, 'imp': cat.feature_importances_})
# Out:
#                    featchure        imp
# 0                       name   0.701808
# 1                   has_test   0.100207
# 2   response_letter_required   0.731988
# 3                salary_from  18.183968
# 4               salary_gross   1.498029
# 5              employer_name   3.783938
# 6                    area_id   0.681302
# 7                  area_name   1.190780
# 8                  timestamp   8.646606
# 9                start_name1   8.109944
# 10               start_name2   7.293179
# 11               start_name3   4.490141
# 12             optimum_title   4.531205
# 13           salary_min_desc   0.595113
# 14           salary_max_desc   1.627691
# 15       salary_mean_opt_emp   3.738599
# 16      salary_mean_opt_area   1.629855
# 17           salary_mean_opt   2.001445
# 18     salary_mean_opt_prof1   2.283099
# 19        salary_mean_prof12   3.536249
# 20        salary_mean_prof13   2.629898
# 21        salary_mean_prof23   2.608039
# 22     salary_mean_prof1_emp   5.729469
# 23     salary_mean_prof2_emp   1.554160
# 24     salary_mean_prof3_emp   1.547962
# 25      salary_mean_emp_area   2.897093
# 26    salary_mean_prof1_area   2.642427
# 27           salary_mean_emp   3.050236
# 28          salary_mean_prof   1.765473
# 29          salary_mean_area   0.220097

# %%
y_pred_val = cat.predict(X_val)

# %%
import numpy as np

def sym_mean_absolute_percentage_error(actual, predicted):
    return 200*np.mean(np.abs(actual - predicted) / (np.abs(actual) + np.abs(predicted)))

# %%
sym_mean_absolute_percentage_error(y_val,y_pred_val)
# Out:
# 23.003961296892538

# %%
qw = pd.DataFrame({ 'X_from': X_val.salary_from,'y_true':y_val, 'y_pred': y_pred_val,'salary_max_desc':X_val.salary_max_desc, 'y_pred_copy': y_pred_val  })

# %%
qw.loc[~qw.salary_max_desc.isnull(),'y_pred'] = qw.loc[~qw.salary_max_desc.isnull()].salary_max_desc
qw.loc[~qw.salary_max_desc.isnull()]
# Out:
#              X_from    y_true    y_pred  salary_max_desc    y_pred_copy
# 5739   37000.000000   45000.0   45000.0          45000.0   51544.207760
# 16333  30000.000000   35000.0   35000.0          35000.0   42797.243266
# 25790  55656.171349   20000.0   10000.0          10000.0  120855.195004
# 21308  50000.000000   70000.0   70000.0          70000.0   97130.012570
# 2632   60887.304029   80000.0  100000.0         100000.0   83080.243805
# ...             ...       ...       ...              ...            ...
# 8073   50000.000000   70000.0   60000.0          60000.0   62736.572142
# 11316  39200.000000   40000.0   40000.0          40000.0   40653.999171
# 27094  50000.000000  110000.0  110000.0         110000.0  104781.841082
# 1782   38985.000000   43000.0   43000.0          43000.0   40278.768658
# 19469  60000.000000   70000.0   70000.0          70000.0   69676.317665
#
# [657 rows x 5 columns]

# %%
y_pred_val = qw.y_pred

# %%
smape = sym_mean_absolute_percentage_error(y_val,y_pred_val)
print("SMAPE:", smape)
# Out:
# SMAPE: 22.45448109567663

# %%
qw['diff'] = abs(qw.y_true-qw.y_pred)

# %%
qw[((~qw.salary_max_desc.isnull()))].sort_values(by = 'diff').tail(20)
# Out:
#               X_from    y_true    y_pred  salary_max_desc    y_pred_copy  \
# 9263    40000.000000  200000.0  352185.0         352185.0  171157.137572
# 3134   100000.000000  300000.0  130000.0         130000.0  209409.718892
# 16918  124300.000000  130000.0  300000.0         300000.0  248564.282181
# 19418  125000.000000  550000.0  378000.0         378000.0  271005.759821
# 5981    90000.000000  300000.0  100000.0         100000.0  210521.430404
# 27791   75000.000000  150000.0  350000.0         350000.0  217224.403428
# 25259  165038.990802  250000.0   40000.0          40000.0  300266.230763
# 26549  179290.853477  250000.0   25000.0          25000.0  180063.277186
# 26625  100000.000000  400000.0  150000.0         150000.0  251723.191828
# 22859   32000.000000  300000.0   39000.0          39000.0  112408.793441
# 4487    80000.000000  120000.0  400000.0         400000.0  153503.278932
# 20857   64800.000000  300000.0   20000.0          20000.0  143945.537484
# 15798   80000.000000  100000.0  400000.0         400000.0  186158.510309
# 25964   30000.000000   45000.0  360000.0         360000.0   56812.183885
# 18847   42940.000000   80000.0  400000.0         400000.0  175430.957480
# 14508   20000.000000   50000.0  400000.0         400000.0   59183.560163
# 25733   81650.000000  150000.0  500000.0         500000.0  265422.578891
# 19696   30000.000000  450000.0   45000.0          45000.0   52922.675938
# 20805    1600.000000    1800.0  414000.0         414000.0   30502.815727
# 4905    42950.281533   40000.0  500000.0         500000.0   74165.230945
#
#            diff
# 9263   152185.0
# 3134   170000.0
# 16918  170000.0
# 19418  172000.0
# 5981   200000.0
# 27791  200000.0
# 25259  210000.0
# 26549  225000.0
# 26625  250000.0
# 22859  261000.0
# 4487   280000.0
# 20857  280000.0
# 15798  300000.0
# 25964  315000.0
# 18847  320000.0
# 14508  350000.0
# 25733  350000.0
# 19696  405000.0
# 20805  412200.0
# 4905   460000.0

# %%
qw.loc[((~qw.salary_max_desc.isnull()) &(qw.y_pred>qw.X_from*2)  ), 'y_pred'] = qw.loc[((~qw.salary_max_desc.isnull()) &(qw.y_pred>qw.X_from*2))].y_pred_copy

# %%
qw['diff'] = abs(qw.y_true-qw.y_pred)

# %%
qw[((~qw.salary_max_desc.isnull()) )].sort_values(by = 'diff').tail(20)
# Out:
#               X_from    y_true        y_pred  salary_max_desc   y_pred_copy  \
# 7236    59140.679906  150000.0  3.900000e+04          39000.0  8.877709e+04
# 20444  131071.461722  400000.0  2.883600e+05         300000.0  2.883600e+05
# 7809   100000.000000  150000.0  2.616463e+05         300000.0  2.616463e+05
# 25733   81650.000000  150000.0  2.654226e+05         500000.0  2.654226e+05
# 16918  124300.000000  130000.0  2.485643e+05         300000.0  2.485643e+05
# 16156  120000.000000  260000.0  1.400000e+05         140000.0  1.808149e+05
# 21232   50000.000000  100000.0  2.203924e+05         200000.0  2.203924e+05
# 11393  263333.333333  400000.0  2.500000e+05         250000.0  3.133509e+05
# 20004  220000.000000  250000.0  4.000000e+05         400000.0  3.397896e+05
# 13342  127193.226478  250000.0  1.000000e+05         100000.0  2.052586e+05
# 3134   100000.000000  300000.0  1.300000e+05         130000.0  2.094097e+05
# 5981    90000.000000  300000.0  1.000000e+05         100000.0  2.105214e+05
# 25259  165038.990802  250000.0  4.000000e+04          40000.0  3.002662e+05
# 26549  179290.853477  250000.0  2.500000e+04          25000.0  1.800633e+05
# 26625  100000.000000  400000.0  1.500000e+05         150000.0  2.517232e+05
# 22859   32000.000000  300000.0  3.900000e+04          39000.0  1.124088e+05
# 19418  125000.000000  550000.0  2.710058e+05         378000.0  2.710058e+05
# 20857   64800.000000  300000.0  2.000000e+04          20000.0  1.439455e+05
# 19696   30000.000000  450000.0  4.500000e+04          45000.0  5.292268e+04
# 23017      15.000000      25.0  1.542029e+06          15000.0  1.542029e+06
#
#                diff
# 7236   1.110000e+05
# 20444  1.116400e+05
# 7809   1.116463e+05
# 25733  1.154226e+05
# 16918  1.185643e+05
# 16156  1.200000e+05
# 21232  1.203924e+05
# 11393  1.500000e+05
# 20004  1.500000e+05
# 13342  1.500000e+05
# 3134   1.700000e+05
# 5981   2.000000e+05
# 25259  2.100000e+05
# 26549  2.250000e+05
# 26625  2.500000e+05
# 22859  2.610000e+05
# 19418  2.789942e+05
# 20857  2.800000e+05
# 19696  4.050000e+05
# 23017  1.542004e+06

# %%
sym_mean_absolute_percentage_error(qw[((~qw.salary_max_desc.isnull()))].y_true, qw[((~qw.salary_max_desc.isnull()))].y_pred)
# Out:
# 14.313717620526193

# %%
qw.loc[qw.X_from<150,'y_pred']  = qw.loc[qw.X_from<=150].X_from*1.2
y_pred_val=qw.y_pred

# %%
smape = sym_mean_absolute_percentage_error(y_val,y_pred_val)
print("SMAPE:", smape)
# Out:
# SMAPE: 22.140890728029504

# %% [markdown]
# # Train all + predict Test

# %%
y_true = X_train.salary_to
X = X_train.drop(columns=["id", "description","salary_currency","salary_to", 'published_at','created_at' ])

# %%
category_feat = X.loc[:, X.dtypes == 'category'].columns.to_list()
category_feat
# Out:
# ['name',
#  'employer_name',
#  'area_name',
#  'start_name1',
#  'start_name2',
#  'start_name3',
#  'optimum_title',
#  'eng']

# %%
cat = CatBoostRegressor(cat_features=category_feat, iterations=700, learning_rate=0.1, depth=10,score_function= 'L2', random_state=912, boosting_type = 'Plain',has_time=False,max_bin=254, random_strength=1)

# %%
cat.fit(X, y_true)
# Out:
# 0:	learn: 100085.4514101	total: 107ms	remaining: 1m 15s
# 1:	learn: 95512.2620877	total: 208ms	remaining: 1m 12s
# 2:	learn: 91465.3428053	total: 311ms	remaining: 1m 12s
# 3:	learn: 87891.7330466	total: 403ms	remaining: 1m 10s
# 4:	learn: 84803.5566089	total: 508ms	remaining: 1m 10s
# 5:	learn: 82171.6821106	total: 611ms	remaining: 1m 10s
# 6:	learn: 79953.9530379	total: 708ms	remaining: 1m 10s
# 7:	learn: 77901.9137021	total: 817ms	remaining: 1m 10s
# 8:	learn: 76235.0267165	total: 920ms	remaining: 1m 10s
# 9:	learn: 74650.1293763	total: 1.02s	remaining: 1m 10s
# 10:	learn: 73092.9237140	total: 1.14s	remaining: 1m 11s
# 11:	learn: 71933.0748301	total: 1.24s	remaining: 1m 10s
# 12:	learn: 70843.7678538	total: 1.33s	remaining: 1m 10s
# 13:	learn: 69872.6075062	total: 1.44s	remaining: 1m 10s
# 14:	learn: 69017.1915045	total: 1.58s	remaining: 1m 12s
# 15:	learn: 68273.3549968	total: 1.71s	remaining: 1m 13s
# 16:	learn: 67617.4489874	total: 1.84s	remaining: 1m 14s
# 17:	learn: 66986.0531172	total: 1.99s	remaining: 1m 15s
# 18:	learn: 66228.3488696	total: 2.13s	remaining: 1m 16s
# 19:	learn: 65687.8435825	total: 2.27s	remaining: 1m 17s
# 20:	learn: 64917.4296371	total: 2.43s	remaining: 1m 18s
# 21:	learn: 64401.7354230	total: 2.57s	remaining: 1m 19s
# 22:	learn: 63781.0517869	total: 2.7s	remaining: 1m 19s
# 23:	learn: 63377.6241908	total: 2.8s	remaining: 1m 18s
# 24:	learn: 62967.0710673	total: 2.9s	remaining: 1m 18s
# 25:	learn: 62584.2357419	total: 3s	remaining: 1m 17s
# 26:	learn: 62206.3901533	total: 3.11s	remaining: 1m 17s
# 27:	learn: 61815.2162747	total: 3.21s	remaining: 1m 16s
# 28:	learn: 61473.2889632	total: 3.3s	remaining: 1m 16s
# 29:	learn: 61048.2322577	total: 3.41s	remaining: 1m 16s
# 30:	learn: 60638.1857421	total: 3.52s	remaining: 1m 15s
# 31:	learn: 60374.8594512	total: 3.62s	remaining: 1m 15s
# 32:	learn: 59911.4674713	total: 3.73s	remaining: 1m 15s
# 33:	learn: 59510.7994116	total: 3.84s	remaining: 1m 15s
# 34:	learn: 59210.7475404	total: 3.95s	remaining: 1m 15s
# 35:	learn: 58981.4045370	total: 4.08s	remaining: 1m 15s
# 36:	learn: 58744.7691038	total: 4.19s	remaining: 1m 15s
# 37:	learn: 58459.7892764	total: 4.3s	remaining: 1m 14s
# 38:	learn: 58162.6976093	total: 4.4s	remaining: 1m 14s
# 39:	learn: 57916.9187166	total: 4.51s	remaining: 1m 14s
# 40:	learn: 57668.7262532	total: 4.61s	remaining: 1m 14s
# 41:	learn: 57436.2037479	total: 4.71s	remaining: 1m 13s
# 42:	learn: 57306.4902551	total: 4.81s	remaining: 1m 13s
# 43:	learn: 57077.3593844	total: 4.92s	remaining: 1m 13s
# 44:	learn: 56829.9281570	total: 5.03s	remaining: 1m 13s
# 45:	learn: 56577.7699657	total: 5.13s	remaining: 1m 12s
# 46:	learn: 56300.3639808	total: 5.24s	remaining: 1m 12s
# 47:	learn: 56159.4660608	total: 5.34s	remaining: 1m 12s
# 48:	learn: 55922.2831946	total: 5.45s	remaining: 1m 12s
# 49:	learn: 55784.8347701	total: 5.55s	remaining: 1m 12s
# 50:	learn: 55606.4743576	total: 5.66s	remaining: 1m 12s
# 51:	learn: 55411.9958274	total: 5.77s	remaining: 1m 11s
# 52:	learn: 55284.7747583	total: 5.88s	remaining: 1m 11s
# 53:	learn: 55199.1409624	total: 5.98s	remaining: 1m 11s
# 54:	learn: 54970.6479063	total: 6.09s	remaining: 1m 11s
# 55:	learn: 54636.6476656	total: 6.19s	remaining: 1m 11s
# 56:	learn: 54442.3560375	total: 6.3s	remaining: 1m 11s
# 57:	learn: 54161.7429335	total: 6.4s	remaining: 1m 10s
# 58:	learn: 53908.5149153	total: 6.49s	remaining: 1m 10s
# 59:	learn: 53773.2047536	total: 6.59s	remaining: 1m 10s
# 60:	learn: 53676.7891702	total: 6.7s	remaining: 1m 10s
# 61:	learn: 53550.3046639	total: 6.81s	remaining: 1m 10s
# 62:	learn: 53332.9966331	total: 6.9s	remaining: 1m 9s
# 63:	learn: 53242.0267008	total: 7.01s	remaining: 1m 9s
# 64:	learn: 52992.5610907	total: 7.12s	remaining: 1m 9s
# 65:	learn: 52849.0510304	total: 7.22s	remaining: 1m 9s
# 66:	learn: 52745.1513832	total: 7.31s	remaining: 1m 9s
# 67:	learn: 52508.8103287	total: 7.41s	remaining: 1m 8s
# 68:	learn: 52425.6063423	total: 7.51s	remaining: 1m 8s
# 69:	learn: 52328.5049423	total: 7.61s	remaining: 1m 8s
# 70:	learn: 52149.4220806	total: 7.72s	remaining: 1m 8s
# 71:	learn: 52031.8731827	total: 7.84s	remaining: 1m 8s
# 72:	learn: 51933.2883342	total: 7.96s	remaining: 1m 8s
# 73:	learn: 51817.3630016	total: 8.07s	remaining: 1m 8s
# 74:	learn: 51557.9253525	total: 8.18s	remaining: 1m 8s
# 75:	learn: 51445.7519262	total: 8.28s	remaining: 1m 8s
# 76:	learn: 51348.5425587	total: 8.39s	remaining: 1m 7s
# 77:	learn: 51232.5440452	total: 8.48s	remaining: 1m 7s
# 78:	learn: 51157.1217652	total: 8.57s	remaining: 1m 7s
# 79:	learn: 50893.0854011	total: 8.68s	remaining: 1m 7s
# 80:	learn: 50676.3243400	total: 8.78s	remaining: 1m 7s
# 81:	learn: 50515.8879060	total: 8.88s	remaining: 1m 6s
# 82:	learn: 50398.7880730	total: 8.99s	remaining: 1m 6s
# 83:	learn: 50165.9609608	total: 9.09s	remaining: 1m 6s
# 84:	learn: 50071.3655616	total: 9.21s	remaining: 1m 6s
# 85:	learn: 49943.0549388	total: 9.32s	remaining: 1m 6s
# 86:	learn: 49890.1622961	total: 9.41s	remaining: 1m 6s
# 87:	learn: 49773.2017067	total: 9.53s	remaining: 1m 6s
# 88:	learn: 49695.4654081	total: 9.63s	remaining: 1m 6s
# 89:	learn: 49511.7216593	total: 9.73s	remaining: 1m 5s
# 90:	learn: 49352.3197358	total: 9.83s	remaining: 1m 5s
# 91:	learn: 49180.8050007	total: 9.95s	remaining: 1m 5s
# 92:	learn: 49090.0102611	total: 10s	remaining: 1m 5s
# 93:	learn: 48940.0188598	total: 10.1s	remaining: 1m 5s
# 94:	learn: 48823.2332268	total: 10.3s	remaining: 1m 5s
# 95:	learn: 48725.6936294	total: 10.4s	remaining: 1m 5s
# 96:	learn: 48538.7338768	total: 10.5s	remaining: 1m 4s
# 97:	learn: 48463.0311543	total: 10.6s	remaining: 1m 4s
# 98:	learn: 48275.3856453	total: 10.7s	remaining: 1m 4s
# 99:	learn: 48180.2467515	total: 10.8s	remaining: 1m 4s
# 100:	learn: 48095.5070979	total: 10.9s	remaining: 1m 4s
# 101:	learn: 48019.8792839	total: 11s	remaining: 1m 4s
# 102:	learn: 47920.6685512	total: 11.1s	remaining: 1m 4s
# 103:	learn: 47752.1398833	total: 11.2s	remaining: 1m 3s
# 104:	learn: 47655.6400060	total: 11.3s	remaining: 1m 3s
# 105:	learn: 47529.0432413	total: 11.4s	remaining: 1m 3s
# 106:	learn: 47438.4378545	total: 11.5s	remaining: 1m 3s
# 107:	learn: 47324.5414137	total: 11.6s	remaining: 1m 3s
# 108:	learn: 47219.6598185	total: 11.7s	remaining: 1m 3s
# 109:	learn: 47121.5826011	total: 11.8s	remaining: 1m 3s
# 110:	learn: 47034.4251252	total: 11.9s	remaining: 1m 3s
# 111:	learn: 46889.6369940	total: 12s	remaining: 1m 3s
# 112:	learn: 46745.0477819	total: 12.1s	remaining: 1m 2s
# 113:	learn: 46653.6216605	total: 12.2s	remaining: 1m 2s
# 114:	learn: 46556.0744575	total: 12.3s	remaining: 1m 2s
# 115:	learn: 46402.3772359	total: 12.5s	remaining: 1m 2s
# 116:	learn: 46308.6299083	total: 12.6s	remaining: 1m 2s
# 117:	learn: 46194.7001243	total: 12.7s	remaining: 1m 2s
# 118:	learn: 46124.7375095	total: 12.8s	remaining: 1m 2s
# 119:	learn: 46063.1242537	total: 12.9s	remaining: 1m 2s
# 120:	learn: 45987.1721621	total: 13s	remaining: 1m 2s
# 121:	learn: 45828.3549603	total: 13.1s	remaining: 1m 2s
# 122:	learn: 45737.3565662	total: 13.2s	remaining: 1m 1s
# 123:	learn: 45679.3629390	total: 13.3s	remaining: 1m 1s
# 124:	learn: 45644.6301994	total: 13.4s	remaining: 1m 1s
# 125:	learn: 45559.8232379	total: 13.5s	remaining: 1m 1s
# 126:	learn: 45473.6269600	total: 13.6s	remaining: 1m 1s
# 127:	learn: 45407.0010323	total: 13.7s	remaining: 1m 1s
# 128:	learn: 45304.7924148	total: 13.8s	remaining: 1m 1s
# 129:	learn: 45246.4684113	total: 13.9s	remaining: 1m 1s
# 130:	learn: 45187.0902420	total: 14.1s	remaining: 1m 1s
# 131:	learn: 45114.6529359	total: 14.2s	remaining: 1m
# 132:	learn: 45000.5534542	total: 14.3s	remaining: 1m
# 133:	learn: 44907.8879508	total: 14.4s	remaining: 1m
# 134:	learn: 44835.9829039	total: 14.5s	remaining: 1m
# 135:	learn: 44740.0881783	total: 14.6s	remaining: 1m
# 136:	learn: 44635.0722760	total: 14.7s	remaining: 1m
# 137:	learn: 44576.3486038	total: 14.8s	remaining: 1m
# 138:	learn: 44507.3887548	total: 14.9s	remaining: 1m
# 139:	learn: 44481.9509262	total: 15s	remaining: 1m
# 140:	learn: 44447.0419046	total: 15.1s	remaining: 59.9s
# 141:	learn: 44359.9890548	total: 15.2s	remaining: 59.9s
# 142:	learn: 44329.8110988	total: 15.3s	remaining: 59.7s
# 143:	learn: 44255.2507099	total: 15.4s	remaining: 59.6s
# 144:	learn: 44191.5661718	total: 15.5s	remaining: 59.5s
# 145:	learn: 44061.8946455	total: 15.6s	remaining: 59.3s
# 146:	learn: 44004.5793203	total: 15.7s	remaining: 59.2s
# 147:	learn: 43899.5875523	total: 15.8s	remaining: 59.1s
# 148:	learn: 43706.6666110	total: 16s	remaining: 59s
# 149:	learn: 43616.5137619	total: 16s	remaining: 58.8s
# 150:	learn: 43561.3782209	total: 16.2s	remaining: 58.7s
# 151:	learn: 43485.1051456	total: 16.3s	remaining: 58.6s
# 152:	learn: 43438.0855934	total: 16.4s	remaining: 58.5s
# 153:	learn: 43313.5620250	total: 16.5s	remaining: 58.5s
# 154:	learn: 43250.0793141	total: 16.6s	remaining: 58.4s
# 155:	learn: 43177.9064301	total: 16.7s	remaining: 58.2s
# 156:	learn: 43080.9046869	total: 16.8s	remaining: 58.1s
# 157:	learn: 43044.3697094	total: 16.9s	remaining: 58s
# 158:	learn: 42955.2146381	total: 17s	remaining: 57.9s
# 159:	learn: 42923.4922339	total: 17.1s	remaining: 57.8s
# 160:	learn: 42816.7005734	total: 17.2s	remaining: 57.7s
# 161:	learn: 42698.7673483	total: 17.3s	remaining: 57.6s
# 162:	learn: 42632.5257596	total: 17.4s	remaining: 57.5s
# 163:	learn: 42516.5975677	total: 17.6s	remaining: 57.4s
# 164:	learn: 42402.4748465	total: 17.7s	remaining: 57.3s
# 165:	learn: 42358.5646169	total: 17.8s	remaining: 57.2s
# 166:	learn: 42284.2822877	total: 17.9s	remaining: 57.1s
# 167:	learn: 42174.9203297	total: 18s	remaining: 57s
# 168:	learn: 42069.7702042	total: 18.1s	remaining: 56.9s
# 169:	learn: 42026.6267057	total: 18.2s	remaining: 56.8s
# 170:	learn: 41942.4889354	total: 18.3s	remaining: 56.7s
# 171:	learn: 41901.9779817	total: 18.4s	remaining: 56.6s
# 172:	learn: 41781.5441672	total: 18.5s	remaining: 56.4s
# 173:	learn: 41642.2993149	total: 18.6s	remaining: 56.4s
# 174:	learn: 41590.4794708	total: 18.7s	remaining: 56.2s
# 175:	learn: 41523.7829254	total: 18.9s	remaining: 56.2s
# 176:	learn: 41466.5246709	total: 19s	remaining: 56.1s
# 177:	learn: 41430.9580788	total: 19.1s	remaining: 56s
# 178:	learn: 41396.0124538	total: 19.2s	remaining: 55.8s
# 179:	learn: 41340.4922953	total: 19.3s	remaining: 55.7s
# 180:	learn: 41292.6052527	total: 19.4s	remaining: 55.6s
# 181:	learn: 41209.9786635	total: 19.5s	remaining: 55.5s
# 182:	learn: 41083.4149483	total: 19.6s	remaining: 55.4s
# 183:	learn: 41051.6429106	total: 19.7s	remaining: 55.3s
# 184:	learn: 40974.6596494	total: 19.8s	remaining: 55.2s
# 185:	learn: 40878.6978095	total: 19.9s	remaining: 55.1s
# 186:	learn: 40824.6679727	total: 20s	remaining: 55s
# 187:	learn: 40783.5711374	total: 20.2s	remaining: 54.9s
# 188:	learn: 40748.9445637	total: 20.3s	remaining: 54.8s
# 189:	learn: 40711.2194800	total: 20.4s	remaining: 54.7s
# 190:	learn: 40657.9261304	total: 20.5s	remaining: 54.6s
# 191:	learn: 40597.1216044	total: 20.6s	remaining: 54.5s
# 192:	learn: 40476.1773126	total: 20.7s	remaining: 54.4s
# 193:	learn: 40373.7313743	total: 20.8s	remaining: 54.3s
# 194:	learn: 40278.5427246	total: 20.9s	remaining: 54.1s
# 195:	learn: 40241.1277126	total: 21s	remaining: 54s
# 196:	learn: 40169.6242410	total: 21.1s	remaining: 53.9s
# 197:	learn: 40108.8469613	total: 21.2s	remaining: 53.7s
# 198:	learn: 40032.7228762	total: 21.3s	remaining: 53.6s
# 199:	learn: 39987.3239477	total: 21.4s	remaining: 53.5s
# 200:	learn: 39889.3632350	total: 21.5s	remaining: 53.3s
# 201:	learn: 39855.6731603	total: 21.6s	remaining: 53.2s
# 202:	learn: 39755.9008899	total: 21.7s	remaining: 53.1s
# 203:	learn: 39685.2714090	total: 21.8s	remaining: 53.1s
# 204:	learn: 39640.6022407	total: 21.9s	remaining: 52.9s
# 205:	learn: 39599.8128462	total: 22s	remaining: 52.9s
# 206:	learn: 39547.7721886	total: 22.1s	remaining: 52.7s
# 207:	learn: 39498.0844838	total: 22.3s	remaining: 52.7s
# 208:	learn: 39448.4013864	total: 22.4s	remaining: 52.6s
# 209:	learn: 39412.9641081	total: 22.5s	remaining: 52.5s
# 210:	learn: 39356.0589277	total: 22.6s	remaining: 52.4s
# 211:	learn: 39316.7352002	total: 22.7s	remaining: 52.3s
# 212:	learn: 39292.9724729	total: 22.8s	remaining: 52.2s
# 213:	learn: 39219.3466737	total: 22.9s	remaining: 52.1s
# 214:	learn: 39178.9968577	total: 23s	remaining: 51.9s
# 215:	learn: 39128.0766700	total: 23.1s	remaining: 51.8s
# 216:	learn: 39069.1353158	total: 23.2s	remaining: 51.7s
# 217:	learn: 39000.2014154	total: 23.3s	remaining: 51.6s
# 218:	learn: 38966.0630655	total: 23.4s	remaining: 51.5s
# 219:	learn: 38875.0751117	total: 23.5s	remaining: 51.3s
# 220:	learn: 38772.0678080	total: 23.6s	remaining: 51.2s
# 221:	learn: 38720.8545260	total: 23.7s	remaining: 51.1s
# 222:	learn: 38681.4227270	total: 23.8s	remaining: 51s
# 223:	learn: 38665.7488904	total: 23.9s	remaining: 50.9s
# 224:	learn: 38548.8651272	total: 24.1s	remaining: 50.8s
# 225:	learn: 38499.4973792	total: 24.2s	remaining: 50.7s
# 226:	learn: 38444.1098131	total: 24.3s	remaining: 50.6s
# 227:	learn: 38372.7814542	total: 24.4s	remaining: 50.5s
# 228:	learn: 38322.0613170	total: 24.5s	remaining: 50.4s
# 229:	learn: 38234.9573049	total: 24.6s	remaining: 50.3s
# 230:	learn: 38207.9298616	total: 24.7s	remaining: 50.1s
# 231:	learn: 38116.0253728	total: 24.8s	remaining: 50s
# 232:	learn: 38061.6367132	total: 24.9s	remaining: 49.9s
# 233:	learn: 38006.0143950	total: 25s	remaining: 49.8s
# 234:	learn: 37962.0272174	total: 25.1s	remaining: 49.7s
# 235:	learn: 37922.2078259	total: 25.2s	remaining: 49.6s
# 236:	learn: 37813.3778109	total: 25.3s	remaining: 49.5s
# 237:	learn: 37747.6331385	total: 25.4s	remaining: 49.4s
# 238:	learn: 37683.6585227	total: 25.6s	remaining: 49.3s
# 239:	learn: 37655.9314017	total: 25.7s	remaining: 49.2s
# 240:	learn: 37574.0048953	total: 25.8s	remaining: 49.1s
# 241:	learn: 37512.0651054	total: 25.9s	remaining: 49s
# 242:	learn: 37488.4883920	total: 26s	remaining: 48.9s
# 243:	learn: 37408.3963990	total: 26.1s	remaining: 48.8s
# 244:	learn: 37350.9904761	total: 26.2s	remaining: 48.7s
# 245:	learn: 37326.4220359	total: 26.3s	remaining: 48.6s
# 246:	learn: 37260.7235817	total: 26.4s	remaining: 48.5s
# 247:	learn: 37200.6986018	total: 26.6s	remaining: 48.4s
# 248:	learn: 37108.9522600	total: 26.7s	remaining: 48.3s
# 249:	learn: 37034.3907621	total: 26.8s	remaining: 48.2s
# 250:	learn: 36957.9776363	total: 26.9s	remaining: 48.1s
# 251:	learn: 36898.2954686	total: 27s	remaining: 48s
# 252:	learn: 36834.9036964	total: 27.1s	remaining: 47.9s
# 253:	learn: 36799.7122449	total: 27.2s	remaining: 47.8s
# 254:	learn: 36720.8087500	total: 27.3s	remaining: 47.7s
# 255:	learn: 36671.4918735	total: 27.5s	remaining: 47.6s
# 256:	learn: 36609.7682159	total: 27.5s	remaining: 47.5s
# 257:	learn: 36583.0327050	total: 27.7s	remaining: 47.4s
# 258:	learn: 36558.4793103	total: 27.8s	remaining: 47.3s
# 259:	learn: 36544.3476298	total: 27.9s	remaining: 47.2s
# 260:	learn: 36456.6735514	total: 28s	remaining: 47.1s
# 261:	learn: 36403.5052399	total: 28.1s	remaining: 47.1s
# 262:	learn: 36365.7507019	total: 28.3s	remaining: 47s
# 263:	learn: 36343.2327707	total: 28.4s	remaining: 46.9s
# 264:	learn: 36290.6276225	total: 28.5s	remaining: 46.8s
# 265:	learn: 36263.4809550	total: 28.6s	remaining: 46.7s
# 266:	learn: 36234.7983138	total: 28.7s	remaining: 46.6s
# 267:	learn: 36175.5485514	total: 28.8s	remaining: 46.5s
# 268:	learn: 36124.3847584	total: 29s	remaining: 46.4s
# 269:	learn: 36069.4691076	total: 29s	remaining: 46.3s
# 270:	learn: 36042.6353454	total: 29.1s	remaining: 46.1s
# 271:	learn: 35987.4453816	total: 29.3s	remaining: 46s
# 272:	learn: 35963.9482287	total: 29.4s	remaining: 46s
# 273:	learn: 35906.3758091	total: 29.5s	remaining: 45.9s
# 274:	learn: 35847.1550705	total: 29.6s	remaining: 45.7s
# 275:	learn: 35805.8626035	total: 29.7s	remaining: 45.6s
# 276:	learn: 35782.6151393	total: 29.8s	remaining: 45.5s
# 277:	learn: 35732.7704755	total: 29.9s	remaining: 45.4s
# 278:	learn: 35619.8376156	total: 30s	remaining: 45.3s
# 279:	learn: 35567.8030719	total: 30.1s	remaining: 45.2s
# 280:	learn: 35504.4676225	total: 30.2s	remaining: 45.1s
# 281:	learn: 35491.7081847	total: 30.4s	remaining: 45s
# 282:	learn: 35460.3375006	total: 30.5s	remaining: 44.9s
# 283:	learn: 35401.3132320	total: 30.6s	remaining: 44.8s
# 284:	learn: 35321.7073487	total: 30.7s	remaining: 44.7s
# 285:	learn: 35276.3474932	total: 30.8s	remaining: 44.6s
# 286:	learn: 35251.6540330	total: 30.9s	remaining: 44.5s
# 287:	learn: 35197.1826514	total: 31.1s	remaining: 44.4s
# 288:	learn: 35160.8792117	total: 31.2s	remaining: 44.3s
# 289:	learn: 35139.3468411	total: 31.3s	remaining: 44.2s
# 290:	learn: 35075.4801913	total: 31.4s	remaining: 44.1s
# 291:	learn: 35023.1659791	total: 31.5s	remaining: 44s
# 292:	learn: 34975.2806471	total: 31.6s	remaining: 43.9s
# 293:	learn: 34939.0647401	total: 31.7s	remaining: 43.8s
# 294:	learn: 34862.3943799	total: 31.8s	remaining: 43.7s
# 295:	learn: 34848.6449826	total: 31.9s	remaining: 43.6s
# 296:	learn: 34821.3767426	total: 32s	remaining: 43.5s
# 297:	learn: 34790.1281648	total: 32.2s	remaining: 43.4s
# 298:	learn: 34756.6901167	total: 32.3s	remaining: 43.3s
# 299:	learn: 34696.4954764	total: 32.4s	remaining: 43.2s
# 300:	learn: 34667.2773778	total: 32.5s	remaining: 43s
# 301:	learn: 34623.2357654	total: 32.6s	remaining: 42.9s
# 302:	learn: 34579.1854301	total: 32.7s	remaining: 42.8s
# 303:	learn: 34545.1970513	total: 32.8s	remaining: 42.7s
# 304:	learn: 34527.4964561	total: 32.9s	remaining: 42.7s
# 305:	learn: 34501.3718128	total: 33.1s	remaining: 42.6s
# 306:	learn: 34455.0081563	total: 33.3s	remaining: 42.6s
# 307:	learn: 34431.0660152	total: 33.4s	remaining: 42.5s
# 308:	learn: 34413.5829382	total: 33.5s	remaining: 42.4s
# 309:	learn: 34389.8473499	total: 33.7s	remaining: 42.4s
# 310:	learn: 34355.5769317	total: 33.8s	remaining: 42.3s
# 311:	learn: 34303.9130349	total: 34s	remaining: 42.2s
# 312:	learn: 34281.0260179	total: 34.1s	remaining: 42.2s
# 313:	learn: 34257.2084796	total: 34.3s	remaining: 42.1s
# 314:	learn: 34222.2825263	total: 34.4s	remaining: 42s
# 315:	learn: 34169.8554695	total: 34.5s	remaining: 41.9s
# 316:	learn: 34143.7563938	total: 34.6s	remaining: 41.8s
# 317:	learn: 34118.5887477	total: 34.7s	remaining: 41.7s
# 318:	learn: 34074.1572164	total: 34.8s	remaining: 41.6s
# 319:	learn: 34037.7936212	total: 34.9s	remaining: 41.4s
# 320:	learn: 34008.0571570	total: 35s	remaining: 41.4s
# 321:	learn: 33948.0568770	total: 35.2s	remaining: 41.3s
# 322:	learn: 33891.6779749	total: 35.3s	remaining: 41.2s
# 323:	learn: 33837.1805036	total: 35.4s	remaining: 41s
# 324:	learn: 33814.9187339	total: 35.5s	remaining: 41s
# 325:	learn: 33793.6535076	total: 35.6s	remaining: 40.9s
# 326:	learn: 33738.8720708	total: 35.7s	remaining: 40.8s
# 327:	learn: 33708.7669461	total: 35.8s	remaining: 40.7s
# 328:	learn: 33672.5974562	total: 35.9s	remaining: 40.5s
# 329:	learn: 33657.3665521	total: 36s	remaining: 40.4s
# 330:	learn: 33629.8861713	total: 36.1s	remaining: 40.3s
# 331:	learn: 33580.3084379	total: 36.3s	remaining: 40.2s
# 332:	learn: 33517.3424250	total: 36.4s	remaining: 40.1s
# 333:	learn: 33468.8952421	total: 36.5s	remaining: 40s
# 334:	learn: 33422.3454246	total: 36.6s	remaining: 39.9s
# 335:	learn: 33393.5223977	total: 36.7s	remaining: 39.8s
# 336:	learn: 33376.5055811	total: 36.8s	remaining: 39.7s
# 337:	learn: 33313.5020696	total: 37s	remaining: 39.6s
# 338:	learn: 33267.6628522	total: 37.1s	remaining: 39.5s
# 339:	learn: 33232.7190519	total: 37.2s	remaining: 39.4s
# 340:	learn: 33187.7168361	total: 37.3s	remaining: 39.3s
# 341:	learn: 33166.3380703	total: 37.4s	remaining: 39.1s
# 342:	learn: 33137.2218962	total: 37.5s	remaining: 39s
# 343:	learn: 33100.8157750	total: 37.6s	remaining: 38.9s
# 344:	learn: 33066.0384615	total: 37.7s	remaining: 38.8s
# 345:	learn: 33030.6243479	total: 37.8s	remaining: 38.7s
# 346:	learn: 33016.0255647	total: 37.9s	remaining: 38.6s
# 347:	learn: 32967.3321763	total: 38.1s	remaining: 38.5s
# 348:	learn: 32926.4338669	total: 38.1s	remaining: 38.4s
# 349:	learn: 32891.0170361	total: 38.2s	remaining: 38.2s
# 350:	learn: 32857.2388453	total: 38.3s	remaining: 38.1s
# 351:	learn: 32822.2841408	total: 38.4s	remaining: 38s
# 352:	learn: 32779.6629239	total: 38.6s	remaining: 37.9s
# 353:	learn: 32737.9262708	total: 38.7s	remaining: 37.8s
# 354:	learn: 32697.5080167	total: 38.8s	remaining: 37.7s
# 355:	learn: 32665.2136040	total: 38.9s	remaining: 37.6s
# 356:	learn: 32621.7841440	total: 39s	remaining: 37.5s
# 357:	learn: 32561.6221309	total: 39.2s	remaining: 37.4s
# 358:	learn: 32498.1559852	total: 39.3s	remaining: 37.3s
# 359:	learn: 32459.1385618	total: 39.4s	remaining: 37.2s
# 360:	learn: 32441.8760907	total: 39.5s	remaining: 37.1s
# 361:	learn: 32405.5211491	total: 39.6s	remaining: 37s
# 362:	learn: 32333.7165268	total: 39.7s	remaining: 36.9s
# 363:	learn: 32306.6565403	total: 39.8s	remaining: 36.8s
# 364:	learn: 32279.5867865	total: 39.9s	remaining: 36.7s
# 365:	learn: 32249.2138694	total: 40s	remaining: 36.5s
# 366:	learn: 32213.3105832	total: 40.1s	remaining: 36.4s
# 367:	learn: 32183.9163808	total: 40.3s	remaining: 36.3s
# 368:	learn: 32145.7554159	total: 40.3s	remaining: 36.2s
# 369:	learn: 32106.6194402	total: 40.5s	remaining: 36.1s
# 370:	learn: 32064.4006172	total: 40.6s	remaining: 36s
# 371:	learn: 32031.7909425	total: 40.7s	remaining: 35.9s
# 372:	learn: 31990.8690205	total: 40.8s	remaining: 35.8s
# 373:	learn: 31949.4940114	total: 40.9s	remaining: 35.7s
# 374:	learn: 31934.5680533	total: 41s	remaining: 35.5s
# 375:	learn: 31905.1853969	total: 41.1s	remaining: 35.4s
# 376:	learn: 31858.7973715	total: 41.2s	remaining: 35.3s
# 377:	learn: 31840.2008188	total: 41.3s	remaining: 35.2s
# 378:	learn: 31786.6304166	total: 41.5s	remaining: 35.1s
# 379:	learn: 31769.9771199	total: 41.6s	remaining: 35s
# 380:	learn: 31744.0510534	total: 41.7s	remaining: 34.9s
# 381:	learn: 31730.0834798	total: 41.8s	remaining: 34.8s
# 382:	learn: 31706.2656514	total: 41.9s	remaining: 34.7s
# 383:	learn: 31650.8605159	total: 42s	remaining: 34.6s
# 384:	learn: 31629.6148712	total: 42.1s	remaining: 34.5s
# 385:	learn: 31608.6665392	total: 42.2s	remaining: 34.4s
# 386:	learn: 31551.8814864	total: 42.3s	remaining: 34.2s
# 387:	learn: 31515.6382447	total: 42.5s	remaining: 34.1s
# 388:	learn: 31489.3808626	total: 42.6s	remaining: 34s
# 389:	learn: 31440.9478829	total: 42.7s	remaining: 33.9s
# 390:	learn: 31407.9278486	total: 42.8s	remaining: 33.8s
# 391:	learn: 31392.1637795	total: 42.9s	remaining: 33.7s
# 392:	learn: 31366.3248581	total: 43s	remaining: 33.6s
# 393:	learn: 31324.7642491	total: 43.1s	remaining: 33.5s
# 394:	learn: 31298.7758252	total: 43.3s	remaining: 33.4s
# 395:	learn: 31256.9624291	total: 43.4s	remaining: 33.3s
# 396:	learn: 31243.2211147	total: 43.5s	remaining: 33.2s
# 397:	learn: 31222.5980076	total: 43.6s	remaining: 33.1s
# 398:	learn: 31184.8588446	total: 43.7s	remaining: 33s
# 399:	learn: 31161.4919365	total: 43.8s	remaining: 32.9s
# 400:	learn: 31142.3122378	total: 44s	remaining: 32.8s
# 401:	learn: 31126.0899790	total: 44.1s	remaining: 32.7s
# 402:	learn: 31093.4142632	total: 44.2s	remaining: 32.6s
# 403:	learn: 31076.5632599	total: 44.3s	remaining: 32.5s
# 404:	learn: 31038.9933731	total: 44.4s	remaining: 32.3s
# 405:	learn: 31005.6150414	total: 44.5s	remaining: 32.2s
# 406:	learn: 30978.0656743	total: 44.6s	remaining: 32.1s
# 407:	learn: 30930.0556933	total: 44.7s	remaining: 32s
# 408:	learn: 30887.8101400	total: 44.8s	remaining: 31.9s
# 409:	learn: 30856.5388358	total: 44.9s	remaining: 31.8s
# 410:	learn: 30796.7212390	total: 45.1s	remaining: 31.7s
# 411:	learn: 30765.9075357	total: 45.2s	remaining: 31.6s
# 412:	learn: 30744.7602467	total: 45.3s	remaining: 31.5s
# 413:	learn: 30709.2326808	total: 45.4s	remaining: 31.4s
# 414:	learn: 30692.6941194	total: 45.5s	remaining: 31.3s
# 415:	learn: 30668.6813084	total: 45.6s	remaining: 31.2s
# 416:	learn: 30643.5808106	total: 45.8s	remaining: 31s
# 417:	learn: 30608.3908728	total: 45.9s	remaining: 30.9s
# 418:	learn: 30580.5008569	total: 46s	remaining: 30.8s
# 419:	learn: 30540.5324091	total: 46.1s	remaining: 30.7s
# 420:	learn: 30492.5301671	total: 46.2s	remaining: 30.6s
# 421:	learn: 30460.0252003	total: 46.3s	remaining: 30.5s
# 422:	learn: 30447.2601385	total: 46.4s	remaining: 30.4s
# 423:	learn: 30410.6323083	total: 46.5s	remaining: 30.3s
# 424:	learn: 30355.5215490	total: 46.6s	remaining: 30.2s
# 425:	learn: 30313.9819342	total: 46.7s	remaining: 30.1s
# 426:	learn: 30285.3257303	total: 46.9s	remaining: 30s
# 427:	learn: 30256.6726497	total: 47s	remaining: 29.8s
# 428:	learn: 30219.2970959	total: 47.1s	remaining: 29.8s
# 429:	learn: 30189.1772199	total: 47.2s	remaining: 29.6s
# 430:	learn: 30164.2512661	total: 47.3s	remaining: 29.5s
# 431:	learn: 30136.6047856	total: 47.4s	remaining: 29.4s
# 432:	learn: 30110.7072972	total: 47.5s	remaining: 29.3s
# 433:	learn: 30080.1371055	total: 47.6s	remaining: 29.2s
# 434:	learn: 30059.4934672	total: 47.8s	remaining: 29.1s
# 435:	learn: 30040.6823071	total: 47.9s	remaining: 29s
# 436:	learn: 30007.4587518	total: 48s	remaining: 28.9s
# 437:	learn: 29987.0097920	total: 48.1s	remaining: 28.8s
# 438:	learn: 29970.5095869	total: 48.2s	remaining: 28.7s
# 439:	learn: 29930.2451450	total: 48.3s	remaining: 28.6s
# 440:	learn: 29897.9883578	total: 48.4s	remaining: 28.4s
# 441:	learn: 29861.7737907	total: 48.5s	remaining: 28.3s
# 442:	learn: 29833.2535541	total: 48.7s	remaining: 28.2s
# 443:	learn: 29783.2285520	total: 48.8s	remaining: 28.1s
# 444:	learn: 29722.8344858	total: 48.9s	remaining: 28s
# 445:	learn: 29707.2998703	total: 49s	remaining: 27.9s
# 446:	learn: 29667.3270935	total: 49.1s	remaining: 27.8s
# 447:	learn: 29646.6362715	total: 49.2s	remaining: 27.7s
# 448:	learn: 29624.7120816	total: 49.3s	remaining: 27.6s
# 449:	learn: 29599.1382616	total: 49.4s	remaining: 27.4s
# 450:	learn: 29577.6237057	total: 49.5s	remaining: 27.3s
# 451:	learn: 29535.7008496	total: 49.6s	remaining: 27.2s
# 452:	learn: 29501.9494082	total: 49.7s	remaining: 27.1s
# 453:	learn: 29473.0819170	total: 49.9s	remaining: 27s
# 454:	learn: 29449.3697841	total: 50s	remaining: 26.9s
# 455:	learn: 29421.3047697	total: 50.1s	remaining: 26.8s
# 456:	learn: 29396.7263697	total: 50.2s	remaining: 26.7s
# 457:	learn: 29373.0681280	total: 50.3s	remaining: 26.6s
# 458:	learn: 29354.0851408	total: 50.4s	remaining: 26.5s
# 459:	learn: 29323.8268502	total: 50.5s	remaining: 26.4s
# 460:	learn: 29298.0957051	total: 50.6s	remaining: 26.2s
# 461:	learn: 29278.9572329	total: 50.8s	remaining: 26.1s
# 462:	learn: 29255.0425486	total: 50.9s	remaining: 26s
# 463:	learn: 29225.2271745	total: 51s	remaining: 25.9s
# 464:	learn: 29189.5501119	total: 51.1s	remaining: 25.8s
# 465:	learn: 29134.5232461	total: 51.2s	remaining: 25.7s
# 466:	learn: 29102.7170288	total: 51.3s	remaining: 25.6s
# 467:	learn: 29040.5285306	total: 51.4s	remaining: 25.5s
# 468:	learn: 29030.5287225	total: 51.5s	remaining: 25.4s
# 469:	learn: 28993.6560818	total: 51.6s	remaining: 25.3s
# 470:	learn: 28961.8922585	total: 51.8s	remaining: 25.2s
# 471:	learn: 28937.6337185	total: 51.9s	remaining: 25.1s
# 472:	learn: 28913.2841835	total: 52s	remaining: 24.9s
# 473:	learn: 28873.3068804	total: 52.1s	remaining: 24.8s
# 474:	learn: 28847.4448732	total: 52.2s	remaining: 24.7s
# 475:	learn: 28799.1194845	total: 52.3s	remaining: 24.6s
# 476:	learn: 28770.3627834	total: 52.4s	remaining: 24.5s
# 477:	learn: 28750.8201410	total: 52.5s	remaining: 24.4s
# 478:	learn: 28714.4163900	total: 52.6s	remaining: 24.3s
# 479:	learn: 28653.3396787	total: 52.8s	remaining: 24.2s
# 480:	learn: 28612.8114881	total: 52.9s	remaining: 24.1s
# 481:	learn: 28595.3075335	total: 53s	remaining: 24s
# 482:	learn: 28569.6186340	total: 53.1s	remaining: 23.9s
# 483:	learn: 28541.1086635	total: 53.2s	remaining: 23.7s
# 484:	learn: 28522.0770734	total: 53.3s	remaining: 23.6s
# 485:	learn: 28506.9602534	total: 53.5s	remaining: 23.5s
# 486:	learn: 28489.0903077	total: 53.6s	remaining: 23.4s
# 487:	learn: 28465.5782044	total: 53.7s	remaining: 23.3s
# 488:	learn: 28445.3684841	total: 53.8s	remaining: 23.2s
# 489:	learn: 28413.8852125	total: 53.9s	remaining: 23.1s
# 490:	learn: 28367.0912001	total: 54.1s	remaining: 23s
# 491:	learn: 28331.2149531	total: 54.2s	remaining: 22.9s
# 492:	learn: 28317.7164611	total: 54.3s	remaining: 22.8s
# 493:	learn: 28304.3575373	total: 54.4s	remaining: 22.7s
# 494:	learn: 28281.5106877	total: 54.5s	remaining: 22.6s
# 495:	learn: 28253.5083670	total: 54.6s	remaining: 22.5s
# 496:	learn: 28231.6874398	total: 54.8s	remaining: 22.4s
# 497:	learn: 28200.6364089	total: 54.9s	remaining: 22.3s
# 498:	learn: 28159.8302661	total: 55s	remaining: 22.1s
# 499:	learn: 28146.3738941	total: 55.1s	remaining: 22s
# 500:	learn: 28118.5626627	total: 55.2s	remaining: 21.9s
# 501:	learn: 28092.8434453	total: 55.3s	remaining: 21.8s
# 502:	learn: 28082.8984586	total: 55.4s	remaining: 21.7s
# 503:	learn: 28053.3019286	total: 55.5s	remaining: 21.6s
# 504:	learn: 28011.0449100	total: 55.7s	remaining: 21.5s
# 505:	learn: 27986.6712216	total: 55.8s	remaining: 21.4s
# 506:	learn: 27943.5539953	total: 55.9s	remaining: 21.3s
# 507:	learn: 27924.6887743	total: 56s	remaining: 21.2s
# 508:	learn: 27907.9526813	total: 56.1s	remaining: 21.1s
# 509:	learn: 27877.1064258	total: 56.2s	remaining: 20.9s
# 510:	learn: 27840.6133724	total: 56.3s	remaining: 20.8s
# 511:	learn: 27822.6200410	total: 56.4s	remaining: 20.7s
# 512:	learn: 27801.5030674	total: 56.5s	remaining: 20.6s
# 513:	learn: 27775.1873363	total: 56.7s	remaining: 20.5s
# 514:	learn: 27730.3266673	total: 56.8s	remaining: 20.4s
# 515:	learn: 27704.8415776	total: 56.9s	remaining: 20.3s
# 516:	learn: 27671.6083244	total: 57s	remaining: 20.2s
# 517:	learn: 27640.0906179	total: 57.1s	remaining: 20.1s
# 518:	learn: 27595.3966340	total: 57.2s	remaining: 20s
# 519:	learn: 27574.0992561	total: 57.3s	remaining: 19.8s
# 520:	learn: 27557.9805318	total: 57.4s	remaining: 19.7s
# 521:	learn: 27514.2293121	total: 57.6s	remaining: 19.6s
# 522:	learn: 27495.6716111	total: 57.7s	remaining: 19.5s
# 523:	learn: 27463.2868500	total: 57.8s	remaining: 19.4s
# 524:	learn: 27426.9186575	total: 57.9s	remaining: 19.3s
# 525:	learn: 27396.9434164	total: 58s	remaining: 19.2s
# 526:	learn: 27382.6760627	total: 58.1s	remaining: 19.1s
# 527:	learn: 27362.4482194	total: 58.2s	remaining: 19s
# 528:	learn: 27334.6219059	total: 58.3s	remaining: 18.9s
# 529:	learn: 27318.5440505	total: 58.4s	remaining: 18.7s
# 530:	learn: 27280.3620750	total: 58.6s	remaining: 18.6s
# 531:	learn: 27256.3780149	total: 58.7s	remaining: 18.5s
# 532:	learn: 27231.0981106	total: 58.8s	remaining: 18.4s
# 533:	learn: 27213.3964650	total: 58.9s	remaining: 18.3s
# 534:	learn: 27176.3168588	total: 59s	remaining: 18.2s
# 535:	learn: 27151.7071759	total: 59.1s	remaining: 18.1s
# 536:	learn: 27130.8736457	total: 59.2s	remaining: 18s
# 537:	learn: 27094.3066568	total: 59.3s	remaining: 17.9s
# 538:	learn: 27074.6989687	total: 59.4s	remaining: 17.8s
# 539:	learn: 27051.2187604	total: 59.5s	remaining: 17.6s
# 540:	learn: 27029.1819369	total: 59.7s	remaining: 17.5s
# 541:	learn: 27011.3925782	total: 59.8s	remaining: 17.4s
# 542:	learn: 26980.7333576	total: 59.9s	remaining: 17.3s
# 543:	learn: 26951.5163387	total: 60s	remaining: 17.2s
# 544:	learn: 26927.3074350	total: 1m	remaining: 17.1s
# 545:	learn: 26898.1727645	total: 1m	remaining: 17s
# 546:	learn: 26876.8451661	total: 1m	remaining: 16.9s
# 547:	learn: 26857.6128399	total: 1m	remaining: 16.8s
# 548:	learn: 26829.9638631	total: 1m	remaining: 16.6s
# 549:	learn: 26790.3968555	total: 1m	remaining: 16.5s
# 550:	learn: 26756.8097076	total: 1m	remaining: 16.4s
# 551:	learn: 26741.9704632	total: 1m	remaining: 16.3s
# 552:	learn: 26715.0404314	total: 1m 1s	remaining: 16.2s
# 553:	learn: 26706.5611975	total: 1m 1s	remaining: 16.1s
# 554:	learn: 26665.5296986	total: 1m 1s	remaining: 16s
# 555:	learn: 26652.1167915	total: 1m 1s	remaining: 15.9s
# 556:	learn: 26632.4461816	total: 1m 1s	remaining: 15.8s
# 557:	learn: 26611.9530232	total: 1m 1s	remaining: 15.7s
# 558:	learn: 26572.9609388	total: 1m 1s	remaining: 15.6s
# 559:	learn: 26542.2524986	total: 1m 2s	remaining: 15.5s
# 560:	learn: 26524.2619297	total: 1m 2s	remaining: 15.4s
# 561:	learn: 26494.0571939	total: 1m 2s	remaining: 15.3s
# 562:	learn: 26474.8761346	total: 1m 2s	remaining: 15.2s
# 563:	learn: 26450.0640742	total: 1m 2s	remaining: 15.1s
# 564:	learn: 26435.1624268	total: 1m 2s	remaining: 15s
# 565:	learn: 26420.3721234	total: 1m 2s	remaining: 14.9s
# 566:	learn: 26390.6735438	total: 1m 2s	remaining: 14.8s
# 567:	learn: 26362.1782106	total: 1m 3s	remaining: 14.7s
# 568:	learn: 26344.6469607	total: 1m 3s	remaining: 14.5s
# 569:	learn: 26318.5424241	total: 1m 3s	remaining: 14.4s
# 570:	learn: 26294.5681329	total: 1m 3s	remaining: 14.3s
# 571:	learn: 26269.4834248	total: 1m 3s	remaining: 14.2s
# 572:	learn: 26261.5397321	total: 1m 3s	remaining: 14.1s
# 573:	learn: 26234.3275592	total: 1m 3s	remaining: 14s
# 574:	learn: 26221.0973482	total: 1m 3s	remaining: 13.9s
# 575:	learn: 26203.4202016	total: 1m 3s	remaining: 13.8s
# 576:	learn: 26180.9993898	total: 1m 4s	remaining: 13.7s
# 577:	learn: 26143.3274031	total: 1m 4s	remaining: 13.6s
# 578:	learn: 26124.1511500	total: 1m 4s	remaining: 13.4s
# 579:	learn: 26103.7786087	total: 1m 4s	remaining: 13.3s
# 580:	learn: 26055.3526572	total: 1m 4s	remaining: 13.2s
# 581:	learn: 26018.8798160	total: 1m 4s	remaining: 13.1s
# 582:	learn: 25988.8984092	total: 1m 4s	remaining: 13s
# 583:	learn: 25967.3646787	total: 1m 5s	remaining: 12.9s
# 584:	learn: 25955.5352008	total: 1m 5s	remaining: 12.8s
# 585:	learn: 25947.9973217	total: 1m 5s	remaining: 12.7s
# 586:	learn: 25921.6829177	total: 1m 5s	remaining: 12.6s
# 587:	learn: 25904.0104475	total: 1m 5s	remaining: 12.5s
# 588:	learn: 25884.2426348	total: 1m 5s	remaining: 12.4s
# 589:	learn: 25861.6020813	total: 1m 5s	remaining: 12.3s
# 590:	learn: 25828.8944602	total: 1m 5s	remaining: 12.2s
# 591:	learn: 25802.8452481	total: 1m 6s	remaining: 12.1s
# 592:	learn: 25777.3860013	total: 1m 6s	remaining: 11.9s
# 593:	learn: 25751.5656425	total: 1m 6s	remaining: 11.8s
# 594:	learn: 25739.6038225	total: 1m 6s	remaining: 11.7s
# 595:	learn: 25719.9610784	total: 1m 6s	remaining: 11.6s
# 596:	learn: 25690.2626155	total: 1m 6s	remaining: 11.5s
# 597:	learn: 25652.8288124	total: 1m 6s	remaining: 11.4s
# 598:	learn: 25627.8901184	total: 1m 6s	remaining: 11.3s
# 599:	learn: 25616.9696586	total: 1m 6s	remaining: 11.2s
# 600:	learn: 25595.5379461	total: 1m 7s	remaining: 11.1s
# 601:	learn: 25577.3882750	total: 1m 7s	remaining: 10.9s
# 602:	learn: 25563.9564748	total: 1m 7s	remaining: 10.8s
# 603:	learn: 25546.1509615	total: 1m 7s	remaining: 10.7s
# 604:	learn: 25532.1904219	total: 1m 7s	remaining: 10.6s
# 605:	learn: 25501.5277321	total: 1m 7s	remaining: 10.5s
# 606:	learn: 25474.7144108	total: 1m 7s	remaining: 10.4s
# 607:	learn: 25447.3320916	total: 1m 7s	remaining: 10.3s
# 608:	learn: 25436.7744595	total: 1m 8s	remaining: 10.2s
# 609:	learn: 25420.8994704	total: 1m 8s	remaining: 10s
# 610:	learn: 25394.6518026	total: 1m 8s	remaining: 9.94s
# 611:	learn: 25385.5114763	total: 1m 8s	remaining: 9.83s
# 612:	learn: 25356.5818614	total: 1m 8s	remaining: 9.72s
# 613:	learn: 25346.0395903	total: 1m 8s	remaining: 9.61s
# 614:	learn: 25328.5419228	total: 1m 8s	remaining: 9.49s
# 615:	learn: 25309.6422774	total: 1m 8s	remaining: 9.38s
# 616:	learn: 25292.3744780	total: 1m 8s	remaining: 9.27s
# 617:	learn: 25271.2410721	total: 1m 9s	remaining: 9.16s
# 618:	learn: 25251.8715046	total: 1m 9s	remaining: 9.05s
# 619:	learn: 25235.4227135	total: 1m 9s	remaining: 8.94s
# 620:	learn: 25214.1496116	total: 1m 9s	remaining: 8.82s
# 621:	learn: 25203.2645135	total: 1m 9s	remaining: 8.71s
# 622:	learn: 25186.0887333	total: 1m 9s	remaining: 8.6s
# 623:	learn: 25168.4047983	total: 1m 9s	remaining: 8.49s
# 624:	learn: 25149.2760512	total: 1m 9s	remaining: 8.38s
# 625:	learn: 25137.7616069	total: 1m 9s	remaining: 8.26s
# 626:	learn: 25119.4078082	total: 1m 10s	remaining: 8.15s
# 627:	learn: 25108.6926987	total: 1m 10s	remaining: 8.04s
# 628:	learn: 25101.3800472	total: 1m 10s	remaining: 7.93s
# 629:	learn: 25080.3958800	total: 1m 10s	remaining: 7.82s
# 630:	learn: 25032.9100963	total: 1m 10s	remaining: 7.71s
# 631:	learn: 25022.8552190	total: 1m 10s	remaining: 7.59s
# 632:	learn: 25011.2538752	total: 1m 10s	remaining: 7.48s
# 633:	learn: 24980.1507186	total: 1m 10s	remaining: 7.37s
# 634:	learn: 24958.8208604	total: 1m 10s	remaining: 7.26s
# 635:	learn: 24938.8272134	total: 1m 11s	remaining: 7.14s
# 636:	learn: 24925.3597923	total: 1m 11s	remaining: 7.03s
# 637:	learn: 24914.4161181	total: 1m 11s	remaining: 6.92s
# 638:	learn: 24892.4568828	total: 1m 11s	remaining: 6.81s
# 639:	learn: 24863.6279247	total: 1m 11s	remaining: 6.7s
# 640:	learn: 24855.8183677	total: 1m 11s	remaining: 6.58s
# 641:	learn: 24829.7766258	total: 1m 11s	remaining: 6.47s
# 642:	learn: 24813.1578649	total: 1m 11s	remaining: 6.36s
# 643:	learn: 24794.7450324	total: 1m 11s	remaining: 6.25s
# 644:	learn: 24774.4860982	total: 1m 11s	remaining: 6.14s
# 645:	learn: 24746.8851716	total: 1m 12s	remaining: 6.03s
# 646:	learn: 24734.4527120	total: 1m 12s	remaining: 5.92s
# 647:	learn: 24705.7340701	total: 1m 12s	remaining: 5.81s
# 648:	learn: 24695.7964445	total: 1m 12s	remaining: 5.7s
# 649:	learn: 24669.3979405	total: 1m 12s	remaining: 5.58s
# 650:	learn: 24637.4847027	total: 1m 12s	remaining: 5.47s
# 651:	learn: 24627.2394931	total: 1m 12s	remaining: 5.36s
# 652:	learn: 24601.2177835	total: 1m 12s	remaining: 5.25s
# 653:	learn: 24575.8244705	total: 1m 13s	remaining: 5.14s
# 654:	learn: 24547.2669277	total: 1m 13s	remaining: 5.03s
# 655:	learn: 24520.0798002	total: 1m 13s	remaining: 4.92s
# 656:	learn: 24494.3658306	total: 1m 13s	remaining: 4.8s
# 657:	learn: 24475.9420339	total: 1m 13s	remaining: 4.69s
# 658:	learn: 24451.4133179	total: 1m 13s	remaining: 4.58s
# 659:	learn: 24428.3588278	total: 1m 13s	remaining: 4.47s
# 660:	learn: 24394.5889161	total: 1m 13s	remaining: 4.36s
# 661:	learn: 24386.1112816	total: 1m 14s	remaining: 4.25s
# 662:	learn: 24368.0401685	total: 1m 14s	remaining: 4.14s
# 663:	learn: 24337.2657022	total: 1m 14s	remaining: 4.03s
# 664:	learn: 24319.7827508	total: 1m 14s	remaining: 3.92s
# 665:	learn: 24298.1813699	total: 1m 14s	remaining: 3.8s
# 666:	learn: 24288.6099482	total: 1m 14s	remaining: 3.69s
# 667:	learn: 24268.9504840	total: 1m 14s	remaining: 3.58s
# 668:	learn: 24259.8250912	total: 1m 14s	remaining: 3.47s
# 669:	learn: 24230.1329184	total: 1m 14s	remaining: 3.35s
# 670:	learn: 24211.7313017	total: 1m 15s	remaining: 3.24s
# 671:	learn: 24191.1508841	total: 1m 15s	remaining: 3.13s
# 672:	learn: 24156.5310505	total: 1m 15s	remaining: 3.02s
# 673:	learn: 24138.6135137	total: 1m 15s	remaining: 2.91s
# 674:	learn: 24103.0393451	total: 1m 15s	remaining: 2.8s
# 675:	learn: 24065.6785332	total: 1m 15s	remaining: 2.69s
# 676:	learn: 24042.8511783	total: 1m 15s	remaining: 2.57s
# 677:	learn: 24014.0431124	total: 1m 15s	remaining: 2.46s
# 678:	learn: 23994.0238384	total: 1m 15s	remaining: 2.35s
# 679:	learn: 23970.5321014	total: 1m 16s	remaining: 2.24s
# 680:	learn: 23939.7300194	total: 1m 16s	remaining: 2.13s
# 681:	learn: 23932.5046193	total: 1m 16s	remaining: 2.01s
# 682:	learn: 23908.8074359	total: 1m 16s	remaining: 1.9s
# 683:	learn: 23897.0465100	total: 1m 16s	remaining: 1.79s
# 684:	learn: 23871.4547914	total: 1m 16s	remaining: 1.68s
# 685:	learn: 23860.0026443	total: 1m 16s	remaining: 1.57s
# 686:	learn: 23844.6018107	total: 1m 16s	remaining: 1.46s
# 687:	learn: 23828.2897383	total: 1m 17s	remaining: 1.34s
# 688:	learn: 23807.9012957	total: 1m 17s	remaining: 1.23s
# 689:	learn: 23770.9011524	total: 1m 17s	remaining: 1.12s
# 690:	learn: 23754.5564348	total: 1m 17s	remaining: 1.01s
# 691:	learn: 23728.2750294	total: 1m 17s	remaining: 896ms
# 692:	learn: 23700.8821876	total: 1m 17s	remaining: 784ms
# 693:	learn: 23676.8492266	total: 1m 17s	remaining: 672ms
# 694:	learn: 23661.9045628	total: 1m 17s	remaining: 560ms
# 695:	learn: 23647.5470138	total: 1m 17s	remaining: 448ms
# 696:	learn: 23636.0669053	total: 1m 18s	remaining: 336ms
# 697:	learn: 23621.4866332	total: 1m 18s	remaining: 224ms
# 698:	learn: 23601.5908425	total: 1m 18s	remaining: 112ms
# 699:	learn: 23593.9185745	total: 1m 18s	remaining: 0us

# %% [markdown]
# # Test

# %%
X_test = pd.read_csv('/kaggle/input/nsu-jobs/nsu-bda-2023-jobs/X_test.csv')
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9312 entries, 0 to 9311
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        9312 non-null   int64
#  1   name                      9312 non-null   object
#  2   has_test                  9312 non-null   bool
#  3   response_letter_required  9312 non-null   bool
#  4   salary_from               7924 non-null   float64
#  5   salary_currency           9312 non-null   object
#  6   salary_gross              9263 non-null   object
#  7   published_at              9312 non-null   object
#  8   created_at                9312 non-null   object
#  9   employer_name             9312 non-null   object
#  10  description               9312 non-null   object
#  11  area_id                   9312 non-null   int64
#  12  area_name                 9312 non-null   object
# dtypes: bool(2), float64(1), int64(2), object(8)
# memory usage: 818.6+ KB

# %%
X_test.description = X_test.description.fillna('')
X_test.published_at = pd.to_datetime(X_test.published_at, errors='raise')
X_test.created_at = pd.to_datetime(X_test.created_at, errors='raise')
X_test['timestamp'] = (X_test.published_at.astype('int64') / 10**9)
X_test.salary_gross=X_test.salary_gross.astype('bool')
X_test.loc[X_test.salary_gross, 'salary_from'] = X_test.loc[X_test.salary_gross].salary_from*1.13

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9312 entries, 0 to 9311
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        9312 non-null   int64
#  1   name                      9312 non-null   object
#  2   has_test                  9312 non-null   bool
#  3   response_letter_required  9312 non-null   bool
#  4   salary_from               7924 non-null   float64
#  5   salary_currency           9312 non-null   object
#  6   salary_gross              9312 non-null   bool
#  7   published_at              9312 non-null   datetime64[ns, UTC]
#  8   created_at                9312 non-null   datetime64[ns, UTC]
#  9   employer_name             9312 non-null   object
#  10  description               9312 non-null   object
#  11  area_id                   9312 non-null   int64
#  12  area_name                 9312 non-null   object
#  13  timestamp                 9312 non-null   float64
# dtypes: bool(3), datetime64[ns, UTC](2), float64(2), int64(2), object(5)
# memory usage: 827.7+ KB

# %%
from tqdm import tqdm
names1_test = []
names2_test = []
names3_test = []
for t in tqdm(X_test.name):
    title = preprocess_title(t)
    if(len(title)>=3):
        names1_test.append(title[0])
        names2_test.append(title[1])
        names3_test.append(title[2])
        continue
    elif(len(title)>=2):
        names1_test.append(title[0])
        names2_test.append(title[1])
        names3_test.append('')
        continue
    elif(len(title)>=1):
        names1_test.append(title[0])
        names2_test.append('')
        names3_test.append('')
    else:
        names1_test.append('')
        names2_test.append('')
        names3_test.append('')
# Out:
# 100%|██████████| 9312/9312 [00:17<00:00, 539.07it/s]

# %%
X_test['start_name1'] = names1_test
X_test['start_name2'] = names2_test
X_test['start_name3'] = names3_test

# %%
title_counts_test = Counter(X_test['name'].apply(lambda x: " ".join(preprocess_title(x))).values)
del title_counts_test['']
title_counts_test.most_common(10)
# Out:
# [('менеджер продажа', 110),
#  ('менеджер работа клиент', 70),
#  ('юрист', 62),
#  ('frontend разработчик', 56),
#  ('помощник юрист', 54),
#  ('уборщица уборщик', 49),
#  ('копирайтер', 48),
#  ('аналитик', 44),
#  ('продавец консультант', 40),
#  ('менеджер закупка', 39)]

# %%
optimum_titless_test = []
optimum_countss_test = []

for title in tqdm(X_test.name):
    optimum_title = optimize_title(title, title_counts=title_counts_test)
    optimum_count = title_counts[optimum_title]
    optimum_titless_test.append(optimum_title)
    optimum_countss_test.append(optimum_count)
# Out:
# 100%|██████████| 9312/9312 [00:18<00:00, 513.12it/s]

# %%
X_test['optimum_title'] = optimum_titless_test

# %%
if(os.path.exists("/kaggle/input/nsu-jobs/tokens_description_plus_lemment_mod0_test.pkl")):
    with open("/kaggle/input/nsu-jobs/tokens_description_plus_lemment_mod0_test.pkl", 'rb') as file:
        tokens_description_lemm_mod0_test = pickle.load(file)
else:
    tokens_description_lemm_mod0_test=[tokenize(a,is_lemmatization=True,mod = 0) for a in tqdm(X_test.description)]
    with open('tokens_description_plus_lemment_mod0_test.pkl', 'wb') as file:
        pickle.dump(tokens_description_lemm_mod0_test, file)

# %%
# h_exp_full_test = [desc_to_tokens(a, False, False) for a in tokens_description_lemm_mod0_test]
# h1_exp_full_test = [get_experience(u) for u in h_exp_full_test]
# len(h_exp_full_test),len(h1_exp_full_test)

# %%
if(os.path.exists("/kaggle/input/nsu-jobs/tokens_description_plus_lemment_mod0_eng_test.pkl")):
    with open("/kaggle/input/nsu-jobs/tokens_description_plus_lemment_mod0_eng_test.pkl", 'rb') as file:
        h_eng_full_test = pickle.load(file)
else:
    h_eng_full_test = [desc_to_tokens(a, True) for a in tqdm(tokens_description_lemm_mod0_test)]
    with open('tokens_description_plus_lemment_mod0_eng_test.pkl', 'wb') as file:
        pickle.dump(h_eng_full_test, file)

# %%
if(os.path.exists("/kaggle/input/nsu-jobs/ExpEng_test.csv")):
    EngExp_test = pd.read_csv("/kaggle/input/nsu-jobs/ExpEng_test.csv")
    X_test=X_test.merge(EngExp_test ,how='left', on='id')
    X_test.eng = X_test.eng.fillna('')
else:
    h_exp_full_test = [desc_to_tokens(a, False, False) for a in tokens_description_lemm_mod0_test]
    h1_exp_full_test = [get_experience(u) for u in h_exp_full_test]
    
    h1_eng_full_test = [get_english(t) for t in h_eng_full_test]
    
    X_test['exp'] = h1_exp_full_test
    X_test['eng'] = h1_eng_full_test
    X_test[['id','exp','eng']].to_csv('ExpEng_test.csv', index=False)
    X_train.eng = X_train.eng.fillna('')

# %%
# h_eng_full_test = [desc_to_tokens(a, True) for a in tqdm(tokens_description_full_test)]
# h1_eng_full_test = [get_english(t) for t in h_eng_full_test]
# len(h_eng_full_test ),len(h1_eng_full_test)

# %%
# X_test['exp'] = h1_exp_full_test
# X_test['eng'] = h1_eng_full_test
# X_test[['id','exp','eng']].to_csv('ExpEng_test.csv', index=False)

# %%
# EngExp_test = pd.read_csv("/kaggle/input/nsu-jobs/ExpEng_test.csv")
# X_test=X_test.merge(EngExp_test ,how='left', on='id')
# X_test.eng = X_test.eng.fillna('')

# %%
desc_is_bonus_test=[is_bonus(t) for t in tokens_description_lemm_mod0_test]
len(desc_is_bonus_test)
# Out:
# 9312

# %%
X_test['is_bonus']=desc_is_bonus_test

# %%
import pickle
if(os.path.exists("/kaggle/input/nsu-jobs/tokens_description_plus_lemment_mod1_test.pkl")):
    with open("/kaggle/input/nsu-jobs/tokens_description_plus_lemment_mod1_test.pkl", 'rb') as file:
        tokens_description_lemm_mod1_test = pickle.load(file)
else:
    tokens_description_lemm_mod1_test = [tokenize(d,is_lemmatization=True,mod = 1) for d in tqdm(X_test['description'])]
    with open('tokens_description_plus_lemment_mod1_test.pkl', 'wb') as file:
        pickle.dump(tokens_description_lemm_mod1_test, file)

# %%
descs_tokens_rus_test = list(map(lambda desc: list(filter(lambda token: is_rus(token), desc)), tokens_description_lemm_mod1_test))
len(descs_tokens_rus_test)
# Out:
# 9312

# %%
descs_tokens_full_test = [desc_to_tokens(d) for d in descs_tokens_rus_test]

# %%
oklads_full_test = [find_salary(descs_token) for descs_token in descs_tokens_full_test]

# %%
salary_min_desc_full_test = []
salary_max_desc_full_test = []
for ind, oklad in enumerate(oklads_full_test):
    salary_from = X_train.salary_from[ind]
    if(oklad[1]==salary_from):
        salary_min_desc_full_test.append(oklad[1])
        salary_max_desc_full_test.append(None)
    else:
        salary_min_desc_full_test.append(oklad[0])
        salary_max_desc_full_test.append(oklad[1])

# %%
X_test['salary_min_desc']=salary_min_desc_full_test
X_test['salary_max_desc']=salary_max_desc_full_test
X_test.loc[((X_test.salary_from>X_test.salary_max_desc) | (abs(X_test['salary_min_desc']-X_test.salary_from)>X_test.salary_from*0.1)),['salary_min_desc', 'salary_max_desc']] = None

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9312 entries, 0 to 9311
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        9312 non-null   int64
#  1   name                      9312 non-null   object
#  2   has_test                  9312 non-null   bool
#  3   response_letter_required  9312 non-null   bool
#  4   salary_from               7924 non-null   float64
#  5   salary_currency           9312 non-null   object
#  6   salary_gross              9312 non-null   bool
#  7   published_at              9312 non-null   datetime64[ns, UTC]
#  8   created_at                9312 non-null   datetime64[ns, UTC]
#  9   employer_name             9312 non-null   object
#  10  description               9312 non-null   object
#  11  area_id                   9312 non-null   int64
#  12  area_name                 9312 non-null   object
#  13  timestamp                 9312 non-null   float64
#  14  start_name1               9312 non-null   object
#  15  start_name2               9312 non-null   object
#  16  start_name3               9312 non-null   object
#  17  optimum_title             9312 non-null   object
#  18  exp                       9312 non-null   float64
#  19  eng                       9312 non-null   object
#  20  is_bonus                  9312 non-null   bool
#  21  salary_min_desc           750 non-null    float64
#  22  salary_max_desc           1244 non-null   float64
# dtypes: bool(4), datetime64[ns, UTC](2), float64(5), int64(2), object(10)
# memory usage: 1.4+ MB

# %%
agg_prof1_emp_test = X_test.groupby(['start_name1','employer_name'],sort=False).agg(
    salary_mean_prof1_emp = ('salary_from', lambda x: np.mean(x)),
)

agg_prof2_emp_test = X_test.groupby(['start_name2','employer_name'],sort=False).agg(
    salary_mean_prof2_emp = ('salary_from', lambda x: np.mean(x)),
)

agg_prof3_emp_test = X_test.groupby(['start_name3','employer_name'],sort=False).agg(
    salary_mean_prof3_emp = ('salary_from', lambda x: np.mean(x)),
)

agg_emp_area_test = X_test.groupby(['employer_name','area_id'],sort=False).agg(
    salary_mean_emp_area = ('salary_from', lambda x: np.mean(x)),
)
agg_prof1_area_test = X_test.groupby(['start_name1','area_id'],sort=False).agg(
    salary_mean_prof1_area = ('salary_from', lambda x: np.mean(x)),
)
agg_emp_test = X_test.groupby(['employer_name',],sort=False).agg(
    salary_mean_emp = ('salary_from', lambda x: np.mean(x)),
)
agg_prof_test = X_test.groupby(['start_name1',],sort=False).agg(
    salary_mean_prof = ('salary_from', lambda x: np.mean(x)),
)
agg_area_test = X_test.groupby(['area_id',],sort=False).agg(
    salary_mean_area = ('salary_from', lambda x: np.mean(x)),
)
agg_all_test = X_test.salary_from.mean()

agg_prof12_test = X_test.groupby(['start_name1','start_name2',],sort=False).agg(
    salary_mean_prof12 = ('salary_from', lambda x: np.mean(x)),
)
agg_prof13_test = X_test.groupby(['start_name1','start_name3',],sort=False).agg(
    salary_mean_prof13 = ('salary_from', lambda x: np.mean(x)),
)
agg_prof23_test = X_test.groupby(['start_name2','start_name3',],sort=False).agg(
    salary_mean_prof23 = ('salary_from', lambda x: np.mean(x)),
)

agg_opt_emp_test = X_test.groupby(['optimum_title','employer_name'],sort=False).agg(
    salary_mean_opt_emp = ('salary_from', lambda x: np.mean(x)),
)

agg_opt_area_test = X_test.groupby(['optimum_title','area_id'],sort=False).agg(
    salary_mean_opt_area = ('salary_from', lambda x: np.mean(x)),
)

agg_opt_test = X_test.groupby(['optimum_title'],sort=False).agg(
    salary_mean_opt = ('salary_from', lambda x: np.mean(x)),
)
agg_opt_prof1_test = X_test.groupby(['optimum_title', 'start_name1'],sort=False).agg(
    salary_mean_opt_prof1 = ('salary_from', lambda x: np.mean(x)),
)

# %%
agg_opt_emp_test.reset_index(inplace=True)
agg_opt_area_test.reset_index(inplace=True)
agg_opt_test.reset_index(inplace=True)
agg_opt_prof1_test.reset_index(inplace=True)

agg_prof1_emp_test.reset_index(inplace=True)
agg_prof2_emp_test.reset_index(inplace=True)
agg_prof3_emp_test.reset_index(inplace=True)
agg_emp_area_test.reset_index(inplace=True)
agg_prof1_area_test.reset_index(inplace=True)
agg_emp_test.reset_index(inplace=True)
agg_prof_test.reset_index(inplace=True)
agg_area_test.reset_index(inplace=True)
agg_prof12_test.reset_index(inplace=True)
agg_prof13_test.reset_index(inplace=True)
agg_prof23_test.reset_index(inplace=True)

agg_opt_emp_test=agg_opt_emp_test.dropna()
agg_opt_area_test=agg_opt_area_test.dropna()
agg_opt_test=agg_opt_test.dropna()
agg_opt_prof1_test=agg_opt_prof1_test.dropna()

agg_prof1_emp_test = agg_prof1_emp_test.dropna()
agg_prof2_emp_test = agg_prof2_emp_test.dropna()
agg_prof3_emp_test = agg_prof3_emp_test.dropna()
agg_emp_area_test = agg_emp_area_test.dropna()
agg_prof1_area_test = agg_prof1_area_test.dropna()
agg_emp_test = agg_emp_test.dropna()
agg_prof_test = agg_prof_test.dropna()
agg_area_test = agg_area_test.dropna()
agg_prof12_test = agg_prof12_test.dropna()
agg_prof13_test= agg_prof13_test.dropna()
agg_prof23_test = agg_prof23_test.dropna()

# %%
X_test2 = X_test.copy()
without_salary_test = X_test2[X_test2.salary_from.isnull()]

# %%
without_salary_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1388 entries, 10 to 9310
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1388 non-null   int64
#  1   name                      1388 non-null   object
#  2   has_test                  1388 non-null   bool
#  3   response_letter_required  1388 non-null   bool
#  4   salary_from               0 non-null      float64
#  5   salary_currency           1388 non-null   object
#  6   salary_gross              1388 non-null   bool
#  7   published_at              1388 non-null   datetime64[ns, UTC]
#  8   created_at                1388 non-null   datetime64[ns, UTC]
#  9   employer_name             1388 non-null   object
#  10  description               1388 non-null   object
#  11  area_id                   1388 non-null   int64
#  12  area_name                 1388 non-null   object
#  13  timestamp                 1388 non-null   float64
#  14  start_name1               1388 non-null   object
#  15  start_name2               1388 non-null   object
#  16  start_name3               1388 non-null   object
#  17  optimum_title             1388 non-null   object
#  18  exp                       1388 non-null   float64
#  19  eng                       1388 non-null   object
#  20  is_bonus                  1388 non-null   bool
#  21  salary_min_desc           83 non-null     float64
#  22  salary_max_desc           257 non-null    float64
# dtypes: bool(4), datetime64[ns, UTC](2), float64(5), int64(2), object(10)
# memory usage: 222.3+ KB

# %%
without_salary_test = without_salary_test.merge(agg_opt_emp_test, on=['optimum_title','employer_name'], how='left')
without_salary_test = without_salary_test.merge(agg_opt_area_test, on=['optimum_title','area_id'], how='left')
without_salary_test = without_salary_test.merge(agg_opt_test, on=['optimum_title'], how='left')
without_salary_test = without_salary_test.merge(agg_opt_prof1_test, on=['optimum_title', 'start_name1'], how='left')

without_salary_test = without_salary_test.merge(agg_prof12_test, on=['start_name1','start_name2'], how='left')
without_salary_test = without_salary_test.merge(agg_prof13_test, on=['start_name1','start_name3'], how='left')
without_salary_test= without_salary_test.merge(agg_prof23_test, on=['start_name2','start_name3'], how='left')

without_salary_test = without_salary_test.merge(agg_prof1_emp_test, on=['start_name1','employer_name'], how='left')
without_salary_test = without_salary_test.merge(agg_prof2_emp_test, on=['start_name2','employer_name'], how='left')
without_salary_test = without_salary_test.merge(agg_prof3_emp_test, on=['start_name3','employer_name'], how='left')

without_salary_test = without_salary_test.merge(agg_emp_area_test, on=['employer_name','area_id'], how='left')
without_salary_test = without_salary_test.merge(agg_prof1_area_test, on=['start_name1','area_id'], how='left')
without_salary_test = without_salary_test.merge(agg_emp_test, on=['employer_name',], how='left')
without_salary_test = without_salary_test.merge(agg_prof_test, on=['start_name1',], how='left')
without_salary_test = without_salary_test.merge(agg_area_test, on=['area_id',], how='left')

# %%
from tqdm import tqdm
median_emp_test=[]
median_prof_test = []
for i in tqdm(range(len(without_salary_test))):
    row_values_emp_test = without_salary_test.loc[i, ['salary_mean_prof1_emp','salary_mean_prof2_emp', 'salary_mean_prof3_emp','salary_mean_opt_emp']]
    row_values_prof_test = without_salary_test.loc[i, ['salary_mean_opt_prof1','salary_mean_opt_area', 'salary_mean_opt','salary_mean_prof12','salary_mean_prof13','salary_mean_prof23','salary_mean_emp_area','salary_mean_prof1_area','salary_mean_emp','salary_mean_prof']]
    median_emp_test.append(row_values_emp_test.mean())
    median_prof_test.append(row_values_prof_test.mean())
# Out:
# 100%|██████████| 1388/1388 [00:01<00:00, 728.69it/s]

# %%
without_salary_test['median_emp'] = median_emp_test
without_salary_test['median_prof'] = median_prof_test
without_salary_test.loc[(without_salary_test.salary_from.isnull()),'salary_from'] = without_salary_test.loc[(without_salary_test.salary_from.isnull())].median_emp
without_salary_test.loc[(without_salary_test.salary_from.isnull()),'salary_from'] = without_salary_test.loc[(without_salary_test.salary_from.isnull())].median_prof
without_salary_test.loc[(without_salary_test.salary_from.isnull()),'salary_from'] = without_salary_test.loc[(without_salary_test.salary_from.isnull())].salary_mean_area
without_salary_test = without_salary_test.rename (columns= {'salary_from': 'salary_from_without'})

# %%
without_salary_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1388 entries, 0 to 1387
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1388 non-null   int64
#  1   name                      1388 non-null   object
#  2   has_test                  1388 non-null   bool
#  3   response_letter_required  1388 non-null   bool
#  4   salary_from_without       1388 non-null   float64
#  5   salary_currency           1388 non-null   object
#  6   salary_gross              1388 non-null   bool
#  7   published_at              1388 non-null   datetime64[ns, UTC]
#  8   created_at                1388 non-null   datetime64[ns, UTC]
#  9   employer_name             1388 non-null   object
#  10  description               1388 non-null   object
#  11  area_id                   1388 non-null   int64
#  12  area_name                 1388 non-null   object
#  13  timestamp                 1388 non-null   float64
#  14  start_name1               1388 non-null   object
#  15  start_name2               1388 non-null   object
#  16  start_name3               1388 non-null   object
#  17  optimum_title             1388 non-null   object
#  18  exp                       1388 non-null   float64
#  19  eng                       1388 non-null   object
#  20  is_bonus                  1388 non-null   bool
#  21  salary_min_desc           83 non-null     float64
#  22  salary_max_desc           257 non-null    float64
#  23  salary_mean_opt_emp       65 non-null     float64
#  24  salary_mean_opt_area      1146 non-null   float64
#  25  salary_mean_opt           1233 non-null   float64
#  26  salary_mean_opt_prof1     1097 non-null   float64
#  27  salary_mean_prof12        970 non-null    float64
#  28  salary_mean_prof13        959 non-null    float64
#  29  salary_mean_prof23        929 non-null    float64
#  30  salary_mean_prof1_emp     84 non-null     float64
#  31  salary_mean_prof2_emp     61 non-null     float64
#  32  salary_mean_prof3_emp     136 non-null    float64
#  33  salary_mean_emp_area      413 non-null    float64
#  34  salary_mean_prof1_area    1256 non-null   float64
#  35  salary_mean_emp           496 non-null    float64
#  36  salary_mean_prof          1339 non-null   float64
#  37  salary_mean_area          1380 non-null   float64
#  38  median_emp                200 non-null    float64
#  39  median_prof               1375 non-null   float64
# dtypes: bool(4), datetime64[ns, UTC](2), float64(22), int64(2), object(10)
# memory usage: 395.9+ KB

# %%
X_test2 = X_test.copy()
X_test2 = X_test2.merge(agg_opt_emp_test, on=['optimum_title','employer_name'], how='left')
X_test2 =X_test2.merge(agg_opt_area_test, on=['optimum_title','area_id'], how='left')
X_test2 = X_test2.merge(agg_opt_test, on=['optimum_title'], how='left')
X_test2 =X_test2.merge(agg_opt_prof1_test, on=['optimum_title', 'start_name1'], how='left')

X_test2 = X_test2.merge(agg_prof12_test, on=['start_name1','start_name2'], how='left')
X_test2 = X_test2.merge(agg_prof13_test, on=['start_name1','start_name3'], how='left')
X_test2= X_test2.merge(agg_prof23_test, on=['start_name2','start_name3'], how='left')

X_test2 = X_test2.merge(agg_prof1_emp_test, on=['start_name1','employer_name'], how='left')
X_test2 = X_test2.merge(agg_prof2_emp_test, on=['start_name2','employer_name'], how='left')
X_test2 = X_test2.merge(agg_prof3_emp_test, on=['start_name3','employer_name'], how='left')

X_test2 = X_test2.merge(agg_emp_area_test, on=['employer_name','area_id'], how='left')
X_test2 = X_test2.merge(agg_prof1_area_test, on=['start_name1','area_id'], how='left')
X_test2 = X_test2.merge(agg_emp_test, on=['employer_name',], how='left')
X_test2 = X_test2.merge(agg_prof_test, on=['start_name1',], how='left')
X_test2 = X_test2.merge(agg_area_test, on=['area_id',], how='left')

# %%
X_test2= X_test2.merge(without_salary_test[['id','salary_from_without']], on='id', how='left')
X_test2.loc[(X_test2.salary_from.isnull()),'salary_from'] = X_test2.salary_from_without

# %%
X_test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9312 entries, 0 to 9311
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        9312 non-null   int64
#  1   name                      9312 non-null   object
#  2   has_test                  9312 non-null   bool
#  3   response_letter_required  9312 non-null   bool
#  4   salary_from               9312 non-null   float64
#  5   salary_currency           9312 non-null   object
#  6   salary_gross              9312 non-null   bool
#  7   published_at              9312 non-null   datetime64[ns, UTC]
#  8   created_at                9312 non-null   datetime64[ns, UTC]
#  9   employer_name             9312 non-null   object
#  10  description               9312 non-null   object
#  11  area_id                   9312 non-null   int64
#  12  area_name                 9312 non-null   object
#  13  timestamp                 9312 non-null   float64
#  14  start_name1               9312 non-null   object
#  15  start_name2               9312 non-null   object
#  16  start_name3               9312 non-null   object
#  17  optimum_title             9312 non-null   object
#  18  exp                       9312 non-null   float64
#  19  eng                       9312 non-null   object
#  20  is_bonus                  9312 non-null   bool
#  21  salary_min_desc           750 non-null    float64
#  22  salary_max_desc           1244 non-null   float64
#  23  salary_mean_opt_emp       7989 non-null   float64
#  24  salary_mean_opt_area      9070 non-null   float64
#  25  salary_mean_opt           9157 non-null   float64
#  26  salary_mean_opt_prof1     9021 non-null   float64
#  27  salary_mean_prof12        8894 non-null   float64
#  28  salary_mean_prof13        8883 non-null   float64
#  29  salary_mean_prof23        8853 non-null   float64
#  30  salary_mean_prof1_emp     8008 non-null   float64
#  31  salary_mean_prof2_emp     7985 non-null   float64
#  32  salary_mean_prof3_emp     8060 non-null   float64
#  33  salary_mean_emp_area      8337 non-null   float64
#  34  salary_mean_prof1_area    9180 non-null   float64
#  35  salary_mean_emp           8420 non-null   float64
#  36  salary_mean_prof          9263 non-null   float64
#  37  salary_mean_area          9304 non-null   float64
#  38  salary_from_without       1388 non-null   float64
# dtypes: bool(4), datetime64[ns, UTC](2), float64(21), int64(2), object(10)
# memory usage: 2.5+ MB

# %%
X_test = X_test2.drop(columns=["id", "description","salary_currency", 'published_at', 'created_at', 'salary_from_without'])

# %%
X_test[X_test.loc[:, X_test.dtypes == object].columns] = X_test.loc[:, X_test.dtypes == object].astype('category')

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9312 entries, 0 to 9311
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name                      9312 non-null   category
#  1   has_test                  9312 non-null   bool
#  2   response_letter_required  9312 non-null   bool
#  3   salary_from               9312 non-null   float64
#  4   salary_gross              9312 non-null   bool
#  5   employer_name             9312 non-null   category
#  6   area_id                   9312 non-null   int64
#  7   area_name                 9312 non-null   category
#  8   timestamp                 9312 non-null   float64
#  9   start_name1               9312 non-null   category
#  10  start_name2               9312 non-null   category
#  11  start_name3               9312 non-null   category
#  12  optimum_title             9312 non-null   category
#  13  exp                       9312 non-null   float64
#  14  eng                       9312 non-null   category
#  15  is_bonus                  9312 non-null   bool
#  16  salary_min_desc           750 non-null    float64
#  17  salary_max_desc           1244 non-null   float64
#  18  salary_mean_opt_emp       7989 non-null   float64
#  19  salary_mean_opt_area      9070 non-null   float64
#  20  salary_mean_opt           9157 non-null   float64
#  21  salary_mean_opt_prof1     9021 non-null   float64
#  22  salary_mean_prof12        8894 non-null   float64
#  23  salary_mean_prof13        8883 non-null   float64
#  24  salary_mean_prof23        8853 non-null   float64
#  25  salary_mean_prof1_emp     8008 non-null   float64
#  26  salary_mean_prof2_emp     7985 non-null   float64
#  27  salary_mean_prof3_emp     8060 non-null   float64
#  28  salary_mean_emp_area      8337 non-null   float64
#  29  salary_mean_prof1_area    9180 non-null   float64
#  30  salary_mean_emp           8420 non-null   float64
#  31  salary_mean_prof          9263 non-null   float64
#  32  salary_mean_area          9304 non-null   float64
# dtypes: bool(4), category(8), float64(20), int64(1)
# memory usage: 2.1 MB

# %%
y_pred_test = cat.predict(X_test)

# %%
qw_test = pd.DataFrame({ 'X_from': X_test.salary_from, 'y_pred': y_pred_test,'salary_max_desc':X_test.salary_max_desc, 'y_pred_copy': y_pred_test  })

# %%
qw_test.loc[~qw_test.salary_max_desc.isnull(),'y_pred'] = qw_test.loc[~qw_test.salary_max_desc.isnull()].salary_max_desc
qw_test.loc[~qw_test.salary_max_desc.isnull()]
# Out:
#         X_from    y_pred  salary_max_desc    y_pred_copy
# 2     200000.0  200000.0         200000.0  306619.099444
# 30     80000.0  100000.0         100000.0  139095.500540
# 33     40000.0   55000.0          55000.0   60825.013931
# 34     30000.0   40000.0          40000.0   41257.974703
# 37     50000.0   60000.0          60000.0   53688.364632
# ...        ...       ...              ...            ...
# 9270   80000.0   80000.0          80000.0  121984.938074
# 9294  190000.0  340000.0         340000.0  279723.865027
# 9295   45000.0   75000.0          75000.0   57908.295417
# 9305   60000.0  140000.0         140000.0  114992.245519
# 9306   60000.0   80000.0          80000.0  128472.344363
#
# [1244 rows x 4 columns]

# %%
qw_test.loc[((~qw_test.salary_max_desc.isnull()) &(qw_test.y_pred>qw_test.X_from*2)  )]
# Out:
#             X_from    y_pred  salary_max_desc    y_pred_copy
# 132   84000.000000  180000.0         180000.0  170807.751285
# 166   15000.000000   40000.0          40000.0   32187.595073
# 213   95000.000000  350000.0         350000.0  257625.069863
# 250   21000.000000   45000.0          45000.0   39451.934040
# 259   55000.000000  150000.0         150000.0  117236.694303
# ...            ...       ...              ...            ...
# 8976  30000.000000  100000.0         100000.0   91322.635511
# 9064  32200.000000   82000.0          82000.0   45866.102191
# 9177  55195.569284  238000.0         238000.0  154551.854336
# 9195  25000.000000   80000.0          80000.0   72265.713587
# 9305  60000.000000  140000.0         140000.0  114992.245519
#
# [178 rows x 4 columns]

# %%
qw_test.loc[((~qw_test.salary_max_desc.isnull()) &(qw_test.y_pred>qw_test.X_from*2)  ), 'y_pred'] = qw_test.loc[((~qw_test.salary_max_desc.isnull()) &(qw_test.y_pred>qw_test.X_from*2))].y_pred_copy

# %%
qw_test.loc[((~qw_test.salary_max_desc.isnull()) &(qw_test.y_pred>qw_test.X_from*2)  )]
# Out:
#             X_from         y_pred  salary_max_desc    y_pred_copy
# 132   84000.000000  170807.751285         180000.0  170807.751285
# 166   15000.000000   32187.595073          40000.0   32187.595073
# 213   95000.000000  257625.069863         350000.0  257625.069863
# 259   55000.000000  117236.694303         150000.0  117236.694303
# 261   40000.000000  110607.241944         120000.0  110607.241944
# ...            ...            ...              ...            ...
# 8960  60000.000000  127663.875696         140000.0  127663.875696
# 8969  70000.000000  193580.217705         235000.0  193580.217705
# 8976  30000.000000   91322.635511         100000.0   91322.635511
# 9177  55195.569284  154551.854336         238000.0  154551.854336
# 9195  25000.000000   72265.713587          80000.0   72265.713587
#
# [128 rows x 4 columns]

# %%
qw_test['difff'] = abs(qw_test.salary_max_desc-qw_test.y_pred_copy)
qw_test[((~qw_test.salary_max_desc.isnull())&(qw_test.X_from>qw_test.y_pred )  )].sort_values(by = 'difff').tail(30)
# Out:
#              X_from    y_pred  salary_max_desc    y_pred_copy          difff
# 1737   53257.592913   30000.0          30000.0   90609.852259   60609.852259
# 1416  133224.153417  100000.0         100000.0  161003.448527   61003.448527
# 8701   31300.000000   24000.0          24000.0   85597.170670   61597.170670
# 2577   31300.000000   24000.0          24000.0   88269.746776   64269.746776
# 6006   68732.171363   60000.0          60000.0  125716.713510   65716.713510
# 4624   67993.316050   20000.0          20000.0   89771.639249   69771.639249
# 7583   91801.844129   40000.0          40000.0  114290.803321   74290.803321
# 175   101542.553721   60000.0          60000.0  137404.895996   77404.895996
# 8826   51834.501212   10000.0          10000.0   89967.844690   79967.844690
# 8075  250000.000000  200000.0         200000.0  282997.230938   82997.230938
# 9066  134543.185897  120000.0         120000.0  206676.646340   86676.646340
# 2395   80353.886693   10000.0          10000.0   97265.778425   87265.778425
# 4570  160000.000000   50000.0          50000.0  142075.522499   92075.522499
# 9019   95654.361013   11000.0          11000.0  105799.948059   94799.948059
# 49     54798.753443   12000.0          12000.0  107106.855918   95106.855918
# 1883  104848.366611   30000.0          30000.0  125542.049733   95542.049733
# 934   200000.000000  170000.0         170000.0  266953.728752   96953.728752
# 8568   86441.354637   50000.0          50000.0  148055.017808   98055.017808
# 5195  101362.098631  100000.0         100000.0  201196.608703  101196.608703
# 4556  115560.613080  100000.0         100000.0  208282.340947  108282.340947
# 8851  200000.000000  170000.0         170000.0  279167.248010  109167.248010
# 6661   54871.128919   15000.0          15000.0  128858.789521  113858.789521
# 6128   31300.000000   24000.0          24000.0  139023.637050  115023.637050
# 2868  100452.070831   80000.0          80000.0  207212.774698  127212.774698
# 1617  105925.119550   10000.0          10000.0  151468.588195  141468.588195
# 424   114321.334894   25000.0          25000.0  205486.522504  180486.522504
# 138   122638.147272   20000.0          20000.0  208578.749073  188578.749073
# 1520  130000.000000   20000.0          20000.0  219732.010009  199732.010009
# 2324  189194.545839  102000.0         102000.0  338568.045026  236568.045026
# 1128  172476.192619   25000.0          25000.0  280160.596074  255160.596074

# %%
qw_test.loc[((~qw_test.salary_max_desc.isnull()) &(qw_test.X_from>qw_test.y_pred )& (qw_test.difff>40000)), 'y_pred'] = qw_test.loc[((~qw_test.salary_max_desc.isnull())  &(qw_test.X_from>qw_test.y_pred )& (qw_test.difff>40000))].y_pred_copy

# %%
qw_test[((~qw_test.salary_max_desc.isnull()) )].sort_values(by = 'difff').tail(20)
# Out:
#              X_from         y_pred  salary_max_desc    y_pred_copy  \
# 3877  101700.000000  160000.000000         160000.0  310677.055458
# 7822   42838.113455   98726.272158         250000.0   98726.272158
# 6629      40.000000  193176.853203          40000.0  193176.853203
# 7441   50000.000000  146445.240776         300000.0  146445.240776
# 7243  120000.000000  150000.000000         150000.0  303641.326796
# 376   100000.000000  100000.000000         100000.0  264143.437664
# 424   114321.334894  205486.522504          25000.0  205486.522504
# 138   122638.147272  208578.749073          20000.0  208578.749073
# 1520  130000.000000  219732.010009          20000.0  219732.010009
# 6957   43785.745238   96690.320940         300000.0   96690.320940
# 2324  189194.545839  338568.045026         102000.0  338568.045026
# 2981  150000.000000  253704.087520         500000.0  253704.087520
# 4150  170000.000000  249434.524657         500000.0  249434.524657
# 1128  172476.192619  280160.596074          25000.0  280160.596074
# 3975  500000.000000  500000.000000         500000.0  760587.612808
# 2706   65377.611770  221597.735588         500000.0  221597.735588
# 5032   65000.000000  193950.596049         500000.0  193950.596049
# 8418   45200.000000  117992.553879         500000.0  117992.553879
# 1163   30000.000000   77971.686582         500000.0   77971.686582
# 6781   30500.000000   67640.966973         500000.0   67640.966973
#
#               difff
# 3877  150677.055458
# 7822  151273.727842
# 6629  153176.853203
# 7441  153554.759224
# 7243  153641.326796
# 376   164143.437664
# 424   180486.522504
# 138   188578.749073
# 1520  199732.010009
# 6957  203309.679060
# 2324  236568.045026
# 2981  246295.912480
# 4150  250565.475343
# 1128  255160.596074
# 3975  260587.612808
# 2706  278402.264412
# 5032  306049.403951
# 8418  382007.446121
# 1163  422028.313418
# 6781  432359.033027

# %%
qw_test.loc[qw_test.X_from<150]
# Out:
#       X_from         y_pred  salary_max_desc    y_pred_copy          difff
# 466    40.00   98957.238110              NaN   98957.238110            NaN
# 989    79.10   96536.114655              NaN   96536.114655            NaN
# 1393   50.00   48319.470532              NaN   48319.470532            NaN
# 1828   35.00  106984.010260              NaN  106984.010260            NaN
# 2509   67.80   21803.443379              NaN   21803.443379            NaN
# 2650   20.00  178641.298801              NaN  178641.298801            NaN
# 3330    1.00   21959.973799          20000.0   21959.973799    1959.973799
# 3524    1.13  479102.522752              NaN  479102.522752            NaN
# 4079  100.00   99970.784607              NaN   99970.784607            NaN
# 4749   67.80     868.840616              NaN     868.840616            NaN
# 6323  120.00   91550.927319              NaN   91550.927319            NaN
# 6629   40.00  193176.853203          40000.0  193176.853203  153176.853203
# 7235   56.50   56545.073294              NaN   56545.073294            NaN
# 8284   70.00   49536.306423              NaN   49536.306423            NaN
# 8789   40.00   25255.909296              NaN   25255.909296            NaN

# %%
qw_test.loc[qw_test.X_from<150,'y_pred']  = qw_test.loc[qw_test.X_from<=150].X_from*1.2
y_pred_test=qw_test.y_pred

# %%
qw_test.tail(10)
# Out:
#           X_from         y_pred  salary_max_desc    y_pred_copy         difff
# 9302  10000.0000   43782.375449              NaN   43782.375449           NaN
# 9303  67800.0000   74677.596090              NaN   74677.596090           NaN
# 9304  55000.0000  106615.123141              NaN  106615.123141           NaN
# 9305  60000.0000  114992.245519         140000.0  114992.245519  25007.754481
# 9306  60000.0000   80000.000000          80000.0  128472.344363  48472.344363
# 9307  40000.0000   85806.532278              NaN   85806.532278           NaN
# 9308  40000.0000   97580.807733              NaN   97580.807733           NaN
# 9309  39550.0000   39288.070943              NaN   39288.070943           NaN
# 9310  52112.2871   68927.627835              NaN   68927.627835           NaN
# 9311  30000.0000   31000.642144              NaN   31000.642144           NaN

# %%
df_sub = pd.read_csv('/kaggle/input/nsu-jobs/random_result.csv')

# %%
df_sub.salary_to=y_pred_test
df_sub
# Out:
#          id      salary_to
# 0     20978   40576.952958
# 1      3102   61898.300145
# 2     14731  200000.000000
# 3     16113  212027.458584
# 4      8410  138294.074065
# ...     ...            ...
# 9307  29490   85806.532278
# 9308  34298   97580.807733
# 9309  33921   39288.070943
# 9310   8886   68927.627835
# 9311  23978   31000.642144
#
# [9312 rows x 2 columns]

# %%
#чуть улучшил скор общей коррректировкой значений
df_sub.loc[df_sub.salary_to>80000,'salary_to' ]=df_sub[df_sub.salary_to>80000].salary_to*0.925
df_sub.loc[df_sub.salary_to>250000,'salary_to' ]=df_sub[df_sub.salary_to>250000].salary_to*0.975
df_sub.loc[df_sub.salary_to>500000,'salary_to' ]=df_sub[df_sub.salary_to>500000].salary_to*0.95
df_sub.loc[df_sub.salary_to<10,'salary_to' ]=df_sub[df_sub.salary_to<10].salary_to*0.83333
df_sub
# Out:
#          id      salary_to
# 0     20978   40576.952958
# 1      3102   61898.300145
# 2     14731  185000.000000
# 3     16113  196125.399190
# 4      8410  127922.018510
# ...     ...            ...
# 9307  29490   79371.042358
# 9308  34298   90262.247153
# 9309  33921   39288.070943
# 9310   8886   68927.627835
# 9311  23978   31000.642144
#
# [9312 rows x 2 columns]

# %%
df_sub.to_csv('submission111.csv', index=False)
